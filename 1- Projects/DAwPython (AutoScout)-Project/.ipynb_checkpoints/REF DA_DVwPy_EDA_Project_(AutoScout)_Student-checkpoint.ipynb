# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">DA & DVwPY</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Exploratory Data Analysis (EDA) Project</p>
#
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">AutoScout Car Price Prediction EDA</p>

# %% [markdown]
# ## Introduction
# Welcome to "***AutoScout Exploratory Data Analysis (EDA) Project***". This is the project of completing ***Data Analysis & Data Visualization*** Courses and a successful hand-over is mandatory for getting certification for both courses. **Auto Scout** data used in this project scraped from the Website of an online car trading company in 2022, and contains many features of 13 different car makes including 594 models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using a variety of Python libraries, such as Numpy, Pandas, Matplotlib, Seaborn, Scipy, and then you will get a clean dataset for your analysis and pretictive modelling in Machine Learning Path. So you will have the chance to use all the skills you have already learned in the Data Analysis and Visualization courses.
#
# **``In this context, the project consists of 3 parts in general:``**
# * **The first part** is related to ``'Data Cleaning'``. It deals with Incorrect Headers, Incorrect Format, Anomalies, and Dropping useless columns.
# * **The second part** is related to ``'Filling Data'``, in other words 'Imputation'. It deals with Missing Values. Categorical to numeric transformation, Encoding, is done as well.
# * **The third part** is related to ``'Handling Outliers of Data'`` via Visualization libraries. So, some insights will be extracted.
#
# **``SPECIAL NOTE:``**  However, you are ``free to create your own style``. You do ``NOT`` have to stick to the steps above. Nevertheless, we, the DA & DV instructors, recommend you study each part separately to create a source notebook for your further studies.
#
# In order to build your Portfolio in terms of the GitHub account, you need to push your solution file up to your own repository.
#
# Please after solving the task, commit your notebook to GitHub and submit its link to LMS page where the project is settled down.
#
# **BE NOTED:** Please ``DO NOT FORGET`` to click the submit button.
#
# ### Some Reminders on Exploratory data analysis (EDA)
#
# Exploratory data analysis (EDA) is an especially important activity in the routine of a data analyst or scientist. It enables an in depth understanding of the dataset, define or discard hypotheses and create predictive models on a solid basis. It uses data manipulation techniques and several statistical tools to describe and understand the relationship between variables and how these can impact business. By means of EDA, we can obtain meaningful insights that can impact analysis under the following questions (If a checklist is good enough for pilots to use every flight, it’s good enough for data scientists to use with every dataset).
# 1. What question are you trying to solve (or prove wrong)?
# 2. What kind of data do you have?
# 3. What’s missing from the data?
# 4. Where are the outliers?
# 5. How can you add, change or remove features to get more out of your data?
#
# **``Exploratory data analysis (EDA)``** is often an **iterative brainstorming process** where you pose a question, review the data, and develop further questions to investigate before beginning model development work. The image below shows how the brainstorming phase is connected with that of understanding the variables and how this in turn is connected again with the brainstorming phase.<br>
#
# <img src=https://i.ibb.co/k0MC950/EDA-Process.png width="300" height="100">
#
# [Image Credit: Andrew D.](https://towardsdatascience.com/exploratory-data-analysis-in-python-a-step-by-step-process-d0dfa6bf94ee)

# %% [markdown]
# # PART- 1 `( Data Cleaning )`

# %%
pip install skimpy --user
# Out:
# Requirement already satisfied: skimpy in c:\users\husey\appdata\roaming\python\python39\site-packages (0.0.8)
# Requirement already satisfied: ipykernel<7.0.0,>=6.7.0 in c:\users\husey\anaconda3\lib\site-packages (from skimpy) (6.15.2)
# Requirement already satisfied: rich<13.0,>=10.9 in c:\users\husey\appdata\roaming\python\python39\site-packages (from skimpy) (12.6.0)
# Requirement already satisfied: jupyter<2.0.0,>=1.0.0 in c:\users\husey\anaconda3\lib\site-packages (from skimpy) (1.0.0)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in c:\users\husey\appdata\roaming\python\python39\site-packages (from skimpy) (8.1.3)
# Requirement already satisfied: typeguard<3.0.0,>=2.12.1 in c:\users\husey\appdata\roaming\python\python39\site-packages (from skimpy) (2.13.3)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in c:\users\husey\appdata\roaming\python\python39\site-packages (from skimpy) (1.24.2)
# Requirement already satisfied: pandas<2.0.0,>=1.3.2 in c:\users\husey\anaconda3\lib\site-packages (from skimpy) (1.4.4)
# Requirement already satisfied: Pygments<3.0.0,>=2.10.0 in c:\users\husey\anaconda3\lib\site-packages (from skimpy) (2.11.2)
# Requirement already satisfied: colorama in c:\users\husey\anaconda3\lib\site-packages (from click<9.0.0,>=8.1.3->skimpy) (0.4.5)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\husey\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (0.1.6)
# Requirement already satisfied: tornado>=6.1 in c:\users\husey\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (6.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\husey\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (23.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\husey\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (7.3.4)
# Requirement already satisfied: traitlets>=5.1.0 in c:\users\husey\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.1.1)
# Requirement already satisfied: nest-asyncio in c:\users\husey\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.5.5)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\husey\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (7.31.1)
# Requirement already satisfied: packaging in c:\users\husey\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (21.3)
# Requirement already satisfied: debugpy>=1.0 in c:\users\husey\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.5.1)
# Requirement already satisfied: psutil in c:\users\husey\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.9.0)
# Requirement already satisfied: jupyter-console in c:\users\husey\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (6.4.3)
# Requirement already satisfied: ipywidgets in c:\users\husey\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (7.6.5)
# Requirement already satisfied: nbconvert in c:\users\husey\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (6.4.4)
# Requirement already satisfied: qtconsole in c:\users\husey\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (5.2.2)
# Requirement already satisfied: notebook in c:\users\husey\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (6.4.12)
# Requirement already satisfied: pytz>=2020.1 in c:\users\husey\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.3.2->skimpy) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\husey\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.3.2->skimpy) (2.8.2)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\husey\appdata\roaming\python\python39\site-packages (from rich<13.0,>=10.9->skimpy) (0.9.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\husey\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\husey\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (3.0.20)
# Requirement already satisfied: decorator in c:\users\husey\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (5.1.1)
# Requirement already satisfied: backcall in c:\users\husey\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\husey\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (63.4.1)
# Requirement already satisfied: pickleshare in c:\users\husey\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.7.5)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\husey\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel<7.0.0,>=6.7.0->skimpy) (4.11.1)
# Requirement already satisfied: entrypoints in c:\users\husey\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel<7.0.0,>=6.7.0->skimpy) (0.4)
# Requirement already satisfied: six>=1.5 in c:\users\husey\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.3.2->skimpy) (1.16.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\husey\anaconda3\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (5.5.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\husey\anaconda3\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (1.0.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\husey\anaconda3\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\husey\anaconda3\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (3.5.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\husey\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.8.4)
# Requirement already satisfied: testpath in c:\users\husey\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.6.0)
# Requirement already satisfied: defusedxml in c:\users\husey\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\husey\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.5.13)
# Requirement already satisfied: bleach in c:\users\husey\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\husey\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (1.5.0)
# Requirement already satisfied: jinja2>=2.4 in c:\users\husey\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (2.11.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\husey\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.1.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\husey\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (4.11.1)
# Requirement already satisfied: prometheus-client in c:\users\husey\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.14.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\husey\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.13.1)
# Requirement already satisfied: argon2-cffi in c:\users\husey\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\husey\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\husey\anaconda3\lib\site-packages (from packaging->ipykernel<7.0.0,>=6.7.0->skimpy) (3.0.9)
# Requirement already satisfied: qtpy in c:\users\husey\anaconda3\lib\site-packages (from qtconsole->jupyter<2.0.0,>=1.0.0->skimpy) (2.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\husey\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\husey\anaconda3\lib\site-packages (from jinja2>=2.4->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (2.0.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\husey\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel<7.0.0,>=6.7.0->skimpy) (302)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\husey\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (4.16.0)
# Requirement already satisfied: fastjsonschema in c:\users\husey\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\husey\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.5)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\husey\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\husey\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\husey\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\husey\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.5.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\husey\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\husey\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (21.4.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\husey\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\husey\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import re
import seaborn as sns 
import matplotlib.pyplot as plt
#from skimpy import clean_columns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %matplotlib inline
# %matplotlib notebook

plt.rcParams["figure.figsize"] = (10,6)
# plt.rcParams['figure.dpi'] = 100

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.2f' % x)

pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %%
df0 = pd.read_json("as24_cars.json")

# %%
df = df0.copy()

# %%
df.head(10).T
# Out:
#                                                                       21427  \
# make_model                                                      Ford Fiesta
# short_description                            Active Colourline 1.0 EcoBoost
# make                                                               \nFord\n
# model                                                      [\n, Fiesta ,\n]
# location                       Herforder Str. 175,  32105 Bad Salzuflen, DE
# price                                                            € 13,970.-
# body_type                                                 [\n, Compact, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                           [\n, Germany, \n]
# offer_number                                            [\n, 100131916, \n]
# warranty                                                [\n, 12 months, \n]
# mileage                                                           78,212 km
# first_registration                                                  03/2019
# gearbox                                                        [\nManual\n]
# fuel_type                                                          Gasoline
# colour                                                                 Grey
# paint                                                              Metallic
# desc                      [Fahrzeug-Nr: 100131916,  ,  , Media,  , Audio...
# seller                                                               Dealer
# seats                                                                  5.00
# power                                                  [\n74 kW (101 hp)\n]
# engine_size                                                    [\n998 cc\n]
# gears                                                                   NaN
# co₂_emissions                                              133 g/km (comb.)
# manufacturer_colour                                  Blizzard-Grau Metallic
# drivetrain                                                  [\n, Front, \n]
# cylinders                                                               NaN
# fuel_consumption          [[5 l/100 km (comb.)], [5.9 l/100 km (city)], ...
# comfort_convenience       [Air conditioning, Automatic climate control, ...
# entertainment_media       Android Auto, Apple CarPlay, Bluetooth, Digita...
# safety_security           [ABS, Adaptive headlights, Central door lock, ...
# extras                    [Alloy wheels, Automatically dimming interior ...
# empty_weight                                                            NaN
# model_code                                               [\n, 8566/BOF, \n]
# general_inspection                                                      New
# last_service                                                            NaN
# full_service_history                                                    Yes
# non_smoker_vehicle                                                      Yes
# emission_class                                                 Euro 6d-TEMP
# emissions_sticker                                                 4 (Green)
# upholstery_colour                                                     Other
# upholstery                                                            Cloth
# production_date                                                     2019.00
# previous_owner                                    [[78,212 km, 03/2019], 1]
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                   C
# co₂_efficiency            Calculated on basis of measured CO₂-emissions ...
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2      Android Auto, Apple CarPlay, Bluetooth, Digita...
# entertainment_media1      [['Android Auto,  Apple CarPlay,  Bluetooth,  ...
# entertainment_point1                                                  10.00
# entertainment_media3      Android Auto, Apple CarPlay, Bluetooth, Digita...
#
#                                                                       9157   \
# make_model                                                      Peugeot 508
# short_description                  SW 1.5 bluehdi GT s&s 130cv eat8 - PROMO
# make                                                            \nPeugeot\n
# model                                                         [\n, 508 ,\n]
# location                     Strada Pianezza, 275/b,  10151 Torino - To, IT
# price                                                            € 30,990.-
# body_type                                           [\n, Station wagon, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                                         NaN
# offer_number                                            [\n, U_1064705, \n]
# warranty                                                [\n, 12 months, \n]
# mileage                                                               10 km
# first_registration                                                  05/2021
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                                            Diesel
# colour                                                                White
# paint                                                              Metallic
# desc                      [Per informazioni:, - Telefono fisso: 01145376...
# seller                                                               Dealer
# seats                                                                  5.00
# power                                                  [\n96 kW (131 hp)\n]
# engine_size                                                  [\n1,499 cc\n]
# gears                                                               [\n8\n]
# co₂_emissions                                               98 g/km (comb.)
# manufacturer_colour                                                  Bianco
# drivetrain                                                  [\n, Front, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption          [[3.7 l/100 km (comb.)], [4.2 l/100 km (city)]...
# comfort_convenience       [Air conditioning, Armrest, Automatic climate ...
# entertainment_media       Android Auto, Apple CarPlay, Digital cockpit, ...
# safety_security           [ABS, Adaptive Cruise Control, Driver-side air...
# extras                    [Alloy wheels, Electronic parking brake, Touch...
# empty_weight                                                 [\n1,505 kg\n]
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                       Euro 6
# emissions_sticker                                                       NaN
# upholstery_colour                                                     Black
# upholstery                                                     Part leather
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2      Android Auto, Apple CarPlay, Digital cockpit, ...
# entertainment_media1      [['Android Auto,  Apple CarPlay,  Digital cock...
# entertainment_point1                                                   5.00
# entertainment_media3      Android Auto, Apple CarPlay, Digital cockpit, ...
#
#                                                                       17010  \
# make_model                                                    Toyota Aygo X
# short_description                                                    x-wave
# make                                                             \nToyota\n
# model                                                      [\n, Aygo X ,\n]
# location                              Halskestraße 1,  72766 Reutlingen, DE
# price                                                            € 10,490.-
# body_type                                                 [\n, Compact, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                           [\n, Germany, \n]
# offer_number                                            [\n, 102208163, \n]
# warranty                                                [\n, 12 months, \n]
# mileage                                                           38,000 km
# first_registration                                                  01/2015
# gearbox                                                        [\nManual\n]
# fuel_type                                                Regular/Benzine 91
# colour                                                                White
# paint                                                                   NaN
# desc                      [Standort: ,  Halskestr. 1 - 72766 Reutlingen ...
# seller                                                               Dealer
# seats                                                                  4.00
# power                                                   [\n51 kW (69 hp)\n]
# engine_size                                                    [\n998 cc\n]
# gears                                                               [\n5\n]
# co₂_emissions                                               95 g/km (comb.)
# manufacturer_colour                                             Pianosaweiß
# drivetrain                                                              NaN
# cylinders                                                           [\n3\n]
# fuel_consumption          [[4.1 l/100 km (comb.)], [5 l/100 km (city)], ...
# comfort_convenience       [Air conditioning, Electrical side mirrors, Hi...
# entertainment_media       Bluetooth, Hands-free equipment, On-board comp...
# safety_security           [ABS, Central door lock, Central door lock wit...
# extras                    [Alloy wheels (15"), Cargo barrier, E10-enable...
# empty_weight                                                   [\n915 kg\n]
# model_code                                               [\n, 5013/AJG, \n]
# general_inspection                                                      New
# last_service                                                            NaN
# full_service_history                                                    Yes
# non_smoker_vehicle                                                      Yes
# emission_class                                                       Euro 5
# emissions_sticker                                                 4 (Green)
# upholstery_colour                                                      Grey
# upholstery                                                     Part leather
# production_date                                                     2015.00
# previous_owner                                    [[38,000 km, 01/2015], 3]
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                   B
# co₂_efficiency            Calculated on basis of measured CO₂-emissions ...
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2      Bluetooth, Hands-free equipment, On-board comp...
# entertainment_media1      [['Bluetooth,  Hands-free equipment,  On-board...
# entertainment_point1                                                   5.00
# entertainment_media3      Bluetooth, Hands-free equipment, On-board comp...
#
#                                                                       12164  \
# make_model                                                       SEAT Ibiza
# short_description                                            1.9 SDi Stella
# make                                                               \nSEAT\n
# model                                                       [\n, Ibiza ,\n]
# location                  CRTA. BILBAO - SAN SEBASTIAN, KM6,  48960 GALD...
# price                                                             € 2,990.-
# body_type                                                 [\n, Compact, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                             [\n, Spain, \n]
# offer_number                                              [\n, 7442193, \n]
# warranty                                                [\n, 12 months, \n]
# mileage                                                          162,000 km
# first_registration                                                  05/2003
# gearbox                                                        [\nManual\n]
# fuel_type                                                            Diesel
# colour                                                               Silver
# paint                                                              Metallic
# desc                      [-AIRE ACONDICIONADO, -CIERRE CENTRALIZADO, -E...
# seller                                                               Dealer
# seats                                                                  5.00
# power                                                   [\n50 kW (68 hp)\n]
# engine_size                                                  [\n1,896 cc\n]
# gears                                                               [\n5\n]
# co₂_emissions                                                           NaN
# manufacturer_colour                                                     NaN
# drivetrain                                                  [\n, Front, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption          [[5.1 l/100 km (comb.)], [6.8 l/100 km (city)]...
# comfort_convenience                         [Power windows, Tinted windows]
# entertainment_media                                                     NaN
# safety_security                               [Immobilizer, Power steering]
# extras                                                                  NaN
# empty_weight                                                 [\n1,010 kg\n]
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                    NaN
# entertainment_media1                                                    NaN
# entertainment_point1                                                    NaN
# entertainment_media3                                                    NaN
#
#                                                                       11225  \
# make_model                                                        Fiat Tipo
# short_description                                                    1.0 SW
# make                                                               \nFiat\n
# model                                                        [\n, Tipo ,\n]
# location                  Via Nigra 4,  20037 Paderno Dugnano - Milano -...
# price                                                            € 16,990.-
# body_type                                           [\n, Station wagon, \n]
# type                                               [\n, Pre-registered, \n]
# doors                                                           [\n, 5, \n]
# country_version                                                         NaN
# offer_number                                             [\n, 16132005, \n]
# warranty                                                                NaN
# mileage                                                                8 km
# first_registration                                                  06/2021
# gearbox                                                        [\nManual\n]
# fuel_type                                                          Gasoline
# colour                                                                Brown
# paint                                                              Metallic
# desc                      [PROMO,  , TUA A PARTIRE DA 239,00€ AL MESE CO...
# seller                                                               Dealer
# seats                                                                  5.00
# power                                                  [\n74 kW (101 hp)\n]
# engine_size                                                    [\n999 cc\n]
# gears                                                               [\n5\n]
# co₂_emissions                                              126 g/km (comb.)
# manufacturer_colour                                                 Marrone
# drivetrain                                                  [\n, Front, \n]
# cylinders                                                           [\n3\n]
# fuel_consumption          [[5.3 l/100 km (comb.)], [4.5 l/100 km (city)]...
# comfort_convenience       [Air conditioning, Cruise control, Hill Holder...
# entertainment_media       Bluetooth, Digital radio, Hands-free equipment...
# safety_security           [ABS, Alarm system, Central door lock, Central...
# extras                                          [Spare tyre, Voice Control]
# empty_weight                                                 [\n1,345 kg\n]
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                 Euro 6d-TEMP
# emissions_sticker                                                       NaN
# upholstery_colour                                                     Black
# upholstery                                                            Cloth
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2      Bluetooth, Digital radio, Hands-free equipment...
# entertainment_media1      [['Bluetooth,  Digital radio,  Hands-free equi...
# entertainment_point1                                                   7.00
# entertainment_media3      Bluetooth, Digital radio, Hands-free equipment...
#
#                                                                       26736  \
# make_model                                                        Volvo C70
# short_description                 2.0T Cabriolet Comfort Klima,Leder,1.Hand
# make                                                              \nVolvo\n
# model                                                         [\n, C70 ,\n]
# location                                    Webereistr.6,  01640 Coswig, DE
# price                                                            € 13,999.-
# body_type                                             [\n, Convertible, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 2, \n]
# country_version                                           [\n, Germany, \n]
# offer_number                                                            NaN
# warranty                                                                NaN
# mileage                                                           37,407 km
# first_registration                                                  05/2001
# gearbox                                                        [\nManual\n]
# fuel_type                                                          Gasoline
# colour                                                               Silver
# paint                                                              Metallic
# desc                      [Herzlich Willkommen, Autokauf ist Vertrauenss...
# seller                                                               Dealer
# seats                                                                  4.00
# power                                                 [\n120 kW (163 hp)\n]
# engine_size                                                  [\n1,984 cc\n]
# gears                                                                   NaN
# co₂_emissions                                              230 g/km (comb.)
# manufacturer_colour                                                     NaN
# drivetrain                                                              NaN
# cylinders                                                               NaN
# fuel_consumption          [[9.7 l/100 km (comb.)], [11.5 l/100 km (city)...
# comfort_convenience       [Air conditioning, Armrest, Cruise control, El...
# entertainment_media                     CD player, On-board computer, Radio
# safety_security           [ABS, Central door lock, Driver-side airbag, F...
# extras                    [Alloy wheels, Automatically dimming interior ...
# empty_weight                                                            NaN
# model_code                                               [\n, 9101/800, \n]
# general_inspection                                                      New
# last_service                                                            NaN
# full_service_history                                                    Yes
# non_smoker_vehicle                                                      Yes
# emission_class                                                       Euro 3
# emissions_sticker                                                 4 (Green)
# upholstery_colour                                                      Grey
# upholstery                                                     Full leather
# production_date                                                         NaN
# previous_owner                                    [[37,407 km, 05/2001], 1]
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                    CD player, On-board computer, Radio
# entertainment_media1            [['CD player,  On-board computer,  Radio']]
# entertainment_point1                                                   3.00
# entertainment_media3                    CD player, On-board computer, Radio
#
#                                                                       3137   \
# make_model                                                     Opel Cascada
# short_description          2.0 CDTI*Start/Stop Edition*Leder*Navi*Bi-Xenon*
# make                                                               \nOpel\n
# model                                                     [\n, Cascada ,\n]
# location                  Gustav-Stresemann-Straße 4,  66806 Ensdorf/Saa...
# price                                                             € 9,950.-
# body_type                                             [\n, Convertible, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 2, \n]
# country_version                                           [\n, Germany, \n]
# offer_number                                                            NaN
# warranty                                                                NaN
# mileage                                                          183,679 km
# first_registration                                                  07/2014
# gearbox                                                        [\nManual\n]
# fuel_type                                                            Diesel
# colour                                                                 Grey
# paint                                                              Metallic
# desc                      [Zum verkauf steht ein Opel Cascada Cabriolet ...
# seller                                                               Dealer
# seats                                                                  4.00
# power                                                 [\n121 kW (165 hp)\n]
# engine_size                                                  [\n1,956 cc\n]
# gears                                                               [\n6\n]
# co₂_emissions                                              138 g/km (comb.)
# manufacturer_colour                                   Phantom Grau Metallic
# drivetrain                                                              NaN
# cylinders                                                           [\n4\n]
# fuel_consumption          [[5.2 l/100 km (comb.)], [6.3 l/100 km (city)]...
# comfort_convenience       [Air conditioning, Armrest, Automatic climate ...
# entertainment_media       Bluetooth, CD player, Hands-free equipment, On...
# safety_security           [ABS, Adaptive headlights, Bi-Xenon headlights...
# extras                    [Alloy wheels, Electronic parking brake, Emerg...
# empty_weight                                                 [\n1,816 kg\n]
# model_code                                               [\n, 0035/AYE, \n]
# general_inspection                                                  10/2023
# last_service                                                        04/2021
# full_service_history                                                    Yes
# non_smoker_vehicle                                                      Yes
# emission_class                                                       Euro 5
# emissions_sticker                                                 4 (Green)
# upholstery_colour                                                     Brown
# upholstery                                                     Full leather
# production_date                                                         NaN
# previous_owner                                   [[183,679 km, 07/2014], 2]
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2      Bluetooth, CD player, Hands-free equipment, On...
# entertainment_media1      [['Bluetooth,  CD player,  Hands-free equipmen...
# entertainment_point1                                                   5.00
# entertainment_media3      Bluetooth, CD player, Hands-free equipment, On...
#
#                                                                       2957   \
# make_model                                                       Opel Astra
# short_description                                          Cosmo H Twin Top
# make                                                               \nOpel\n
# model                                                       [\n, Astra ,\n]
# location                          Memminger Str. 50 1/2,  89231 Neu-Ulm, DE
# price                                                             € 4,480.-
# body_type                                             [\n, Convertible, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 2, \n]
# country_version                                           [\n, Germany, \n]
# offer_number                                                   [\n, 07, \n]
# warranty                                                                NaN
# mileage                                                          111,000 km
# first_registration                                                  03/2007
# gearbox                                                        [\nManual\n]
# fuel_type                                                          Gasoline
# colour                                                                 Blue
# paint                                                              Metallic
# desc                      [Sonderausstattung:, Innenausstattung: Leder, ...
# seller                                                               Dealer
# seats                                                                  4.00
# power                                                 [\n103 kW (140 hp)\n]
# engine_size                                                  [\n1,796 cc\n]
# gears                                                               [\n5\n]
# co₂_emissions                                              185 g/km (comb.)
# manufacturer_colour                                               Metro  M2
# drivetrain                                                  [\n, Front, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption          [[7.7 l/100 km (comb.)], [10.3 l/100 km (city)...
# comfort_convenience       [Air conditioning, Armrest, Cruise control, El...
# entertainment_media                CD player, MP3, On-board computer, Radio
# safety_security           [ABS, Central door lock, Central door lock wit...
# extras                    [Alloy wheels (17"), Emergency tyre, Emergency...
# empty_weight                                                 [\n1,500 kg\n]
# model_code                                               [\n, 0035/AAN, \n]
# general_inspection                                                  05/2024
# last_service                                                        08/2017
# full_service_history                                                    Yes
# non_smoker_vehicle                                                      Yes
# emission_class                                                       Euro 4
# emissions_sticker                                                 4 (Green)
# upholstery_colour                                                     Black
# upholstery                                                            Other
# production_date                                                         NaN
# previous_owner                                   [[111,000 km, 03/2007], 2]
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                             11/2017
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2               CD player, MP3, On-board computer, Radio
# entertainment_media1      [['CD player,  MP3,  On-board computer,  Radio']]
# entertainment_point1                                                   4.00
# entertainment_media3               CD player, MP3, On-board computer, Radio
#
#                                                                       13504  \
# make_model                                                        SEAT Leon
# short_description                                        1.5 TSI ACT OPF FR
# make                                                               \nSEAT\n
# model                                                        [\n, Leon ,\n]
# location                           Nürnberger Str. 51,  91126 Schwabach, DE
# price                                                            € 21,970.-
# body_type                                                   [\n, Sedan, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                           [\n, Germany, \n]
# offer_number                                            [\n, 102159496, \n]
# warranty                                                [\n, 12 months, \n]
# mileage                                                           21,753 km
# first_registration                                                  07/2019
# gearbox                                                        [\nManual\n]
# fuel_type                              Regular/Benzine 91 (Particle filter)
# colour                                                                 Grey
# paint                                                              Metallic
# desc                      [Standort: ,  Nuernberger Str. 51 - 91126 Schw...
# seller                                                               Dealer
# seats                                                                  5.00
# power                                                 [\n110 kW (150 hp)\n]
# engine_size                                                  [\n1,498 cc\n]
# gears                                                               [\n6\n]
# co₂_emissions                                              117 g/km (comb.)
# manufacturer_colour                                           Magnetic Tech
# drivetrain                                                              NaN
# cylinders                                                           [\n4\n]
# fuel_consumption          [[5.1 l/100 km (comb.)], [6.5 l/100 km (city)]...
# comfort_convenience       [Air conditioning, Armrest, Automatic climate ...
# entertainment_media       Android Auto, Apple CarPlay, Bluetooth, CD pla...
# safety_security           [ABS, Adaptive headlights, Central door lock, ...
# extras                    [Alloy wheels (18"), Ambient lighting, Automat...
# empty_weight                                                 [\n1,243 kg\n]
# model_code                                               [\n, 7593/AOK, \n]
# general_inspection                                                      New
# last_service                                                            NaN
# full_service_history                                                    Yes
# non_smoker_vehicle                                                      Yes
# emission_class                                                 Euro 6d-TEMP
# emissions_sticker                                                 4 (Green)
# upholstery_colour                                                      Grey
# upholstery                                                            Cloth
# production_date                                                     2019.00
# previous_owner                                    [[21,753 km, 07/2019], 2]
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                   B
# co₂_efficiency            Calculated on basis of measured CO₂-emissions ...
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2      Android Auto, Apple CarPlay, Bluetooth, CD pla...
# entertainment_media1      [['Android Auto,  Apple CarPlay,  Bluetooth,  ...
# entertainment_point1                                                  12.00
# entertainment_media3      Android Auto, Apple CarPlay, Bluetooth, CD pla...
#
#                                                                       6530   \
# make_model                                            Renault Megane E-Tech
# short_description                                   IV Estate 1.5 dCi 110ch
# make                                                            \nRenault\n
# model                                               [\n, Megane E-Tech ,\n]
# location                          264 Rue Henri Ducassou,  56850 Caudan, FR
# price                                                            € 14,990.-
# body_type                                           [\n, Station wagon, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                                         NaN
# offer_number                                               [\n, 119978, \n]
# warranty                                                 [\n, 3 months, \n]
# mileage                                                           95,000 km
# first_registration                                                  07/2018
# gearbox                                                        [\nManual\n]
# fuel_type                                                            Diesel
# colour                                                                 Grey
# paint                                                                   NaN
# desc                      [Renault Megane en très bon état ,  , Contrôle...
# seller                                                               Dealer
# seats                                                                  5.00
# power                                                  [\n81 kW (110 hp)\n]
# engine_size                                                             NaN
# gears                                                                   NaN
# co₂_emissions                                               95 g/km (comb.)
# manufacturer_colour                                                    Gris
# drivetrain                                                              NaN
# cylinders                                                               NaN
# fuel_consumption                                                        NaN
# comfort_convenience       [Armrest, Cruise control, Multi-function steer...
# entertainment_media       Android Auto, Apple CarPlay, Bluetooth, On-boa...
# safety_security           [ABS, Adaptive headlights, Electronic stabilit...
# extras                        [Ambient lighting, Spare tyre, Voice Control]
# empty_weight                                                            NaN
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                        07/2022
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# ...
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                    NaN
# entertainment_media1                                                    NaN
# entertainment_point1                                                    NaN
# entertainment_media3                                                    NaN
#
#                                                                       14854  \
# make_model                                                    Skoda Octavia
# short_description                             Combi 1.5 TSI Soleil Navi DAB
# make                                                              \nSkoda\n
# model                                                     [\n, Octavia ,\n]
# location                         Weidenauer Str. 124-136,  57076 Siegen, DE
# price                                                            € 23,350.-
# body_type                                           [\n, Station wagon, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                           [\n, Germany, \n]
# offer_number                                                [\n, 19050, \n]
# warranty                                                                NaN
# mileage                                                           66,200 km
# first_registration                                                  06/2020
# gearbox                                                        [\nManual\n]
# fuel_type                                                          Super 95
# colour                                                                White
# paint                                                                   NaN
# desc                      [Pakete, , Ablagepaket, Chrom black Paket, Chr...
# seller                                                               Dealer
# seats                                                                  5.00
# power                                                 [\n110 kW (150 hp)\n]
# engine_size                                                  [\n1,498 cc\n]
# gears                                                               [\n6\n]
# co₂_emissions                                              116 g/km (comb.)
# manufacturer_colour                                             Candy-Weiss
# drivetrain                                                  [\n, Front, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption          [[4.9 l/100 km (comb.)], [5.1 l/100 km (city)]...
# comfort_convenience       [Air conditioning, Armrest, Automatic climate ...
# entertainment_media       Bluetooth, Digital radio, Hands-free equipment...
# safety_security           [ABS, Central door lock, Daytime running light...
# extras                    [Alloy wheels, Catalytic Converter, Roof rack,...
# empty_weight                                                 [\n1,280 kg\n]
# model_code                                               [\n, 8004/ASY, \n]
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      Yes
# emission_class                                                       Euro 6
# emissions_sticker                                                 4 (Green)
# upholstery_colour                                                     Black
# upholstery                                                            Cloth
# production_date                                                         NaN
# previous_owner                                    [[66,200 km, 06/2020], 1]
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                   B
# co₂_efficiency            Calculated on basis of measured CO₂-emissions ...
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2      Bluetooth, Digital radio, Hands-free equipment...
# entertainment_media1      [['Bluetooth,  Digital radio,  Hands-free equi...
# entertainment_point1                                                   6.00
# entertainment_media3      Bluetooth, Digital radio, Hands-free equipment...
#
#                                                                       19604  \
# make_model                                                      Nissan 350Z
# short_description               Cabrio Leder Klima Brembo Bose Xeno SHZ 18"
# make                                                             \nNissan\n
# model                                                        [\n, 350Z ,\n]
# location                            Im Brenntenstock 5,  74613 Öhringen, DE
# price                                                            € 11,890.-
# body_type                                             [\n, Convertible, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 2, \n]
# country_version                                                         NaN
# offer_number                                                            NaN
# warranty                                                                NaN
# mileage                                                          107,000 km
# first_registration                                                  04/2005
# gearbox                                                        [\nManual\n]
# fuel_type                                                Regular/Benzine 91
# colour                                                               Silver
# paint                                                              Metallic
# desc                      [Nissan 350Z Cabrio Premium Pack !, Silver Met...
# seller                                                               Dealer
# seats                                                                  2.00
# power                                                 [\n206 kW (280 hp)\n]
# engine_size                                                  [\n3,498 cc\n]
# gears                                                                   NaN
# co₂_emissions                                              273 g/km (comb.)
# manufacturer_colour                                         Silver Metallic
# drivetrain                                                              NaN
# cylinders                                                               NaN
# fuel_consumption          [[11.4 l/100 km (comb.)], [16.1 l/100 km (city...
# comfort_convenience       [Air conditioning, Automatic climate control, ...
# entertainment_media       CD player, Hands-free equipment, On-board comp...
# safety_security           [ABS, Central door lock, Driver-side airbag, E...
# extras                    [Alloy wheels, Headlight washer system, Sport ...
# empty_weight                                                            NaN
# model_code                                                              NaN
# general_inspection                                                  06/2024
# last_service                                                            NaN
# full_service_history                                                    Yes
# non_smoker_vehicle                                                      NaN
# emission_class                                                       Euro 3
# emissions_sticker                                                 4 (Green)
# upholstery_colour                                                     Black
# upholstery                                                     Full leather
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2      CD player, Hands-free equipment, On-board comp...
# entertainment_media1      [['CD player,  Hands-free equipment,  On-board...
# entertainment_point1                                                   5.00
# entertainment_media3      CD player, Hands-free equipment, On-board comp...
#
#                                                                       1677
# make_model                                              Mercedes-Benz E 350
# short_description                      T CDI 4Matic*Airmatic*StHz*Distronic
# make                                                      \nMercedes-Benz\n
# model                                                       [\n, E 350 ,\n]
# location                           Neuköllner Straße 234,  12357 Berlin, DE
# price                                                            € 29,950.-
# body_type                                           [\n, Station wagon, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 4, \n]
# country_version                                           [\n, Germany, \n]
# offer_number                                                   [\n, 26, \n]
# warranty                                                      [\n, Yes, \n]
# mileage                                                           82,259 km
# first_registration                                                  12/2013
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                                            Diesel
# colour                                                                Black
# paint                                                              Metallic
# desc                      [Fahrzeug lückenlos bei Mercedes scheckheftgep...
# seller                                                               Dealer
# seats                                                                  5.00
# power                                                 [\n185 kW (252 hp)\n]
# engine_size                                                  [\n2,987 cc\n]
# gears                                                                   NaN
# co₂_emissions                                              170 g/km (comb.)
# manufacturer_colour                          OBSIDIANSCHWARZ - METALLICLACK
# drivetrain                                                    [\n, 4WD, \n]
# cylinders                                                               NaN
# fuel_consumption          [[6.4 l/100 km (comb.)], [7.7 l/100 km (city)]...
# comfort_convenience       [360° camera, Air conditioning, Air suspension...
# entertainment_media       Bluetooth, CD player, Hands-free equipment, On...
# safety_security           [ABS, Adaptive Cruise Control, Alarm system, B...
# extras                    [Alloy wheels, Ambient lighting, Automatically...
# empty_weight                                                            NaN
# model_code                                                              NaN
# general_inspection                                                  04/2023
# last_service                                                            NaN
# full_service_history                                                    Yes
# non_smoker_vehicle                                                      Yes
# emission_class                                                       Euro 6
# emissions_sticker                                                 4 (Green)
# upholstery_colour                                                     Black
# upholstery                                                     Full leather
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2      Bluetooth, CD player, Hands-free equipment, On...
# entertainment_media1      [['Bluetooth,  CD player,  Hands-free equipmen...
# entertainment_point1                                                   7.00
# entertainment_media3      Bluetooth, CD player, Hands-free equipment, On...

# %%
df.sample().T
# Out:
#                                                                        19153
# make_model                                                      Nissan Micra
# short_description                                 1.0 IG 71 N-WAY Klima Navi
# make                                                              \nNissan\n
# model                                                        [\n, Micra ,\n]
# location                                 Hauptstrasse 34,  27386 Brockel, DE
# price                                                             € 12,750.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                            [\n, Germany, \n]
# Offer number                                                   [\n, 512, \n]
# Warranty                                                                 NaN
# Mileage                                                            33,430 km
# First registration                                                   09/2019
# Gearbox                                                         [\nManual\n]
# Fuel type                                                           Super 95
# Colour                                                                 Black
# Paint                                                               Metallic
# desc                       [Technik & Sicherheit:, Airbag Fahrer-/Beifahr...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                    [\n52 kW (71 hp)\n]
# Engine size                                                     [\n999 cc\n]
# Gears                                                                [\n5\n]
# CO₂-emissions                                               139 g/km (comb.)
# Manufacturer colour                                         Enigma Black (M)
# Drivetrain                                                   [\n, Front, \n]
# Cylinders                                                            [\n3\n]
# Fuel consumption           [[5.3 l/100 km (comb.)], [6.3 l/100 km (city)]...
# \nComfort & Convenience\n  [Air conditioning, Cruise control, Electrical ...
# \nEntertainment & Media\n  [Bluetooth, Digital radio, Hands-free equipmen...
# \nSafety & Security\n      [ABS, Central door lock, Daytime running light...
# \nExtras\n                 [Alloy wheels, Catalytic Converter, Touch scre...
# Empty weight                                                  [\n1,109 kg\n]
# Model code                                                [\n, 1329/ALD, \n]
# General inspection                                                       New
# Last service                                                             NaN
# Full service history                                                     Yes
# Non-smoker vehicle                                                       Yes
# Emission class                                                       Euro 6c
# Emissions sticker                                                  4 (Green)
# Upholstery colour                                                      Black
# Upholstery                                                             Cloth
# Production date                                                          NaN
# Previous owner                                     [[33,430 km, 09/2019], 1]
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                    C
# CO₂-efficiency             Calculated on basis of measured CO₂-emissions ...
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29480 entries, 0 to 29479
# Data columns (total 58 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   make_model                28630 non-null  object
#  1   short_description         28630 non-null  object
#  2   make                      28630 non-null  object
#  3   model                     28630 non-null  object
#  4   location                  28630 non-null  object
#  5   price                     28630 non-null  object
#  6   Body type                 28630 non-null  object
#  7   Type                      28630 non-null  object
#  8   Doors                     28271 non-null  object
#  9   Country version           16889 non-null  object
#  10  Offer number              23100 non-null  object
#  11  Warranty                  15784 non-null  object
#  12  Mileage                   28629 non-null  object
#  13  First registration        28628 non-null  object
#  14  Gearbox                   28382 non-null  object
#  15  Fuel type                 26843 non-null  object
#  16  Colour                    26906 non-null  object
#  17  Paint                     14495 non-null  object
#  18  desc                      28047 non-null  object
#  19  seller                    28630 non-null  object
#  20  Seats                     25505 non-null  object
#  21  Power                     28058 non-null  object
#  22  Engine size               27227 non-null  object
#  23  Gears                     18954 non-null  object
#  24  CO₂-emissions             18594 non-null  object
#  25  Manufacturer colour       21787 non-null  object
#  26  Drivetrain                16893 non-null  object
#  27  Cylinders                 18852 non-null  object
#  28  Fuel consumption          23385 non-null  object
#  29
# Comfort & Convenience
#    25433 non-null  object
#  30
# Entertainment & Media
#    23644 non-null  object
#  31
# Safety & Security
#        25415 non-null  object
#  32
# Extras
#                   23480 non-null  object
#  33  Empty weight              17758 non-null  object
#  34  Model code                8367 non-null   object
#  35  General inspection        12254 non-null  object
#  36  Last service              2003 non-null   object
#  37  Full service history      12565 non-null  object
#  38  Non-smoker vehicle        11594 non-null  object
#  39  Emission class            17859 non-null  object
#  40  Emissions sticker         9414 non-null   object
#  41  Upholstery colour         14569 non-null  object
#  42  Upholstery                18610 non-null  object
#  43  Production date           5908 non-null   float64
#  44  Previous owner            14015 non-null  object
#  45  Other fuel types          2313 non-null   object
#  46  Power consumption         515 non-null    object
#  47  Energy efficiency class   7804 non-null   object
#  48  CO₂-efficiency            7804 non-null   object
#  49  Fuel consumption (WLTP)   100 non-null    object
#  50  CO₂-emissions (WLTP)      116 non-null    object
#  51  Available from            393 non-null    object
#  52  Taxi or rental car        422 non-null    object
#  53  Availability              301 non-null    object
#  54  Last timing belt change   572 non-null    object
#  55  Electric Range (WLTP)     16 non-null     object
#  56  Power consumption (WLTP)  16 non-null     object
#  57  Battery Ownership         7 non-null      object
# dtypes: float64(1), object(57)
# memory usage: 13.0+ MB

# %%
df.head(5).T
# Out:
#                                                                            0  \
# make_model                                               Mercedes-Benz A 160
# short_description                                                        CDi
# make                                                       \nMercedes-Benz\n
# model                                                        [\n, A 160 ,\n]
# location                   P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...
# price                                                             € 16,950.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7468157, \n]
# Warranty                                                 [\n, 24 months, \n]
# Mileage                                                           120,200 km
# First registration                                                   06/2016
# Gearbox                                                         [\nManual\n]
# Fuel type                                                             Diesel
# Colour                                                                 Black
# Paint                                                               Metallic
# desc                       [ , Precio al contado: 16950 euros,  ,  , Vehí...
# seller                                                                Dealer
# Seats                                                                    NaN
# Power                                                                    NaN
# Engine size                                                              NaN
# Gears                                                                    NaN
# CO₂-emissions                                                            NaN
# Manufacturer colour                                                      NaN
# Drivetrain                                                               NaN
# Cylinders                                                                NaN
# Fuel consumption                                                         NaN
# \nComfort & Convenience\n                                                NaN
# \nEntertainment & Media\n                                                NaN
# \nSafety & Security\n                                                    NaN
# \nExtras\n                                                               NaN
# Empty weight                                                             NaN
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                            1  \
# make_model                                             Mercedes-Benz EQE 350
# short_description                                                       350+
# make                                                       \nMercedes-Benz\n
# model                                                      [\n, EQE 350 ,\n]
# location                        APARTADO DE CORREOS 1032,  26140 LOGROÑO, ES
# price                                                             € 80,900.-
# Body type                                                  [\n, Compact, \n]
# Type                                                [\n, Pre-registered, \n]
# Doors                                                            [\n, 4, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7054863, \n]
# Warranty                                                 [\n, 24 months, \n]
# Mileage                                                             5,000 km
# First registration                                                   06/2022
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                           Electric
# Colour                                                                   NaN
# Paint                                                                    NaN
# desc                       [ , Precio al contado: 88900 euros,  , AUTO OJ...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n215 kW (292 hp)\n]
# Engine size                                                       [\n1 cc\n]
# Gears                                                                [\n9\n]
# CO₂-emissions                                                 0 g/km (comb.)
# Manufacturer colour                                          Negro Obsidiana
# Drivetrain                                                               NaN
# Cylinders                                                                NaN
# Fuel consumption                                                         NaN
# \nComfort & Convenience\n                                                NaN
# \nEntertainment & Media\n                                                NaN
# \nSafety & Security\n                                                    NaN
# \nExtras\n                                                               NaN
# Empty weight                                                             NaN
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                            2  \
# make_model                                            Mercedes-Benz A 45 AMG
# short_description                                           S 4Matic+ 8G-DCT
# make                                                       \nMercedes-Benz\n
# model                                                     [\n, A 45 AMG ,\n]
# location                   PORT. TARRACO, MOLL DE LLEVANT, Nº 5, LOC. 6-8...
# price                                                             € 69,900.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7410454, \n]
# Warranty                                                 [\n, 12 months, \n]
# Mileage                                                            18,900 km
# First registration                                                   07/2020
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                           Gasoline
# Colour                                                                  Grey
# Paint                                                                    NaN
# desc                       [Gris MANUFAKTUR mountaingrau magno,  , Linea/...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n310 kW (421 hp)\n]
# Engine size                                                   [\n1,991 cc\n]
# Gears                                                                [\n8\n]
# CO₂-emissions                                                            NaN
# Manufacturer colour                                       Mountaingrau magno
# Drivetrain                                                     [\n, 4WD, \n]
# Cylinders                                                            [\n4\n]
# Fuel consumption           [[8.4 l/100 km (comb.)], [10.9 l/100 km (city)...
# \nComfort & Convenience\n                                                NaN
# \nEntertainment & Media\n                                                NaN
# \nSafety & Security\n                                                    NaN
# \nExtras\n                                                               NaN
# Empty weight                                                             NaN
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                            3  \
# make_model                                            Mercedes-Benz A 35 AMG
# short_description                                             4Matic+ 7G-DCT
# make                                                       \nMercedes-Benz\n
# model                                                     [\n, A 35 AMG ,\n]
# location                   Carrer de Provença, 31 Local,  8029 BARCELONA, ES
# price                                                             € 46,990.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7464503, \n]
# Warranty                                                 [\n, 12 months, \n]
# Mileage                                                            18,995 km
# First registration                                                   01/2020
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                           Gasoline
# Colour                                                                Yellow
# Paint                                                                    NaN
# desc                       [ , Precio al contado: 48990 euros,  ,  , BONI...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n225 kW (306 hp)\n]
# Engine size                                                   [\n1,991 cc\n]
# Gears                                                                [\n7\n]
# CO₂-emissions                                                            NaN
# Manufacturer colour                                             Amarillo Sol
# Drivetrain                                                     [\n, 4WD, \n]
# Cylinders                                                            [\n4\n]
# Fuel consumption           [[7.3 l/100 km (comb.)], [9.3 l/100 km (city)]...
# \nComfort & Convenience\n  [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n                                              [USB]
# \nSafety & Security\n      [ABS, Central door lock, Driver-side airbag, E...
# \nExtras\n                                                     [Sport seats]
# Empty weight                                                             NaN
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                            4
# make_model                                            Mercedes-Benz A 45 AMG
# short_description                                   200CDI BE Line 4M 7G-DCT
# make                                                       \nMercedes-Benz\n
# model                                                     [\n, A 45 AMG ,\n]
# location                              CARRIL ARAGONES 4,  30007 CASILLAS, ES
# price                                                             € 16,800.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7127931, \n]
# Warranty                                                 [\n, 12 months, \n]
# Mileage                                                           197,000 km
# First registration                                                   09/2015
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                             Diesel
# Colour                                                                 White
# Paint                                                               Metallic
# desc                       [ , Precio al contado: 17400 euros,  , Vehícul...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n100 kW (136 hp)\n]
# Engine size                                                   [\n2,143 cc\n]
# Gears                                                                [\n7\n]
# CO₂-emissions                                                            NaN
# Manufacturer colour                                                      NaN
# Drivetrain                                                     [\n, 4WD, \n]
# Cylinders                                                            [\n4\n]
# Fuel consumption           [[4.9 l/100 km (comb.)], [5.7 l/100 km (city)]...
# \nComfort & Convenience\n  [Air conditioning, Electrical side mirrors, Mu...
# \nEntertainment & Media\n                   [Bluetooth, CD player, MP3, USB]
# \nSafety & Security\n      [ABS, Central door lock, Driver-side airbag, E...
# \nExtras\n                                                               NaN
# Empty weight                                                  [\n1,545 kg\n]
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN

# %%
df.describe()
# Out:
#        Production date
# count          5908.00
# mean           2018.00
# std               6.49
# min            1954.00
# 25%            2018.00
# 50%            2019.00
# 75%            2021.00
# max            2022.00

# %%
#df.describe(include=[object])

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'make', 'model', 'location', 'price',
#        'Body type', 'Type', 'Doors', 'Country version', 'Offer number',
#        'Warranty', 'Mileage', 'First registration', 'Gearbox', 'Fuel type',
#        'Colour', 'Paint', 'desc', 'seller', 'Seats', 'Power', 'Engine size',
#        'Gears', 'CO₂-emissions', 'Manufacturer colour', 'Drivetrain',
#        'Cylinders', 'Fuel consumption', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nSafety & Security\n', '\nExtras\n',
#        'Empty weight', 'Model code', 'General inspection', 'Last service',
#        'Full service history', 'Non-smoker vehicle', 'Emission class',
#        'Emissions sticker', 'Upholstery colour', 'Upholstery',
#        'Production date', 'Previous owner', 'Other fuel types',
#        'Power consumption', 'Energy efficiency class', 'CO₂-efficiency',
#        'Fuel consumption (WLTP)', 'CO₂-emissions (WLTP)', 'Available from',
#        'Taxi or rental car', 'Availability', 'Last timing belt change',
#        'Electric Range (WLTP)', 'Power consumption (WLTP)',
#        'Battery Ownership'],
#       dtype='object')

# %%
for i in df.columns:
    df.rename(columns={i:i.lower().replace(' & ','_').replace(' ','_').replace('\n','').replace('-','_')},inplace = True)
    
df.head(3).T
# Out:
#                                                                           0  \
# make_model                                              Mercedes-Benz A 160
# short_description                                                       CDi
# make                                                      \nMercedes-Benz\n
# model                                                       [\n, A 160 ,\n]
# location                  P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...
# price                                                            € 16,950.-
# body_type                                                 [\n, Compact, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                             [\n, Spain, \n]
# offer_number                                              [\n, 7468157, \n]
# warranty                                                [\n, 24 months, \n]
# mileage                                                          120,200 km
# first_registration                                                  06/2016
# gearbox                                                        [\nManual\n]
# fuel_type                                                            Diesel
# colour                                                                Black
# paint                                                              Metallic
# desc                      [ , Precio al contado: 16950 euros,  ,  , Vehí...
# seller                                                               Dealer
# seats                                                                   NaN
# power                                                                   NaN
# engine_size                                                             NaN
# gears                                                                   NaN
# co₂_emissions                                                           NaN
# manufacturer_colour                                                     NaN
# drivetrain                                                              NaN
# cylinders                                                               NaN
# fuel_consumption                                                        NaN
# comfort_convenience                                                     NaN
# entertainment_media                                                     NaN
# safety_security                                                         NaN
# extras                                                                  NaN
# empty_weight                                                            NaN
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
#
#                                                                           1  \
# make_model                                            Mercedes-Benz EQE 350
# short_description                                                      350+
# make                                                      \nMercedes-Benz\n
# model                                                     [\n, EQE 350 ,\n]
# location                       APARTADO DE CORREOS 1032,  26140 LOGROÑO, ES
# price                                                            € 80,900.-
# body_type                                                 [\n, Compact, \n]
# type                                               [\n, Pre-registered, \n]
# doors                                                           [\n, 4, \n]
# country_version                                             [\n, Spain, \n]
# offer_number                                              [\n, 7054863, \n]
# warranty                                                [\n, 24 months, \n]
# mileage                                                            5,000 km
# first_registration                                                  06/2022
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                                          Electric
# colour                                                                  NaN
# paint                                                                   NaN
# desc                      [ , Precio al contado: 88900 euros,  , AUTO OJ...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                 [\n215 kW (292 hp)\n]
# engine_size                                                      [\n1 cc\n]
# gears                                                               [\n9\n]
# co₂_emissions                                                0 g/km (comb.)
# manufacturer_colour                                         Negro Obsidiana
# drivetrain                                                              NaN
# cylinders                                                               NaN
# fuel_consumption                                                        NaN
# comfort_convenience                                                     NaN
# entertainment_media                                                     NaN
# safety_security                                                         NaN
# extras                                                                  NaN
# empty_weight                                                            NaN
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
#
#                                                                           2
# make_model                                           Mercedes-Benz A 45 AMG
# short_description                                          S 4Matic+ 8G-DCT
# make                                                      \nMercedes-Benz\n
# model                                                    [\n, A 45 AMG ,\n]
# location                  PORT. TARRACO, MOLL DE LLEVANT, Nº 5, LOC. 6-8...
# price                                                            € 69,900.-
# body_type                                                 [\n, Compact, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                             [\n, Spain, \n]
# offer_number                                              [\n, 7410454, \n]
# warranty                                                [\n, 12 months, \n]
# mileage                                                           18,900 km
# first_registration                                                  07/2020
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                                          Gasoline
# colour                                                                 Grey
# paint                                                                   NaN
# desc                      [Gris MANUFAKTUR mountaingrau magno,  , Linea/...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                 [\n310 kW (421 hp)\n]
# engine_size                                                  [\n1,991 cc\n]
# gears                                                               [\n8\n]
# co₂_emissions                                                           NaN
# manufacturer_colour                                      Mountaingrau magno
# drivetrain                                                    [\n, 4WD, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption          [[8.4 l/100 km (comb.)], [10.9 l/100 km (city)...
# comfort_convenience                                                     NaN
# entertainment_media                                                     NaN
# safety_security                                                         NaN
# extras                                                                  NaN
# empty_weight                                                            NaN
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN

# %%
df.isnull().sum()
# Out:
# make_model                    850
# short_description             850
# make                          850
# model                         850
# location                      850
# price                         850
# Body type                     850
# Type                          850
# Doors                        1209
# Country version             12591
# Offer number                 6380
# Warranty                    13696
# Mileage                       851
# First registration            852
# Gearbox                      1098
# Fuel type                    2637
# Colour                       2574
# Paint                       14985
# desc                         1433
# seller                        850
# Seats                        3975
# Power                        1422
# Engine size                  2253
# Gears                       10526
# CO₂-emissions               10886
# Manufacturer colour          7693
# Drivetrain                  12587
# Cylinders                   10628
# Fuel consumption             6095
# Comfort&Convenience          4047
# Entertainment&Media          5836
# Safety&Security              4065
# Extras                       6000
# Empty weight                11722
# Model code                  21113
# General inspection          17226
# Last service                27477
# Full service history        16915
# Non-smoker vehicle          17886
# Emission class              11621
# Emissions sticker           20066
# Upholstery colour           14911
# Upholstery                  10870
# Production date             23572
# Previous owner              15465
# Other fuel types            27167
# Power consumption           28965
# Energy efficiency class     21676
# CO₂-efficiency              21676
# Fuel consumption (WLTP)     29380
# CO₂-emissions (WLTP)        29364
# Available from              29087
# Taxi or rental car          29058
# Availability                29179
# Last timing belt change     28908
# Electric Range (WLTP)       29464
# Power consumption (WLTP)    29464
# Battery Ownership           29473
# dtype: int64

# %%
is_null = pd.DataFrame(df.isnull().sum(), columns = ['isnull'])
is_null
# Out:
#                           isnull
# make_model                   850
# short_description            850
# make                         850
# model                        850
# location                     850
# price                        850
# Body type                    850
# Type                         850
# Doors                       1209
# Country version            12591
# Offer number                6380
# Warranty                   13696
# Mileage                      851
# First registration           852
# Gearbox                     1098
# Fuel type                   2637
# Colour                      2574
# Paint                      14985
# desc                        1433
# seller                       850
# Seats                       3975
# Power                       1422
# Engine size                 2253
# Gears                      10526
# CO₂-emissions              10886
# Manufacturer colour         7693
# Drivetrain                 12587
# Cylinders                  10628
# Fuel consumption            6095
# Comfort&Convenience         4047
# Entertainment&Media         5836
# Safety&Security             4065
# Extras                      6000
# Empty weight               11722
# Model code                 21113
# General inspection         17226
# Last service               27477
# Full service history       16915
# Non-smoker vehicle         17886
# Emission class             11621
# Emissions sticker          20066
# Upholstery colour          14911
# Upholstery                 10870
# Production date            23572
# Previous owner             15465
# Other fuel types           27167
# Power consumption          28965
# Energy efficiency class    21676
# CO₂-efficiency             21676
# Fuel consumption (WLTP)    29380
# CO₂-emissions (WLTP)       29364
# Available from             29087
# Taxi or rental car         29058
# Availability               29179
# Last timing belt change    28908
# Electric Range (WLTP)      29464
# Power consumption (WLTP)   29464
# Battery Ownership          29473

# %%
percentage_null = pd.DataFrame(df.isnull().sum()/df.shape[0]*100, columns = ['percentage_null'])
percentage_null
# Out:
#                           percentage_null
# make_model                           2.88
# short_description                    2.88
# make                                 2.88
# model                                2.88
# location                             2.88
# price                                2.88
# Body type                            2.88
# Type                                 2.88
# Doors                                4.10
# Country version                     42.71
# Offer number                        21.64
# Warranty                            46.46
# Mileage                              2.89
# First registration                   2.89
# Gearbox                              3.72
# Fuel type                            8.95
# Colour                               8.73
# Paint                               50.83
# desc                                 4.86
# seller                               2.88
# Seats                               13.48
# Power                                4.82
# Engine size                          7.64
# Gears                               35.71
# CO₂-emissions                       36.93
# Manufacturer colour                 26.10
# Drivetrain                          42.70
# Cylinders                           36.05
# Fuel consumption                    20.68
# Comfort&Convenience                 13.73
# Entertainment&Media                 19.80
# Safety&Security                     13.79
# Extras                              20.35
# Empty weight                        39.76
# Model code                          71.62
# General inspection                  58.43
# Last service                        93.21
# Full service history                57.38
# Non-smoker vehicle                  60.67
# Emission class                      39.42
# Emissions sticker                   68.07
# Upholstery colour                   50.58
# Upholstery                          36.87
# Production date                     79.96
# Previous owner                      52.46
# Other fuel types                    92.15
# Power consumption                   98.25
# Energy efficiency class             73.53
# CO₂-efficiency                      73.53
# Fuel consumption (WLTP)             99.66
# CO₂-emissions (WLTP)                99.61
# Available from                      98.67
# Taxi or rental car                  98.57
# Availability                        98.98
# Last timing belt change             98.06
# Electric Range (WLTP)               99.95
# Power consumption (WLTP)            99.95
# Battery Ownership                   99.98

# %%
summary_null = pd.concat([is_null, percentage_null], axis = 1).reset_index().rename({'index':'Columns'},axis = 1)
summary_null
# Out:
#                      Columns  isnull  percentage_null
# 0                 make_model     850             2.88
# 1          short_description     850             2.88
# 2                       make     850             2.88
# 3                      model     850             2.88
# 4                   location     850             2.88
# 5                      price     850             2.88
# 6                  Body type     850             2.88
# 7                       Type     850             2.88
# 8                      Doors    1209             4.10
# 9            Country version   12591            42.71
# 10              Offer number    6380            21.64
# 11                  Warranty   13696            46.46
# 12                   Mileage     851             2.89
# 13        First registration     852             2.89
# 14                   Gearbox    1098             3.72
# 15                 Fuel type    2637             8.95
# 16                    Colour    2574             8.73
# 17                     Paint   14985            50.83
# 18                      desc    1433             4.86
# 19                    seller     850             2.88
# 20                     Seats    3975            13.48
# 21                     Power    1422             4.82
# 22               Engine size    2253             7.64
# 23                     Gears   10526            35.71
# 24             CO₂-emissions   10886            36.93
# 25       Manufacturer colour    7693            26.10
# 26                Drivetrain   12587            42.70
# 27                 Cylinders   10628            36.05
# 28          Fuel consumption    6095            20.68
# 29       Comfort&Convenience    4047            13.73
# 30       Entertainment&Media    5836            19.80
# 31           Safety&Security    4065            13.79
# 32                    Extras    6000            20.35
# 33              Empty weight   11722            39.76
# 34                Model code   21113            71.62
# 35        General inspection   17226            58.43
# 36              Last service   27477            93.21
# 37      Full service history   16915            57.38
# 38        Non-smoker vehicle   17886            60.67
# 39            Emission class   11621            39.42
# 40         Emissions sticker   20066            68.07
# 41         Upholstery colour   14911            50.58
# 42                Upholstery   10870            36.87
# 43           Production date   23572            79.96
# 44            Previous owner   15465            52.46
# 45          Other fuel types   27167            92.15
# 46         Power consumption   28965            98.25
# 47   Energy efficiency class   21676            73.53
# 48            CO₂-efficiency   21676            73.53
# 49   Fuel consumption (WLTP)   29380            99.66
# 50      CO₂-emissions (WLTP)   29364            99.61
# 51            Available from   29087            98.67
# 52        Taxi or rental car   29058            98.57
# 53              Availability   29179            98.98
# 54   Last timing belt change   28908            98.06
# 55     Electric Range (WLTP)   29464            99.95
# 56  Power consumption (WLTP)   29464            99.95
# 57         Battery Ownership   29473            99.98

# %%
missing = df.isnull().sum()*100 / df.shape[0]

# %%
missing.loc[lambda x : x >= 70] #%70
# Out:
# Model code                 71.62
# Last service               93.21
# Production date            79.96
# Other fuel types           92.15
# Power consumption          98.25
# Energy efficiency class    73.53
# CO₂-efficiency             73.53
# Fuel consumption (WLTP)    99.66
# CO₂-emissions (WLTP)       99.61
# Available from             98.67
# Taxi or rental car         98.57
# Availability               98.98
# Last timing belt change    98.06
# Electric Range (WLTP)      99.95
# Power consumption (WLTP)   99.95
# Battery Ownership          99.98
# dtype: float64

# %% [markdown]
# # BUNDAN SONRASI HUSEYIN K.

# %%
df.columns[20:40]
# Out:
# Index(['seats', 'power', 'engine_size', 'gears', 'co₂_emissions',
#        'manufacturer_colour', 'drivetrain', 'cylinders', 'fuel_consumption',
#        'comfort_convenience', 'entertainment_media', 'safety_security',
#        'extras', 'empty_weight', 'model_code', 'general_inspection',
#        'last_service', 'full_service_history', 'non_smoker_vehicle',
#        'emission_class'],
#       dtype='object')

# %%
df['seats'].value_counts()
# Out:
# [\n, 5, \n]     18308
# [\n, 4, \n]      5390
# [\n, 2, \n]      1186
# [\n, 7, \n]       488
# [\n, 8, \n]        43
# [\n, 9, \n]        35
# [\n, 3, \n]        25
# [\n, 6, \n]        12
# [\n, 0, \n]         9
# [\n, 1, \n]         7
# [\n, 17, \n]        2
# Name: seats, dtype: int64

# %%
df['seats'] = df['seats'].apply(lambda t: int(str(t).split(',')[1].strip()) if pd.notnull(t) else t)
df['seats'].value_counts()
# Out:
# 5.00     18308
# 4.00      5390
# 2.00      1186
# 7.00       488
# 8.00        43
# 9.00        35
# 3.00        25
# 6.00        12
# 0.00         9
# 1.00         7
# 17.00        2
# Name: seats, dtype: int64

# %%
df['power'].value_counts()
# Out:
# [\n110 kW (150 hp)\n]      1992
# [\n96 kW (131 hp)\n]       1356
# [\n88 kW (120 hp)\n]       1182
# [\n81 kW (110 hp)\n]       1166
# [\n66 kW (90 hp)\n]        1110
#                            ...
# [\n746 kW (1,014 hp)\n]       1
# [\n570 kW (775 hp)\n]         1
# [\n471 kW (640 hp)\n]         1
# [\n179 kW (243 hp)\n]         1
# [\n26 kW (35 hp)\n]           1
# Name: Power, Length: 351, dtype: int64

# %%
df['power'] = df['power'].apply(lambda t: int(re.findall(r'\d+', str(t))[0]) if pd.notnull(t) else t)
df['power'].value_counts()
# Out:
# 110.00    1992
# 96.00     1356
# 88.00     1182
# 81.00     1166
# 66.00     1110
#           ...
# 746.00       1
# 570.00       1
# 471.00       1
# 179.00       1
# 26.00        1
# Name: Power, Length: 351, dtype: int64

# %%
df['engine_size'].value_counts()
# Out:
# [\n1,598 cc\n]    2099
# [\n999 cc\n]      2068
# [\n1,969 cc\n]    1929
# [\n1,461 cc\n]    1110
# [\n1,998 cc\n]    1000
#                   ...
# [\n2,753 cc\n]       1
# [\n2,495 cc\n]       1
# [\n200 cc\n]         1
# [\n3,224 cc\n]       1
# [\n2,473 cc\n]       1
# Name: Engine size, Length: 467, dtype: int64

# %%
df['engine_size']=df['engine_size'].apply(lambda t: t[0].replace(',','') if pd.notnull(t) else t)
df['engine_size'] = df['engine_size'].apply(lambda t: int(re.findall(r'\d+', str(t))[0]) if pd.notnull(t) else t)
df['engine_size'].value_counts()
# Out:
# 1598.00    2099
# 999.00     2068
# 1969.00    1929
# 1461.00    1110
# 1998.00    1000
#            ...
# 2753.00       1
# 2495.00       1
# 200.00        1
# 3224.00       1
# 2473.00       1
# Name: Engine size, Length: 467, dtype: int64

# %%
df['gears'].value_counts()
# Out:
# [\n6\n]     8412
# [\n5\n]     5335
# [\n7\n]     1738
# [\n8\n]     1690
# [\n1\n]      712
# [\n9\n]      642
# [\n4\n]      256
# [\n10\n]     112
# [\n0\n]       31
# [\n3\n]       24
# [\n2\n]        2
# Name: Gears, dtype: int64

# %%
df['gears'] = df['gears'].apply(lambda t: int(re.findall(r'\d+', str(t))[0]) if pd.notnull(t) else t)
df['gears'].value_counts()
# Out:
# 6.00     8412
# 5.00     5335
# 7.00     1738
# 8.00     1690
# 1.00      712
# 9.00      642
# 4.00      256
# 10.00     112
# 0.00       31
# 3.00       24
# 2.00        2
# Name: Gears, dtype: int64

# %%
df['co₂_emissions'].value_counts()
# Out:
# 0 g/km (comb.)       1038
# 119 g/km (comb.)      393
# 124 g/km (comb.)      340
# 129 g/km (comb.)      319
# 114 g/km (comb.)      313
#                      ...
# 7 g/km (comb.)          1
# 80 g/km (comb.)         1
# 196  g/km (comb.)       1
# 100  g/km (comb.)       1
# 53 g/km (comb.)         1
# Name: CO₂-emissions, Length: 347, dtype: int64

# %%
# The 'CO₂-emissions' column can be dropped later, because there are several other columns showing the similar feature, such as 'Emission class and 'Emisssions sticker'. .

df['co₂_emissions'] = df['co₂_emissions'].apply(lambda t: int(re.findall(r'\d+', str(t))[0]) if pd.notnull(t) else t)
df['co₂_emissions'].value_counts()
# Out:
# 0.00      1040
# 119.00     393
# 124.00     340
# 129.00     319
# 114.00     313
#           ...
# 272.00       1
# 344.00       1
# 342.00       1
# 398.00       1
# 53.00        1
# Name: CO₂-emissions, Length: 326, dtype: int64

# %%
# The 'Manufacrurer colour' column can be dropped later, because it has 4963 distinct values with description of colours by manufacturers in different languages. The 'Colour' column can be used instead. It has 14 distinct values already including almost all auto colours.

df['manufacturer_colour'].value_counts()
# Out:
# Blanco                            1235
# Gris                               671
# Azul                               552
# Negro                              546
# Rojo                               381
#                                   ...
# Colore esterno (snowflake whit       1
# Pompeigraumetallic                   1
# Cararragrau                          1
# ICE WHITE (wit metallic)             1
# Denim Blue metallic (blauw met       1
# Name: manufacturer_colour, Length: 4963, dtype: int64

# %%
df['drivetrain'].value_counts()
# Out:
# [\n, Front, \n]    12066
# [\n, 4WD, \n]       3252
# [\n, Rear, \n]      1575
# Name: Drivetrain, dtype: int64

# %%
df['drivetrain']=df['drivetrain'].apply(lambda t: str(t).split(',')[1].strip() if pd.notnull(t) else t)
df['drivetrain'].value_counts()
# Out:
# Front    12066
# 4WD       3252
# Rear      1575
# Name: Drivetrain, dtype: int64

# %%
df['cylinders'].value_counts()
# Out:
# [\n4\n]     13068
# [\n3\n]      3258
# [\n6\n]      1013
# [\n5\n]       799
# [\n8\n]       539
# [\n2\n]       103
# [\n0\n]        35
# [\n1\n]        21
# [\n12\n]        8
# [\n7\n]         6
# [\n26\n]        1
# [\n16\n]        1
# Name: Cylinders, dtype: int64

# %%
df['cylinders'] = df['cylinders'].apply(lambda t: int(re.findall(r'\d+', str(t))[0]) if pd.notnull(t) else t)
df['cylinders'].value_counts()
# Out:
# 4.00     13068
# 3.00      3258
# 6.00      1013
# 5.00       799
# 8.00       539
# 2.00       103
# 0.00        35
# 1.00        21
# 12.00        8
# 7.00         6
# 26.00        1
# 16.00        1
# Name: Cylinders, dtype: int64

# %%
df['fuel_consumption'].value_counts()
# Out:
# [[0 l/100 km (comb.)]]                                                         330
# [[0 l/100 km (comb.)], [0 l/100 km (city)], [0 l/100 km (country)]]            306
# [[3.4 l/100 km (comb.)], [3.7 l/100 km (city)], [3.2 l/100 km (country)]]      170
# [[4 l/100 km (comb.)]]                                                         149
# [[3.9 l/100 km (comb.)]]                                                       133
#                                                                               ...
# [[5.2 l/100 km (comb.)], [5.6 l/100 km (city)], [5 l/100 km (country)]]          1
# [[5 l/100 km (comb.)], [4.4 l/100 km (city)], [3.6 l/100 km (country)]]          1
# [[5.5 l/100 km (comb.)], [4.8 l/100 km (city)], [3.9 l/100 km (country)]]        1
# [[4.8 l/100 km (comb.)], [5.5 l/100 km (city)], [4.3 l/100 km (country)]]        1
# [[10.4 l/100 km (comb.)], [15.3 l/100 km (city)], [7.6 l/100 km (country)]]      1
# Name: fuel_consumption, Length: 3452, dtype: int64

# %%
df['fuel_consumption'] = df['fuel_consumption'].astype('str')
df['fuel_consumption'] = df['fuel_consumption'].str.extract('(\d+.\d+|\d+).+com', expand=True).astype(float)
df['fuel_consumption'].value_counts()
# Out:
# 5.00     831
# 4.90     811
# 4.50     690
# 5.10     647
# 0.00     645
#         ...
# 16.00      1
# 57.00      1
# 61.00      1
# 14.50      1
# 44.00      1
# Name: Fuel consumption, Length: 160, dtype: int64

# %%
#???
df['comfort_convenience'].value_counts()
# Out:
# [Air conditioning, Automatic climate control, Electrical side mirrors, Multi-function steering wheel, Power windows]                                                                                                                                          244
# [Air conditioning, Automatic climate control, Cruise control]                                                                                                                                                                                                 171
# [Air conditioning, Automatic climate control, Cruise control, Electrical side mirrors, Multi-function steering wheel, Power windows]                                                                                                                          168
# [Air conditioning]                                                                                                                                                                                                                                            157
# [Power windows]                                                                                                                                                                                                                                               150
#                                                                                                                                                                                                                                                              ...
# [Air conditioning, Automatic climate control, Multi-function steering wheel, Parking assist system sensors front, Parking assist system sensors rear, Split rear seats]                                                                                         1
# [Air conditioning, Electrical side mirrors, Leather steering wheel, Power windows, Seat heating, Tinted windows, Wind deflector]                                                                                                                                1
# [Air conditioning, Electrical side mirrors, Hill Holder, Power windows, Tinted windows]                                                                                                                                                                         1
# [Air conditioning, Automatic climate control, Electrical side mirrors, Leather steering wheel, Light sensor, Multi-function steering wheel, Parking assist system camera, Power windows, Rain sensor, Split rear seats, Start-stop system, Tinted windows]      1
# [Air conditioning, Armrest, Cruise control, Electrical side mirrors, Leather steering wheel, Lumbar support, Multi-function steering wheel, Navigation system, Power windows, Seat heating, Tinted windows]                                                     1
# Name: Comfort&Convenience, Length: 14438, dtype: int64

# %%
#???
df['entertainment_media'].value_counts()
# Out:
# [Bluetooth, USB]                                                                                                                                                             753
# [Bluetooth]                                                                                                                                                                  665
# [On-board computer]                                                                                                                                                          662
# [CD player, On-board computer, Radio]                                                                                                                                        644
# [Radio]                                                                                                                                                                      425
#                                                                                                                                                                             ...
# [Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, Sound system, WLAN / WiFi hotspot]      1
# [Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Sound system, USB, WLAN / WiFi hotspot]            1
# [Digital cockpit, Digital radio, On-board computer, Radio]                                                                                                                     1
# [Android Auto, Apple CarPlay, Digital radio, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot]                                                                 1
# [Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB]                                                                                              1
# Name: entertainment_media, Length: 1944, dtype: int64

# %%
df['entertainment_media'] = [", ".join(item) if type(item) == list else item for item in df["entertainment_media"]]
df['entertainment_media'].value_counts(dropna=False)
# Out:
# NaN                                                                                                                                                                        5836
# Bluetooth, USB                                                                                                                                                              753
# Bluetooth                                                                                                                                                                   665
# On-board computer                                                                                                                                                           662
# CD player, On-board computer, Radio                                                                                                                                         644
#                                                                                                                                                                            ...
# Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, Sound system, WLAN / WiFi hotspot       1
# Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Sound system, USB, WLAN / WiFi hotspot             1
# Digital cockpit, Digital radio, On-board computer, Radio                                                                                                                      1
# Android Auto, Apple CarPlay, Digital radio, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot                                                                  1
# Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB                                                                                               1
# Name: entertainment_media, Length: 1945, dtype: int64

# %%
df.sort_values('price', ascending=False)['comfort_convenience']
# Out:
# 7782     [Air conditioning, Armrest, Automatic climate ...
# 8936     [Air conditioning, Electrical side mirrors, Po...
# 20054                                            [Armrest]
# 24470    [Electrical side mirrors, Leather steering whe...
# 2658                             [Electrical side mirrors]
#                                ...
# 29419                                                  NaN
# 29445                                                  NaN
# 29451                                                  NaN
# 29473                                                  NaN
# 29479                                                  NaN
# Name: comfort_convenience, Length: 29480, dtype: object

# %%
df[df['comfort_convenience'].str.contains("cruise") == True]
# Out:
# Empty DataFrame
# Columns: [make_model, short_description, make, model, location, price, body_type, type, doors, country_version, offer_number, warranty, mileage, first_registration, gearbox, fuel_type, colour, paint, desc, seller, seats, power, engine_size, gears, co₂_emissions, manufacturer_colour, drivetrain, cylinders, fuel_consumption, comfort_convenience, entertainment_media, safety_security, extras, empty_weight, model_code, general_inspection, last_service, full_service_history, non_smoker_vehicle, emission_class, emissions_sticker, upholstery_colour, upholstery, production_date, previous_owner, other_fuel_types, power_consumption, energy_efficiency_class, co₂_efficiency, fuel_consumption_(wltp), co₂_emissions_(wltp), available_from, taxi_or_rental_car, availability, last_timing_belt_change, electric_range_(wltp), power_consumption_(wltp), battery_ownership, entertainment_media3]
# Index: []

# %%
df['comfort_convenience'].value_counts()
# Out:
# [Air conditioning, Automatic climate control, Electrical side mirrors, Multi-function steering wheel, Power windows]                                                                                                                                          244
# [Air conditioning, Automatic climate control, Cruise control]                                                                                                                                                                                                 171
# [Air conditioning, Automatic climate control, Cruise control, Electrical side mirrors, Multi-function steering wheel, Power windows]                                                                                                                          168
# [Air conditioning]                                                                                                                                                                                                                                            157
# [Power windows]                                                                                                                                                                                                                                               150
#                                                                                                                                                                                                                                                              ...
# [Air conditioning, Automatic climate control, Multi-function steering wheel, Parking assist system sensors front, Parking assist system sensors rear, Split rear seats]                                                                                         1
# [Air conditioning, Electrical side mirrors, Leather steering wheel, Power windows, Seat heating, Tinted windows, Wind deflector]                                                                                                                                1
# [Air conditioning, Electrical side mirrors, Hill Holder, Power windows, Tinted windows]                                                                                                                                                                         1
# [Air conditioning, Automatic climate control, Electrical side mirrors, Leather steering wheel, Light sensor, Multi-function steering wheel, Parking assist system camera, Power windows, Rain sensor, Split rear seats, Start-stop system, Tinted windows]      1
# [Air conditioning, Armrest, Cruise control, Electrical side mirrors, Leather steering wheel, Lumbar support, Multi-function steering wheel, Navigation system, Power windows, Seat heating, Tinted windows]                                                     1
# Name: comfort_convenience, Length: 14438, dtype: int64

# %%
high_comfort=['Automatic climate control', 'Parking assist system sensors rear', 'Rain sensor', 'Light sensor', 'Seat heating', 'Cruise control']

def comfort1(x):
    c=0
    for i in high_comfort:
        if i in x:
            c+=1
    return c

# %%
df['comfort_convenience1'] = df['comfort_convenience'].apply(lambda x: comfort1(x) if pd.notnull(x) else x)
df['comfort_convenience1'].value_counts(dropna=False)
# Out:
# 0.00    25298
# NaN      4047
# 1.00      135
# Name: comfort_convenience1, dtype: int64

# %%
premium_comfort = ['Navigation system', 'Parking assist system sensors front', 'Split rear seats', 'Multi-function steering wheel', 'Parking assist system camera']

def comfort2(x):
    c=0
    for i in premium_comfort:
        if i in x:
            c+=1
    return c

# %%
df['comfort_convenience2'] = df['comfort_convenience'].apply(lambda x: comfort2(x) if pd.notnull(x) else x)
df['comfort_convenience2'].value_counts(dropna=False)
# Out:
# NaN     5836
# 1.00    5411
# 3.00    4322
# 5.00    3338
# 2.00    3262
# 4.00    2533
# 6.00    2247
# 0.00    1508
# 7.00    1023
# Name: entertainment_media2, dtype: int64

# %%
df.loc[df['comfort_convenience1'] > 2, 'comfort_convenience'] = "high"

# %%
df.loc[df['comfort_convenience2'] > 2, 'comfort_convenience'] = "premium"

# %%
df['comfort_convenience'] = df['comfort_convenience'].apply(lambda x: "standard" if (pd.notnull(x)) & (x != "high") & (x != "premium") else x)

# %%
df['comfort_convenience'].value_counts(dropna=False)
# Out:
# premium     13463
# standard     8716
# NaN          5836
# high         1465
# Name: entertainment_media, dtype: int64

# %%
df.drop(labels=['comfort_convenience1', 'comfort_convenience2'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'make', 'model', 'location', 'price',
#        'body_type', 'type', 'doors', 'country_version', 'offer_number',
#        'warranty', 'mileage', 'first_registration', 'gearbox', 'fuel_type',
#        'colour', 'paint', 'desc', 'seller', 'seats', 'power', 'engine_size',
#        'gears', 'co₂_emissions', 'manufacturer_colour', 'drivetrain',
#        'cylinders', 'fuel_consumption', 'comfort_convenience',
#        'entertainment_media', 'safety_security', 'extras', 'empty_weight',
#        'model_code', 'general_inspection', 'last_service',
#        'full_service_history', 'non_smoker_vehicle', 'emission_class',
#        'emissions_sticker', 'upholstery_colour', 'upholstery',
#        'production_date', 'previous_owner', 'other_fuel_types',
#        'power_consumption', 'energy_efficiency_class', 'co₂_efficiency',
#        'fuel_consumption_(wltp)', 'co₂_emissions_(wltp)', 'available_from',
#        'taxi_or_rental_car', 'availability', 'last_timing_belt_change',
#        'electric_range_(wltp)', 'power_consumption_(wltp)',
#        'battery_ownership', 'entertainment_media3'],
#       dtype='object')

# %%
df['entertainment_media'].value_counts(dropna=False)
# Out:
# high        11373
# standard    10692
# NaN          5836
# premium      1579
# Name: entertainment_media, dtype: int64

# %%
df['entertainment_media'].value_counts(dropna=False)
# Out:
# NaN                                                                                                                                                                        5836
# Bluetooth, USB                                                                                                                                                              753
# Bluetooth                                                                                                                                                                   665
# On-board computer                                                                                                                                                           662
# CD player, On-board computer, Radio                                                                                                                                         644
#                                                                                                                                                                            ...
# Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, Sound system, WLAN / WiFi hotspot       1
# Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Sound system, USB, WLAN / WiFi hotspot             1
# Digital cockpit, Digital radio, On-board computer, Radio                                                                                                                      1
# Android Auto, Apple CarPlay, Digital radio, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot                                                                  1
# Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB                                                                                               1
# Name: entertainment_media, Length: 1945, dtype: int64

# %%
df.head(20).T
# Out:
#                                                                          0   \
# make_model                                              Mercedes-Benz A 160
# short_description                                                       CDi
# make                                                      \nMercedes-Benz\n
# model                                                       [\n, A 160 ,\n]
# location                  P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...
# price                                                            € 16,950.-
# body_type                                                 [\n, Compact, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                             [\n, Spain, \n]
# offer_number                                              [\n, 7468157, \n]
# warranty                                                [\n, 24 months, \n]
# mileage                                                          120,200 km
# first_registration                                                  06/2016
# gearbox                                                        [\nManual\n]
# fuel_type                                                            Diesel
# colour                                                                Black
# paint                                                              Metallic
# desc                      [ , Precio al contado: 16950 euros,  ,  , Vehí...
# seller                                                               Dealer
# seats                                                                   NaN
# power                                                                   NaN
# engine_size                                                             NaN
# gears                                                                   NaN
# co₂_emissions                                                           NaN
# manufacturer_colour                                                     NaN
# drivetrain                                                              NaN
# cylinders                                                               NaN
# fuel_consumption                                                        NaN
# comfort_convenience                                                     NaN
# entertainment_media                                                     NaN
# safety_security                                                         NaN
# extras                                                                  NaN
# empty_weight                                                            NaN
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                    NaN
# entertainment_media1                                                    NaN
#
#                                                                          1   \
# make_model                                            Mercedes-Benz EQE 350
# short_description                                                      350+
# make                                                      \nMercedes-Benz\n
# model                                                     [\n, EQE 350 ,\n]
# location                       APARTADO DE CORREOS 1032,  26140 LOGROÑO, ES
# price                                                            € 80,900.-
# body_type                                                 [\n, Compact, \n]
# type                                               [\n, Pre-registered, \n]
# doors                                                           [\n, 4, \n]
# country_version                                             [\n, Spain, \n]
# offer_number                                              [\n, 7054863, \n]
# warranty                                                [\n, 24 months, \n]
# mileage                                                            5,000 km
# first_registration                                                  06/2022
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                                          Electric
# colour                                                                  NaN
# paint                                                                   NaN
# desc                      [ , Precio al contado: 88900 euros,  , AUTO OJ...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                 [\n215 kW (292 hp)\n]
# engine_size                                                      [\n1 cc\n]
# gears                                                               [\n9\n]
# co₂_emissions                                                0 g/km (comb.)
# manufacturer_colour                                         Negro Obsidiana
# drivetrain                                                              NaN
# cylinders                                                               NaN
# fuel_consumption                                                        NaN
# comfort_convenience                                                     NaN
# entertainment_media                                                     NaN
# safety_security                                                         NaN
# extras                                                                  NaN
# empty_weight                                                            NaN
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                    NaN
# entertainment_media1                                                    NaN
#
#                                                                          2   \
# make_model                                           Mercedes-Benz A 45 AMG
# short_description                                          S 4Matic+ 8G-DCT
# make                                                      \nMercedes-Benz\n
# model                                                    [\n, A 45 AMG ,\n]
# location                  PORT. TARRACO, MOLL DE LLEVANT, Nº 5, LOC. 6-8...
# price                                                            € 69,900.-
# body_type                                                 [\n, Compact, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                             [\n, Spain, \n]
# offer_number                                              [\n, 7410454, \n]
# warranty                                                [\n, 12 months, \n]
# mileage                                                           18,900 km
# first_registration                                                  07/2020
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                                          Gasoline
# colour                                                                 Grey
# paint                                                                   NaN
# desc                      [Gris MANUFAKTUR mountaingrau magno,  , Linea/...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                 [\n310 kW (421 hp)\n]
# engine_size                                                  [\n1,991 cc\n]
# gears                                                               [\n8\n]
# co₂_emissions                                                           NaN
# manufacturer_colour                                      Mountaingrau magno
# drivetrain                                                    [\n, 4WD, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption          [[8.4 l/100 km (comb.)], [10.9 l/100 km (city)...
# comfort_convenience                                                     NaN
# entertainment_media                                                     NaN
# safety_security                                                         NaN
# extras                                                                  NaN
# empty_weight                                                            NaN
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                    NaN
# entertainment_media1                                                    NaN
#
#                                                                          3   \
# make_model                                           Mercedes-Benz A 35 AMG
# short_description                                            4Matic+ 7G-DCT
# make                                                      \nMercedes-Benz\n
# model                                                    [\n, A 35 AMG ,\n]
# location                  Carrer de Provença, 31 Local,  8029 BARCELONA, ES
# price                                                            € 46,990.-
# body_type                                                 [\n, Compact, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                             [\n, Spain, \n]
# offer_number                                              [\n, 7464503, \n]
# warranty                                                [\n, 12 months, \n]
# mileage                                                           18,995 km
# first_registration                                                  01/2020
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                                          Gasoline
# colour                                                               Yellow
# paint                                                                   NaN
# desc                      [ , Precio al contado: 48990 euros,  ,  , BONI...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                 [\n225 kW (306 hp)\n]
# engine_size                                                  [\n1,991 cc\n]
# gears                                                               [\n7\n]
# co₂_emissions                                                           NaN
# manufacturer_colour                                            Amarillo Sol
# drivetrain                                                    [\n, 4WD, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption          [[7.3 l/100 km (comb.)], [9.3 l/100 km (city)]...
# comfort_convenience       [Air conditioning, Automatic climate control, ...
# entertainment_media                                                     USB
# safety_security           [ABS, Central door lock, Driver-side airbag, E...
# extras                                                        [Sport seats]
# empty_weight                                                            NaN
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                   0.00
# entertainment_media1                                                   1.00
#
#                                                                          4   \
# make_model                                           Mercedes-Benz A 45 AMG
# short_description                                  200CDI BE Line 4M 7G-DCT
# make                                                      \nMercedes-Benz\n
# model                                                    [\n, A 45 AMG ,\n]
# location                             CARRIL ARAGONES 4,  30007 CASILLAS, ES
# price                                                            € 16,800.-
# body_type                                                 [\n, Compact, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                             [\n, Spain, \n]
# offer_number                                              [\n, 7127931, \n]
# warranty                                                [\n, 12 months, \n]
# mileage                                                          197,000 km
# first_registration                                                  09/2015
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                                            Diesel
# colour                                                                White
# paint                                                              Metallic
# desc                      [ , Precio al contado: 17400 euros,  , Vehícul...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                 [\n100 kW (136 hp)\n]
# engine_size                                                  [\n2,143 cc\n]
# gears                                                               [\n7\n]
# co₂_emissions                                                           NaN
# manufacturer_colour                                                     NaN
# drivetrain                                                    [\n, 4WD, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption          [[4.9 l/100 km (comb.)], [5.7 l/100 km (city)]...
# comfort_convenience       [Air conditioning, Electrical side mirrors, Mu...
# entertainment_media                          Bluetooth, CD player, MP3, USB
# safety_security           [ABS, Central door lock, Driver-side airbag, E...
# extras                                                                  NaN
# empty_weight                                                 [\n1,545 kg\n]
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                   1.00
# entertainment_media1                                                   2.00
#
#                                                                          5   \
# make_model                                              Mercedes-Benz C 160
# short_description           Sp. Ed. C-Klasse Sportcoupe!TÜV N.!24 Mon. Gew.
# make                                                      \nMercedes-Benz\n
# model                                                       [\n, C 160 ,\n]
# location                              Beethovenstr. 89,  42655 Solingen, DE
# price                                                             € 4,690.-
# body_type                                                 [\n, Compact, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 3, \n]
# country_version                                           [\n, Germany, \n]
# offer_number                                                            NaN
# warranty                                                                NaN
# mileage                                                          165,000 km
# first_registration                                                  08/2005
# gearbox                                                        [\nManual\n]
# fuel_type                                                          Gasoline
# colour                                                                Black
# paint                                                              Metallic
# desc                      [Sonderausstattung:, Panorama-Schiebedach elek...
# seller                                                               Dealer
# seats                                                           [\n, 4, \n]
# power                                                  [\n90 kW (122 hp)\n]
# engine_size                                                  [\n1,799 cc\n]
# gears                                                               [\n6\n]
# co₂_emissions                                              196 g/km (comb.)
# manufacturer_colour                               Diamant schwarz  metallic
# drivetrain                                                   [\n, Rear, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption          [[8.2 l/100 km (comb.)], [11.6 l/100 km (city)...
# comfort_convenience       [Air conditioning, Armrest, Automatic climate ...
# entertainment_media                     CD player, On-board computer, Radio
# safety_security           [ABS, Bi-Xenon headlights, Central door lock, ...
# extras                    [Alloy wheels (17"), Catalytic Converter, Emer...
# empty_weight                                                 [\n1,465 kg\n]
# model_code                                               [\n, 0999/338, \n]
# general_inspection                                                      New
# last_service                                                        07/2022
# full_service_history                                                    Yes
# non_smoker_vehicle                                                      Yes
# emission_class                                                       Euro 4
# emissions_sticker                                                 4 (Green)
# upholstery_colour                                                     Black
# upholstery                                                            Cloth
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                   1.00
# entertainment_media1                                                   1.00
#
#                                                                          6   \
# make_model                                            Mercedes-Benz CLA 180
# short_description                                                      180D
# make                                                      \nMercedes-Benz\n
# model                                                     [\n, CLA 180 ,\n]
# location                    CR PATERNA-LA CAÑADA, KM. 2,  46980 PATERNA, ES
# price                                                            € 22,550.-
# body_type                                                 [\n, Compact, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                             [\n, Spain, \n]
# offer_number                                              [\n, 7201260, \n]
# warranty                                                [\n, 12 months, \n]
# mileage                                                           83,339 km
# first_registration                                                  07/2018
# gearbox                                                        [\nManual\n]
# fuel_type                                                            Diesel
# colour                                                               Silver
# paint                                                                   NaN
# desc                      [ , Precio al contado: 24900 euros,  , LIQUIDA...
# seller                                                               Dealer
# seats                                                                   NaN
# power                                                                   NaN
# engine_size                                                             NaN
# gears                                                                   NaN
# co₂_emissions                                                           NaN
# manufacturer_colour                                                     NaN
# drivetrain                                                              NaN
# cylinders                                                               NaN
# fuel_consumption                                                        NaN
# comfort_convenience                                                     NaN
# entertainment_media                                                     NaN
# safety_security                                                         NaN
# extras                                                                  NaN
# empty_weight                                                            NaN
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                    NaN
# entertainment_media1                                                    NaN
#
#                                                                          7   \
# make_model                                              Mercedes-Benz A 220
# short_description                                                    7G-DCT
# make                                                      \nMercedes-Benz\n
# model                                                       [\n, A 220 ,\n]
# location                       CTRA DE MADRID KM 315,7,  50012 ZARAGOZA, ES
# price                                                            € 26,900.-
# body_type                                                 [\n, Compact, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                             [\n, Spain, \n]
# offer_number                                              [\n, 7329555, \n]
# warranty                                                [\n, 24 months, \n]
# mileage                                                           48,900 km
# first_registration                                                  10/2019
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                                          Gasoline
# colour                                                                 Grey
# paint                                                              Metallic
# desc                      [ , Precio al contado: 28900 euros,  , OPORTUN...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                 [\n140 kW (190 hp)\n]
# engine_size                                                  [\n1,991 cc\n]
# gears                                                               [\n7\n]
# co₂_emissions                                                           NaN
# manufacturer_colour                                            Gris Montaña
# drivetrain                                                  [\n, Front, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption          [[6.1 l/100 km (comb.)], [8.1 l/100 km (city)]...
# comfort_convenience       [Air conditioning, Automatic climate control, ...
# entertainment_media                                                     USB
# safety_security           [ABS, Central door lock, Driver-side airbag, E...
# extras                                                                  NaN
# empty_weight                                                 [\n1,450 kg\n]
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                   0.00
# entertainment_media1                                                   1.00
#
#                                                                          8   \
# make_model                                           Mercedes-Benz A 35 AMG
# short_description                                                    4MATIC
# make                                                      \nMercedes-Benz\n
# model                                                    [\n, A 35 AMG ,\n]
# location                                Voogdijstraat 25,  3500 Hasselt, BE
# price                                                            € 44,999.-
# body_type                                                 [\n, Compact, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                                         NaN
# offer_number                                              [\n, j107114, \n]
# warranty                                                                NaN
# mileage                                                           56,876 km
# first_registration                                                  06/2019
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                                Regular/Benzine 91
# colour                                                                 Grey
# paint                                                                   NaN
# desc                      [440 - Snelheidsregelaar TEMPOMAT met variabel...
# seller                                                               Dealer
# seats                                                                   NaN
# power                                                 [\n225 kW (306 hp)\n]
# engine_size                                                  [\n1,991 cc\n]
# gears                                                                   NaN
# co₂_emissions                                              168 g/km (comb.)
# manufacturer_colour                                                     NaN
# drivetrain                                                              NaN
# cylinders                                                               NaN
# fuel_consumption                                     [[0 l/100 km (comb.)]]
# comfort_convenience       [Multi-function steering wheel, Navigation sys...
# entertainment_media                                                     NaN
# safety_security                                 [Emergency brake assistant]
# extras                                                      [Sport package]
# empty_weight                                                            NaN
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                       Euro 6
# emissions_sticker                                                       NaN
# upholstery_colour                                                     Black
# upholstery                                                     Full leather
# production_date                                                     2019.00
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                    NaN
# entertainment_media1                                                    NaN
#
#                                                                          9   \
# make_model                                              Mercedes-Benz A 200
# short_description                                         200CDI Autotronic
# make                                                      \nMercedes-Benz\n
# model                                                       [\n, A 200 ,\n]
# location                            AUTOVÍA AS-2, Nº 1529,  33392 GIJON, ES
# price                                                            € 23,900.-
# body_type                                                 [\n, Compact, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                             [\n, Spain, \n]
# offer_number                                              [\n, 7454322, \n]
# warranty                                                [\n, 12 months, \n]
# mileage                                                           21,854 km
# first_registration                                                  08/2018
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                                            Diesel
# colour                                                                White
# paint                                                                   NaN
# desc                      [ , Precio al contado: 25900 euros,  ,  , Extr...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                 [\n102 kW (139 hp)\n]
# engine_size                                                  [\n1,991 cc\n]
# gears                                                               [\n1\n]
# co₂_emissions                                                           NaN
# manufacturer_colour                                   Blanco Cirro (sólido)
# drivetrain                                                  [\n, Front, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption          [[5.4 l/100 km (comb.)], [6.9 l/100 km (city)]...
# comfort_convenience       [Air conditioning, Automatic climate control, ...
# entertainment_media                                                     NaN
# safety_security           [ABS, Central door lock, Driver-side airbag, E...
# extras                                                       [Alloy wheels]
# empty_weight                                                 [\n1,365 kg\n]
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# ...
# emissions_sticker                                                       NaN
# upholstery_colour                                                     Black
# upholstery                                                              NaN
# production_date                                                     2021.00
# previous_owner                                                          NaN
# other_fuel_types                                                Electricity
# power_consumption                                      0 kWh/100 km (comb.)
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                    NaN
# entertainment_media1                                                    NaN
#
#                                                                          17  \
# make_model                                           Mercedes-Benz A 35 AMG
# short_description                                            4Matic+ 7G-DCT
# make                                                      \nMercedes-Benz\n
# model                                                    [\n, A 35 AMG ,\n]
# location                    Avenida Principe Felipe 160A,  23600 MARTOS, ES
# price                                                            € 41,900.-
# body_type                                                 [\n, Compact, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                             [\n, Spain, \n]
# offer_number                                              [\n, 7436715, \n]
# warranty                                                [\n, 12 months, \n]
# mileage                                                           44,000 km
# first_registration                                                  06/2019
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                                          Gasoline
# colour                                                                Black
# paint                                                              Metallic
# desc                      [ , Precio al contado: 43900 euros,  , PRECIO ...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                 [\n225 kW (306 hp)\n]
# engine_size                                                  [\n1,991 cc\n]
# gears                                                               [\n7\n]
# co₂_emissions                                                           NaN
# manufacturer_colour                                                     NaN
# drivetrain                                                    [\n, 4WD, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption          [[7.3 l/100 km (comb.)], [9.3 l/100 km (city)]...
# comfort_convenience       [Air conditioning, Automatic climate control, ...
# entertainment_media                                                     USB
# safety_security           [ABS, Central door lock, Driver-side airbag, E...
# extras                                                        [Sport seats]
# empty_weight                                                            NaN
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                   0.00
# entertainment_media1                                                   1.00
#
#                                                                          18  \
# make_model                                              Mercedes-Benz A 180
# short_description                                               180d 7G-DCT
# make                                                      \nMercedes-Benz\n
# model                                                       [\n, A 180 ,\n]
# location                                 Calle Carbón 19,  29603 MALAGA, ES
# price                                                            € 29,800.-
# body_type                                                 [\n, Compact, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                             [\n, Spain, \n]
# offer_number                                              [\n, 7452684, \n]
# warranty                                                [\n, 12 months, \n]
# mileage                                                           21,734 km
# first_registration                                                  01/2020
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                                            Diesel
# colour                                                                 Grey
# paint                                                              Metallic
# desc                      [ , Precio al contado: 32800 euros,  , EQUIPAM...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                  [\n85 kW (116 hp)\n]
# engine_size                                                  [\n1,461 cc\n]
# gears                                                               [\n7\n]
# co₂_emissions                                                           NaN
# manufacturer_colour                                                     NaN
# drivetrain                                                  [\n, Front, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption          [[3.9 l/100 km (comb.)], [4.7 l/100 km (city)]...
# comfort_convenience       [Air conditioning, Automatic climate control, ...
# entertainment_media                                                     USB
# safety_security           [ABS, Central door lock, Driver-side airbag, E...
# extras                                                                  NaN
# empty_weight                                                 [\n1,445 kg\n]
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                   0.00
# entertainment_media1                                                   1.00
#
#                                                                          19
# make_model                                           Mercedes-Benz A 45 AMG
# short_description                                             4Matic 7G-DCT
# make                                                      \nMercedes-Benz\n
# model                                                    [\n, A 45 AMG ,\n]
# location                  C/ FIDIAS 25, PARQUE EMPRESARIAL SANTA BARBARA...
# price                                                            € 37,490.-
# body_type                                                 [\n, Compact, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                             [\n, Spain, \n]
# offer_number                                              [\n, 7391621, \n]
# warranty                                                [\n, 12 months, \n]
# mileage                                                           81,500 km
# first_registration                                                  06/2016
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                                          Gasoline
# colour                                                                  Red
# paint                                                                   NaN
# desc                      [ , Precio al contado: 38990 euros,  , Mercede...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                 [\n280 kW (381 hp)\n]
# engine_size                                                  [\n1,991 cc\n]
# gears                                                               [\n7\n]
# co₂_emissions                                                           NaN
# manufacturer_colour                                                    Rojo
# drivetrain                                                    [\n, 4WD, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption          [[6.9 l/100 km (comb.)], [9.2 l/100 km (city)]...
# comfort_convenience       [Air conditioning, Electrical side mirrors, Po...
# entertainment_media                                                     NaN
# safety_security           [ABS, Central door lock, Driver-side airbag, I...
# extras                                          [Alloy wheels, Sport seats]
# empty_weight                                                 [\n1,555 kg\n]
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                    NaN
# entertainment_media1                                                    NaN

# %%
df[df['entertainment_media2'] > 3 ] = "premium"

# %%
df.sample(20).T
# Out:
#                                                                       12611  \
# make_model                                                       SEAT Ateca
# short_description                Style 1.5 TSI Navi Klimau. LED beats Audio
# make                                                               \nSEAT\n
# model                                                       [\n, Ateca ,\n]
# location                                  Europaplatz 10,  52068 Aachen, DE
# price                                                            € 22,990.-
# body_type                                        [\n, Off-Road/Pick-up, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                                         NaN
# offer_number                                               [\n, G35461, \n]
# warranty                                                                NaN
# mileage                                                           36,500 km
# first_registration                                                  01/2019
# gearbox                                                        [\nManual\n]
# fuel_type                                                          Super 95
# colour                                                                 Grey
# paint                                                              Metallic
# desc                      [Getriebe, Schaltgetriebe, Technik, Bordcomput...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                 [\n110 kW (150 hp)\n]
# engine_size                                                  [\n1,498 cc\n]
# gears                                                               [\n6\n]
# co₂_emissions                                              126 g/km (comb.)
# manufacturer_colour                                             Rodium grau
# drivetrain                                                  [\n, Front, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption          [[5.5 l/100 km (comb.)], [6.4 l/100 km (city)]...
# comfort_convenience       [Air conditioning, Armrest, Automatic climate ...
# entertainment_media       Android Auto, Apple CarPlay, Bluetooth, CD pla...
# safety_security           [ABS, Central door lock, Daytime running light...
# extras                    [Alloy wheels, Catalytic Converter, Roof rack,...
# empty_weight                                                 [\n1,355 kg\n]
# model_code                                               [\n, 7593/AOB, \n]
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      Yes
# emission_class                                                       Euro 6
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                            Cloth
# production_date                                                     2019.00
# previous_owner                                    [[36,500 km, 01/2019], 1]
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                   B
# co₂_efficiency            Calculated on basis of measured CO₂-emissions ...
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                   6.00
#
#                                                                       21613  \
# make_model                                                      Ford Fiesta
# short_description                              1.0 EcoBoost S/S ST Line 140
# make                                                               \nFord\n
# model                                                      [\n, Fiesta ,\n]
# location                           AVDA SANT JAUME, S/N,  43870 AMPOSTA, ES
# price                                                            € 17,500.-
# body_type                                                 [\n, Compact, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                             [\n, Spain, \n]
# offer_number                                              [\n, 7352882, \n]
# warranty                                                [\n, 60 months, \n]
# mileage                                                           11,000 km
# first_registration                                                  07/2020
# gearbox                                                        [\nManual\n]
# fuel_type                                                          Gasoline
# colour                                                                 Blue
# paint                                                              Metallic
# desc                      [ , Precio al contado: 19500 euros,  , VEHICUL...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                 [\n103 kW (140 hp)\n]
# engine_size                                                    [\n998 cc\n]
# gears                                                               [\n6\n]
# co₂_emissions                                                           NaN
# manufacturer_colour                                             AZUL CHROME
# drivetrain                                                  [\n, Front, \n]
# cylinders                                                           [\n3\n]
# fuel_consumption          [[4.5 l/100 km (comb.)], [5.8 l/100 km (city)]...
# comfort_convenience       [Air conditioning, Automatic climate control, ...
# entertainment_media                                                     USB
# safety_security           [ABS, Central door lock, Driver-side airbag, E...
# extras                                     [Alloy wheels, Sport suspension]
# empty_weight                                                 [\n1,101 kg\n]
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                   0.00
#
#                                                                       4273   \
# make_model                                                    Opel Insignia
# short_description          SW 2.0 CDTi 170 CV Aut. 8 Innovation In Garanzia
# make                                                               \nOpel\n
# model                                                    [\n, Insignia ,\n]
# location                  Via Santa Maria 64/A,  87046 Montalto Uffugo -...
# price                                                            € 17,400.-
# body_type                                           [\n, Station wagon, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                             [\n, Italy, \n]
# offer_number                                                            NaN
# warranty                                                [\n, 12 months, \n]
# mileage                                                           53,534 km
# first_registration                                                  07/2018
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                          Diesel (Particle filter)
# colour                                                                 Grey
# paint                                                              Metallic
# desc                      [Spedizione in tutta Italia 250 euro, Sardegna...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                 [\n125 kW (170 hp)\n]
# engine_size                                                  [\n1,956 cc\n]
# gears                                                               [\n8\n]
# co₂_emissions                                              150 g/km (comb.)
# manufacturer_colour                                                     NaN
# drivetrain                                                  [\n, Front, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption          [[5.7 l/100 km (comb.)], [7.5 l/100 km (city)]...
# comfort_convenience       [Air conditioning, Armrest, Automatic climate ...
# entertainment_media       Bluetooth, CD player, Digital cockpit, Digital...
# safety_security           [ABS, Adaptive Cruise Control, Alarm system, C...
# extras                    [All season tyres, Alloy wheels, Ambient light...
# empty_weight                                                            NaN
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    Yes
# non_smoker_vehicle                                                      Yes
# emission_class                                                      Euro 6c
# emissions_sticker                                                       NaN
# upholstery_colour                                                     Black
# upholstery                                                     Part leather
# production_date                                                         NaN
# previous_owner                                    [[53,534 km, 07/2018], 1]
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                   5.00
#
#                                                                       3650   \
# make_model                                                 Opel Grandland X
# short_description          Plug-in-Hybrid4 1.6 DI Start/Stop Aut INNOVATION
# make                                                               \nOpel\n
# model                                                 [\n, Grandland X ,\n]
# location                          Stubbendorfer Ring 2,  23858 Reinfeld, DE
# price                                                            € 31,950.-
# body_type                                        [\n, Off-Road/Pick-up, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                           [\n, Germany, \n]
# offer_number                                                 [\n, 2878, \n]
# warranty                                                                NaN
# mileage                                                           27,800 km
# first_registration                                                  01/2020
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                        Super 95 (Particle filter)
# colour                                                                White
# paint                                                              Metallic
# desc                      [12-V-Ausstattung, 2 Zündschlüssel, klappba, A...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                 [\n221 kW (300 hp)\n]
# engine_size                                                  [\n1,598 cc\n]
# gears                                                               [\n8\n]
# co₂_emissions                                               34 g/km (comb.)
# manufacturer_colour                                         Jade Weiß (Uni)
# drivetrain                                                    [\n, 4WD, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption                                   [[1.5 l/100 km (comb.)]]
# comfort_convenience       [Air conditioning, Armrest, Automatic climate ...
# entertainment_media       Android Auto, Apple CarPlay, Bluetooth, Hands-...
# safety_security           [ABS, Adaptive headlights, Blind spot monitor,...
# extras                    [Alloy wheels (19"), Automatically dimming int...
# empty_weight                                                 [\n1,875 kg\n]
# model_code                                               [\n, 1844/AKO, \n]
# general_inspection                                                      New
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                      Euro 6d
# emissions_sticker                                                 4 (Green)
# upholstery_colour                                                     Black
# upholstery                                                            Cloth
# production_date                                                         NaN
# previous_owner                                    [[27,800 km, 01/2020], 2]
# other_fuel_types                                                Electricity
# power_consumption                                   16.9 kWh/100 km (comb.)
# energy_efficiency_class                                                  A+
# co₂_efficiency            Calculated on basis of measured CO₂-emissions ...
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                   6.00
#
#                                                                       29240  \
# make_model                                          Volvo V40 Cross Country
# short_description                             D2 Euro 6 D Temp AHK-abnehmb.
# make                                                              \nVolvo\n
# model                                           [\n, V40 Cross Country ,\n]
# location                             Unterer Talweg 48,  86179 Augsburg, DE
# price                                                            € 21,880.-
# body_type                                                   [\n, Sedan, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                           [\n, Germany, \n]
# offer_number                                                  [\n, 229, \n]
# warranty                                                [\n, 12 months, \n]
# mileage                                                           13,000 km
# first_registration                                                  10/2018
# gearbox                                                        [\nManual\n]
# fuel_type                                          Diesel (Particle filter)
# colour                                                                 Grey
# paint                                                              Metallic
# desc                      [Highlights: , Scheckheftgepflegt; Herstellere...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                  [\n88 kW (120 hp)\n]
# engine_size                                                  [\n1,969 cc\n]
# gears                                                               [\n6\n]
# co₂_emissions                                                0 g/km (comb.)
# manufacturer_colour                                    OSMIUM GREY METALLIC
# drivetrain                                                  [\n, Front, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption          [[0 l/100 km (comb.)], [0 l/100 km (city)], [0...
# comfort_convenience       [Armrest, Automatic climate control, 2 zones, ...
# entertainment_media       Bluetooth, CD player, Hands-free equipment, MP...
# safety_security           [ABS, Central door lock, Central door lock wit...
# extras                    [Alloy wheels, Automatically dimming interior ...
# empty_weight                                                            NaN
# model_code                                               [\n, 9101/BBH, \n]
# general_inspection                                                  10/2020
# last_service                                                            NaN
# full_service_history                                                    Yes
# non_smoker_vehicle                                                      NaN
# emission_class                                                 Euro 6d-TEMP
# emissions_sticker                                                 4 (Green)
# upholstery_colour                                                     Black
# upholstery                                                            Cloth
# production_date                                                         NaN
# previous_owner                                    [[13,000 km, 10/2018], 2]
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                   A
# co₂_efficiency            Calculated on basis of measured CO₂-emissions ...
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                   3.00
#
#                                                                       18951  \
# make_model                                                     Toyota Auris
# short_description                                                130 Active
# make                                                             \nToyota\n
# model                                                       [\n, Auris ,\n]
# location                  Parque Empresarial avda. de la Illustracion, 5...
# price                                                            € 11,990.-
# body_type                                                   [\n, Sedan, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                             [\n, Spain, \n]
# offer_number                                              [\n, 7433755, \n]
# warranty                                                [\n, 12 months, \n]
# mileage                                                          109,117 km
# first_registration                                                  08/2014
# gearbox                                                        [\nManual\n]
# fuel_type                                                          Gasoline
# colour                                                                  NaN
# paint                                                                   NaN
# desc                      [Ref: 7440 , CONCESIONARIO OFICIAL NIMAUTO , P...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                  [\n97 kW (132 hp)\n]
# engine_size                                                  [\n1,598 cc\n]
# gears                                                               [\n6\n]
# co₂_emissions                                                           NaN
# manufacturer_colour                                                  BLANCO
# drivetrain                                                              NaN
# cylinders                                                               NaN
# fuel_consumption          [[5 l/100 km (comb.)], [7 l/100 km (city)], [4...
# comfort_convenience                                                     NaN
# entertainment_media                                                     NaN
# safety_security                                                         NaN
# extras                                                                  NaN
# empty_weight                                                            NaN
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                    NaN
#
#                                                                       4107   \
# make_model                                                      Opel Vivaro
# short_description                  2.0D Edition Navi,AHK,PDC,BT,Tempomat,BC
# make                                                               \nOpel\n
# model                                                      [\n, Vivaro ,\n]
# location                         Bayreuther Straße 39-41,  92224 Amberg, DE
# price                                                            € 23,980.-
# body_type                                           [\n, Station wagon, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 4, \n]
# country_version                                           [\n, Germany, \n]
# offer_number                                            [\n, Vivaro340, \n]
# warranty                                                [\n, 60 months, \n]
# mileage                                                           61,200 km
# first_registration                                                  06/2020
# gearbox                                                        [\nManual\n]
# fuel_type                                          Diesel (Particle filter)
# colour                                                                White
# paint                                                                   NaN
# desc                      [Ihre Ansprechpartner für dieses KFZ:,  ,  , R...
# seller                                                               Dealer
# seats                                                           [\n, 3, \n]
# power                                                 [\n110 kW (150 hp)\n]
# engine_size                                                  [\n1,997 cc\n]
# gears                                                               [\n6\n]
# co₂_emissions                                              142 g/km (comb.)
# manufacturer_colour                                              Jade Weiss
# drivetrain                                                              NaN
# cylinders                                                           [\n4\n]
# fuel_consumption          [[5.4 l/100 km (comb.)], [6 l/100 km (city)], ...
# comfort_convenience       [Air conditioning, Cruise control, Electrical ...
# entertainment_media       Android Auto, Apple CarPlay, Bluetooth, Hands-...
# safety_security           [ABS, Central door lock, Daytime running light...
# extras                    [Spare tyre, Steel wheels, Touch screen, Voice...
# empty_weight                                                 [\n1,678 kg\n]
# model_code                                               [\n, 3003/AXA, \n]
# general_inspection                                                      New
# last_service                                                            NaN
# full_service_history                                                    Yes
# non_smoker_vehicle                                                      Yes
# emission_class                                                 Euro 6d-TEMP
# emissions_sticker                                                 4 (Green)
# upholstery_colour                                                     Black
# upholstery                                                            Other
# production_date                                                     2020.00
# previous_owner                                    [[61,200 km, 06/2020], 1]
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                   A
# co₂_efficiency            Calculated on basis of measured CO₂-emissions ...
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                   5.00
#
#                                                                       7551   \
# make_model                                                      Peugeot 208
# short_description                                           1.2 68ch Active
# make                                                            \nPeugeot\n
# model                                                         [\n, 208 ,\n]
# location                          9 boulevard Jules Ferry,  75011 Paris, FR
# price                                                            € 12,190.-
# body_type                                                 [\n, Compact, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                                         NaN
# offer_number              [\n, fbd53ff8-507d-54ea-a2d1-d8b49125bb3f-fr, \n]
# warranty                                                                NaN
# mileage                                                           31,103 km
# first_registration                                                  10/2019
# gearbox                                                        [\nManual\n]
# fuel_type                                                Regular/Benzine 91
# colour                                                                White
# paint                                                                   NaN
# desc                      [La meilleure façon de trouver votre prochaine...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                   [\n50 kW (68 hp)\n]
# engine_size                                                  [\n1,200 cc\n]
# gears                                                               [\n5\n]
# co₂_emissions                                              110 g/km (comb.)
# manufacturer_colour                                                     NaN
# drivetrain                                                  [\n, Front, \n]
# cylinders                                                           [\n3\n]
# fuel_consumption                                   [[4.7 l/100 km (comb.)]]
# comfort_convenience                      [Air conditioning, Cruise control]
# entertainment_media                                 Bluetooth, Sound system
# safety_security           [Driver-side airbag, Isofix, LED Daytime Runni...
# extras                                                       [Winter tyres]
# empty_weight                                                 [\n1,050 kg\n]
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                            Other
# production_date                                                     2019.00
# previous_owner                                    [[31,103 km, 10/2019], 1]
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                   2.00
#
#                                                                       14965  \
# make_model                                                    Skoda Octavia
# short_description                  Combi Ambition 1.0TSI 110PS 6-Gang mech.
# make                                                              \nSkoda\n
# model                                                     [\n, Octavia ,\n]
# location                        Im Herrmannshof 23,  91595 Burgoberbach, DE
# price                                                            € 25,890.-
# body_type                                           [\n, Station wagon, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 4, \n]
# country_version                                           [\n, Germany, \n]
# offer_number                                              [\n, 24-5301, \n]
# warranty                                                [\n, 12 months, \n]
# mileage                                                           15,600 km
# first_registration                                                  05/2021
# gearbox                                                        [\nManual\n]
# fuel_type                                        Super 95 (Particle filter)
# colour                                                                 Grey
# paint                                                              Metallic
# desc                      [Fahrzeug-Nummer: 24-5301,  , C02-Effizienzkla...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                  [\n81 kW (110 hp)\n]
# engine_size                                                    [\n999 cc\n]
# gears                                                                   NaN
# co₂_emissions                                              106 g/km (comb.)
# manufacturer_colour                                     Quarz grau metallic
# drivetrain                                                              NaN
# cylinders                                                               NaN
# fuel_consumption          [[4.7 l/100 km (comb.)], [6 l/100 km (city)], ...
# comfort_convenience       [Air conditioning, Armrest, Automatic climate ...
# entertainment_media       Bluetooth, Digital radio, Hands-free equipment...
# safety_security           [ABS, Adaptive Cruise Control, Adaptive headli...
# extras                    [Alloy wheels, Roof rack, Touch screen, Voice ...
# empty_weight                                                            NaN
# model_code                                                              NaN
# general_inspection                                                      New
# last_service                                                            NaN
# full_service_history                                                    Yes
# non_smoker_vehicle                                                      Yes
# emission_class                                                      Euro 6d
# emissions_sticker                                                 4 (Green)
# upholstery_colour                                                     Black
# upholstery                                                            Cloth
# production_date                                                         NaN
# previous_owner                                    [[15,600 km, 05/2021], 1]
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                   B
# co₂_efficiency            Calculated on basis of measured CO₂-emissions ...
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                   3.00
#
#                                                                       15179  \
# make_model                                            Skoda Rapid/Spaceback
# short_description            Rapid 1.6 TDI Style AAC Navigation Sitzheizung
# make                                                              \nSkoda\n
# model                                             [\n, Rapid/Spaceback ,\n]
# location                         Fritz-Meinhardt-Str. 2,  01239 Dresden, DE
# price                                                            € 15,900.-
# body_type                                                   [\n, Sedan, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                           [\n, Germany, \n]
# offer_number                                                [\n, 0759G, \n]
# warranty                                                      [\n, Yes, \n]
# mileage                                                           64,240 km
# first_registration                                                  04/2018
# gearbox                                                        [\nManual\n]
# fuel_type                                          Diesel (Particle filter)
# colour                                                                White
# paint                                                                   NaN
# desc                      [Komfort, Klimaautomatik,  , Zentralverriegelu...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                  [\n85 kW (116 hp)\n]
# engine_size                                                  [\n1,598 cc\n]
# gears                                                                   NaN
# co₂_emissions                                                0 g/km (comb.)
# manufacturer_colour                                              Laser Weiß
# drivetrain                                                              NaN
# cylinders                                                               NaN
# fuel_consumption                                   [[3.7 l/100 km (comb.)]]
# comfort_convenience       [Air conditioning, Armrest, Automatic climate ...
# entertainment_media       Android Auto, Apple CarPlay, Bluetooth, Hands-...
# safety_security           [ABS, Adaptive headlights, Central door lock, ...
# extras                    [Alloy wheels, Automatically dimming interior ...
# empty_weight                                                            NaN
# model_code                                                              NaN
# general_inspection                                                      New
# last_service                                                            NaN
# full_service_history                                                    Yes
# non_smoker_vehicle                                                      Yes
# emission_class                                                       Euro 6
# emissions_sticker                                                 4 (Green)
# upholstery_colour                                                       NaN
# upholstery                                                            Cloth
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                   5.00
#
#                                                                       14269  \
# make_model                                                      Skoda Karoq
# short_description                          1.5 TSI ACT Style *LED/Navi/ACC*
# make                                                              \nSkoda\n
# model                                                       [\n, Karoq ,\n]
# location                                Ulmer Str. 90,  73730 Esslingen, DE
# price                                                            € 23,890.-
# ...
# last_service                                                        02/2022
# full_service_history                                                    Yes
# non_smoker_vehicle                                                      Yes
# emission_class                                                       Euro 5
# emissions_sticker                                                 4 (Green)
# upholstery_colour                                                       NaN
# upholstery                                                     Part leather
# production_date                                                         NaN
# previous_owner                                    [[85,697 km, 02/2014], 1]
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                   3.00
#
#                                                                       10197  \
# make_model                                                  Fiat 124 Spider
# short_description                                        1.4 MultiAir Lusso
# make                                                               \nFiat\n
# model                                                  [\n, 124 Spider ,\n]
# location                         Via Luigi Zoja, 37,  20100 Milano - Mi, IT
# price                                                            € 24,990.-
# body_type                                             [\n, Convertible, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 2, \n]
# country_version                                                         NaN
# offer_number                                              [\n, 6099187, \n]
# warranty                                                                NaN
# mileage                                                           23,800 km
# first_registration                                                  07/2017
# gearbox                                                        [\nManual\n]
# fuel_type                                                          Gasoline
# colour                                                                Black
# paint                                                                   NaN
# desc                      [DEK:[6099187], ID 729414 SPA, Per maggiori in...
# seller                                                               Dealer
# seats                                                           [\n, 2, \n]
# power                                                 [\n103 kW (140 hp)\n]
# engine_size                                                  [\n1,368 cc\n]
# gears                                                               [\n6\n]
# co₂_emissions                                              148 g/km (comb.)
# manufacturer_colour                                                    Nero
# drivetrain                                                   [\n, Rear, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption          [[6.4 l/100 km (comb.)], [8.5 l/100 km (city)]...
# comfort_convenience       [Air conditioning, Automatic climate control, ...
# entertainment_media                                   Bluetooth, MP3, Radio
# safety_security           [ABS, Central door lock, Daytime running light...
# extras                                                       [Alloy wheels]
# empty_weight                                                            NaN
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                       Euro 6
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                     Full leather
# production_date                                                     2017.00
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                   1.00
#
#                                                                       28027  \
# make_model                                                       Volvo XC40
# short_description                                 Recharge Inscription,  T5
# make                                                              \nVolvo\n
# model                                                        [\n, XC40 ,\n]
# location                           Leuvensesteenweg 430,  1930 Zaventem, BE
# price                                                            € 51,899.-
# body_type                                        [\n, Off-Road/Pick-up, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                                         NaN
# offer_number                             [\n, 657928297-471606_ct26-06, \n]
# warranty                                                [\n, 24 months, \n]
# mileage                                                           31,452 km
# first_registration                                                  11/2020
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                                               NaN
# colour                                                                Black
# paint                                                              Metallic
# desc                      [IntelliSafe Surround ,  , IntelliSafe Assist ...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                 [\n132 kW (179 hp)\n]
# engine_size                                                  [\n1,477 cc\n]
# gears                                                               [\n7\n]
# co₂_emissions                                               41 g/km (comb.)
# manufacturer_colour                                              Onyx black
# drivetrain                                                              NaN
# cylinders                                                               NaN
# fuel_consumption                                   [[1.8 l/100 km (comb.)]]
# comfort_convenience       [Air conditioning, Automatic climate control, ...
# entertainment_media                                                   Radio
# safety_security           [Driver-side airbag, Electronic stability cont...
# extras                                                                  NaN
# empty_weight                                                            NaN
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                     2020.00
# previous_owner                                                          NaN
# other_fuel_types                                                Electricity
# power_consumption                                   15.9 kWh/100 km (comb.)
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                   0.00
#
#                                                                       20342
# make_model                                                   Nissan Qashqai
# short_description                  1.2 DIG-T N-Connecta AAC,360°,18'',I-Key
# make                                                             \nNissan\n
# model                                                     [\n, Qashqai ,\n]
# location                             Torgauer Str.  108,  04318 Leipzig, DE
# price                                                            € 16,890.-
# body_type                                        [\n, Off-Road/Pick-up, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                           [\n, Germany, \n]
# offer_number                                             [\n, UZ034981, \n]
# warranty                                                [\n, 60 months, \n]
# mileage                                                           15,160 km
# first_registration                                                  05/2017
# gearbox                                                        [\nManual\n]
# fuel_type                                                          Super 95
# colour                                                                  Red
# paint                                                              Metallic
# desc                      [Wir sind telefonisch, per Mail und gerne auch...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                  [\n85 kW (116 hp)\n]
# engine_size                                                  [\n1,197 cc\n]
# gears                                                               [\n6\n]
# co₂_emissions                                              133 g/km (comb.)
# manufacturer_colour                                             NEW RED (M)
# drivetrain                                                              NaN
# cylinders                                                           [\n4\n]
# fuel_consumption          [[5.8 l/100 km (comb.)], [6.8 l/100 km (city)]...
# comfort_convenience       [360° camera, Air conditioning, Armrest, Autom...
# entertainment_media       Bluetooth, CD player, Digital radio, Hands-fre...
# safety_security           [ABS, Central door lock, Daytime running light...
# extras                    [Alloy wheels (18"), Ambient lighting, Automat...
# empty_weight                                                 [\n1,350 kg\n]
# model_code                                               [\n, 1329/AHQ, \n]
# general_inspection                                                      New
# last_service                                                            NaN
# full_service_history                                                    Yes
# non_smoker_vehicle                                                      Yes
# emission_class                                                       Euro 6
# emissions_sticker                                                 4 (Green)
# upholstery_colour                                                     Other
# upholstery                                                            Cloth
# production_date                                                     2017.00
# previous_owner                                    [[15,160 km, 05/2017], 2]
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                   B
# co₂_efficiency            Calculated on basis of measured CO₂-emissions ...
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
# entertainment_media2                                                   3.00

# %%
df.head(10)
# Out:
#                make_model                                short_description  \
# 0     Mercedes-Benz A 160                                              CDi
# 1   Mercedes-Benz EQE 350                                             350+
# 2  Mercedes-Benz A 45 AMG                                 S 4Matic+ 8G-DCT
# 3  Mercedes-Benz A 35 AMG                                   4Matic+ 7G-DCT
# 4  Mercedes-Benz A 45 AMG                         200CDI BE Line 4M 7G-DCT
# 5     Mercedes-Benz C 160  Sp. Ed. C-Klasse Sportcoupe!TÜV N.!24 Mon. Gew.
# 6   Mercedes-Benz CLA 180                                             180D
# 7     Mercedes-Benz A 220                                           7G-DCT
# 8  Mercedes-Benz A 35 AMG                                           4MATIC
# 9     Mercedes-Benz A 200                                200CDI Autotronic
#
#                 make               model  \
# 0  \nMercedes-Benz\n     [\n, A 160 ,\n]
# 1  \nMercedes-Benz\n   [\n, EQE 350 ,\n]
# 2  \nMercedes-Benz\n  [\n, A 45 AMG ,\n]
# 3  \nMercedes-Benz\n  [\n, A 35 AMG ,\n]
# 4  \nMercedes-Benz\n  [\n, A 45 AMG ,\n]
# 5  \nMercedes-Benz\n     [\n, C 160 ,\n]
# 6  \nMercedes-Benz\n   [\n, CLA 180 ,\n]
# 7  \nMercedes-Benz\n     [\n, A 220 ,\n]
# 8  \nMercedes-Benz\n  [\n, A 35 AMG ,\n]
# 9  \nMercedes-Benz\n     [\n, A 200 ,\n]
#
#                                             location       price  \
# 0  P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...  € 16,950.-
# 1       APARTADO DE CORREOS 1032,  26140 LOGROÑO, ES  € 80,900.-
# 2  PORT. TARRACO, MOLL DE LLEVANT, Nº 5, LOC. 6-8...  € 69,900.-
# 3  Carrer de Provença, 31 Local,  8029 BARCELONA, ES  € 46,990.-
# 4             CARRIL ARAGONES 4,  30007 CASILLAS, ES  € 16,800.-
# 5              Beethovenstr. 89,  42655 Solingen, DE   € 4,690.-
# 6    CR PATERNA-LA CAÑADA, KM. 2,  46980 PATERNA, ES  € 22,550.-
# 7       CTRA DE MADRID KM 315,7,  50012 ZARAGOZA, ES  € 26,900.-
# 8                Voogdijstraat 25,  3500 Hasselt, BE  € 44,999.-
# 9            AUTOVÍA AS-2, Nº 1529,  33392 GIJON, ES  € 23,900.-
#
#            body_type                      type        doors  \
# 0  [\n, Compact, \n]            [\n, Used, \n]  [\n, 5, \n]
# 1  [\n, Compact, \n]  [\n, Pre-registered, \n]  [\n, 4, \n]
# 2  [\n, Compact, \n]            [\n, Used, \n]  [\n, 5, \n]
# 3  [\n, Compact, \n]            [\n, Used, \n]  [\n, 5, \n]
# 4  [\n, Compact, \n]            [\n, Used, \n]  [\n, 5, \n]
# 5  [\n, Compact, \n]            [\n, Used, \n]  [\n, 3, \n]
# 6  [\n, Compact, \n]            [\n, Used, \n]  [\n, 5, \n]
# 7  [\n, Compact, \n]            [\n, Used, \n]  [\n, 5, \n]
# 8  [\n, Compact, \n]            [\n, Used, \n]  [\n, 5, \n]
# 9  [\n, Compact, \n]            [\n, Used, \n]  [\n, 5, \n]
#
#      country_version       offer_number             warranty     mileage  \
# 0    [\n, Spain, \n]  [\n, 7468157, \n]  [\n, 24 months, \n]  120,200 km
# 1    [\n, Spain, \n]  [\n, 7054863, \n]  [\n, 24 months, \n]    5,000 km
# 2    [\n, Spain, \n]  [\n, 7410454, \n]  [\n, 12 months, \n]   18,900 km
# 3    [\n, Spain, \n]  [\n, 7464503, \n]  [\n, 12 months, \n]   18,995 km
# 4    [\n, Spain, \n]  [\n, 7127931, \n]  [\n, 12 months, \n]  197,000 km
# 5  [\n, Germany, \n]                NaN                  NaN  165,000 km
# 6    [\n, Spain, \n]  [\n, 7201260, \n]  [\n, 12 months, \n]   83,339 km
# 7    [\n, Spain, \n]  [\n, 7329555, \n]  [\n, 24 months, \n]   48,900 km
# 8                NaN  [\n, j107114, \n]                  NaN   56,876 km
# 9    [\n, Spain, \n]  [\n, 7454322, \n]  [\n, 12 months, \n]   21,854 km
#
#   first_registration          gearbox           fuel_type  colour     paint  \
# 0            06/2016     [\nManual\n]              Diesel   Black  Metallic
# 1            06/2022  [\nAutomatic\n]            Electric     NaN       NaN
# 2            07/2020  [\nAutomatic\n]            Gasoline    Grey       NaN
# 3            01/2020  [\nAutomatic\n]            Gasoline  Yellow       NaN
# 4            09/2015  [\nAutomatic\n]              Diesel   White  Metallic
# 5            08/2005     [\nManual\n]            Gasoline   Black  Metallic
# 6            07/2018     [\nManual\n]              Diesel  Silver       NaN
# 7            10/2019  [\nAutomatic\n]            Gasoline    Grey  Metallic
# 8            06/2019  [\nAutomatic\n]  Regular/Benzine 91    Grey       NaN
# 9            08/2018  [\nAutomatic\n]              Diesel   White       NaN
#
#                                                 desc  seller        seats  \
# 0  [ , Precio al contado: 16950 euros,  ,  , Vehí...  Dealer          NaN
# 1  [ , Precio al contado: 88900 euros,  , AUTO OJ...  Dealer  [\n, 5, \n]
# 2  [Gris MANUFAKTUR mountaingrau magno,  , Linea/...  Dealer  [\n, 5, \n]
# 3  [ , Precio al contado: 48990 euros,  ,  , BONI...  Dealer  [\n, 5, \n]
# 4  [ , Precio al contado: 17400 euros,  , Vehícul...  Dealer  [\n, 5, \n]
# 5  [Sonderausstattung:, Panorama-Schiebedach elek...  Dealer  [\n, 4, \n]
# 6  [ , Precio al contado: 24900 euros,  , LIQUIDA...  Dealer          NaN
# 7  [ , Precio al contado: 28900 euros,  , OPORTUN...  Dealer  [\n, 5, \n]
# 8  [440 - Snelheidsregelaar TEMPOMAT met variabel...  Dealer          NaN
# 9  [ , Precio al contado: 25900 euros,  ,  , Extr...  Dealer  [\n, 5, \n]
#
#                    power     engine_size    gears     co₂_emissions  \
# 0                    NaN             NaN      NaN               NaN
# 1  [\n215 kW (292 hp)\n]      [\n1 cc\n]  [\n9\n]    0 g/km (comb.)
# 2  [\n310 kW (421 hp)\n]  [\n1,991 cc\n]  [\n8\n]               NaN
# 3  [\n225 kW (306 hp)\n]  [\n1,991 cc\n]  [\n7\n]               NaN
# 4  [\n100 kW (136 hp)\n]  [\n2,143 cc\n]  [\n7\n]               NaN
# 5   [\n90 kW (122 hp)\n]  [\n1,799 cc\n]  [\n6\n]  196 g/km (comb.)
# 6                    NaN             NaN      NaN               NaN
# 7  [\n140 kW (190 hp)\n]  [\n1,991 cc\n]  [\n7\n]               NaN
# 8  [\n225 kW (306 hp)\n]  [\n1,991 cc\n]      NaN  168 g/km (comb.)
# 9  [\n102 kW (139 hp)\n]  [\n1,991 cc\n]  [\n1\n]               NaN
#
#          manufacturer_colour       drivetrain cylinders  \
# 0                        NaN              NaN       NaN
# 1            Negro Obsidiana              NaN       NaN
# 2         Mountaingrau magno    [\n, 4WD, \n]   [\n4\n]
# 3               Amarillo Sol    [\n, 4WD, \n]   [\n4\n]
# 4                        NaN    [\n, 4WD, \n]   [\n4\n]
# 5  Diamant schwarz  metallic   [\n, Rear, \n]   [\n4\n]
# 6                        NaN              NaN       NaN
# 7               Gris Montaña  [\n, Front, \n]   [\n4\n]
# 8                        NaN              NaN       NaN
# 9      Blanco Cirro (sólido)  [\n, Front, \n]   [\n4\n]
#
#                                     fuel_consumption  \
# 0                                                NaN
# 1                                                NaN
# 2  [[8.4 l/100 km (comb.)], [10.9 l/100 km (city)...
# 3  [[7.3 l/100 km (comb.)], [9.3 l/100 km (city)]...
# 4  [[4.9 l/100 km (comb.)], [5.7 l/100 km (city)]...
# 5  [[8.2 l/100 km (comb.)], [11.6 l/100 km (city)...
# 6                                                NaN
# 7  [[6.1 l/100 km (comb.)], [8.1 l/100 km (city)]...
# 8                             [[0 l/100 km (comb.)]]
# 9  [[5.4 l/100 km (comb.)], [6.9 l/100 km (city)]...
#
#                                  comfort_convenience  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [Air conditioning, Automatic climate control, ...
# 4  [Air conditioning, Electrical side mirrors, Mu...
# 5  [Air conditioning, Armrest, Automatic climate ...
# 6                                                NaN
# 7  [Air conditioning, Automatic climate control, ...
# 8  [Multi-function steering wheel, Navigation sys...
# 9  [Air conditioning, Automatic climate control, ...
#
#                    entertainment_media  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  USB
# 4       Bluetooth, CD player, MP3, USB
# 5  CD player, On-board computer, Radio
# 6                                  NaN
# 7                                  USB
# 8                                  NaN
# 9                                  NaN
#
#                                      safety_security  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [ABS, Central door lock, Driver-side airbag, E...
# 4  [ABS, Central door lock, Driver-side airbag, E...
# 5  [ABS, Bi-Xenon headlights, Central door lock, ...
# 6                                                NaN
# 7  [ABS, Central door lock, Driver-side airbag, E...
# 8                        [Emergency brake assistant]
# 9  [ABS, Central door lock, Driver-side airbag, E...
#
#                                               extras    empty_weight  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                      [Sport seats]             NaN
# 4                                                NaN  [\n1,545 kg\n]
# 5  [Alloy wheels (17"), Catalytic Converter, Emer...  [\n1,465 kg\n]
# 6                                                NaN             NaN
# 7                                                NaN  [\n1,450 kg\n]
# 8                                    [Sport package]             NaN
# 9                                     [Alloy wheels]  [\n1,365 kg\n]
#
#            model_code general_inspection last_service full_service_history  \
# 0                 NaN                NaN          NaN                  NaN
# 1                 NaN                NaN          NaN                  NaN
# 2                 NaN                NaN          NaN                  NaN
# 3                 NaN                NaN          NaN                  NaN
# 4                 NaN                NaN          NaN                  NaN
# 5  [\n, 0999/338, \n]                New      07/2022                  Yes
# 6                 NaN                NaN          NaN                  NaN
# 7                 NaN                NaN          NaN                  NaN
# 8                 NaN                NaN          NaN                  NaN
# 9                 NaN                NaN          NaN                  NaN
#
#   non_smoker_vehicle emission_class emissions_sticker upholstery_colour  \
# 0                NaN            NaN               NaN               NaN
# 1                NaN            NaN               NaN               NaN
# 2                NaN            NaN               NaN               NaN
# 3                NaN            NaN               NaN               NaN
# 4                NaN            NaN               NaN               NaN
# 5                Yes         Euro 4         4 (Green)             Black
# 6                NaN            NaN               NaN               NaN
# 7                NaN            NaN               NaN               NaN
# 8                NaN         Euro 6               NaN             Black
# 9                NaN            NaN               NaN               NaN
#
#      upholstery production_date previous_owner other_fuel_types  \
# 0           NaN             NaN            NaN              NaN
# 1           NaN             NaN            NaN              NaN
# 2           NaN             NaN            NaN              NaN
# 3           NaN             NaN            NaN              NaN
# 4           NaN             NaN            NaN              NaN
# 5         Cloth             NaN            NaN              NaN
# 6           NaN             NaN            NaN              NaN
# 7           NaN             NaN            NaN              NaN
# 8  Full leather         2019.00            NaN              NaN
# 9           NaN             NaN            NaN              NaN
#
#   power_consumption energy_efficiency_class co₂_efficiency  \
# 0               NaN                     NaN            NaN
# 1               NaN                     NaN            NaN
# 2               NaN                     NaN            NaN
# 3               NaN                     NaN            NaN
# 4               NaN                     NaN            NaN
# 5               NaN                     NaN            NaN
# 6               NaN                     NaN            NaN
# 7               NaN                     NaN            NaN
# 8               NaN                     NaN            NaN
# 9               NaN                     NaN            NaN
#
#   fuel_consumption_(wltp) co₂_emissions_(wltp) available_from  \
# 0                     NaN                  NaN            NaN
# 1                     NaN                  NaN            NaN
# 2                     NaN                  NaN            NaN
# 3                     NaN                  NaN            NaN
# 4                     NaN                  NaN            NaN
# 5                     NaN                  NaN            NaN
# 6                     NaN                  NaN            NaN
# 7                     NaN                  NaN            NaN
# 8                     NaN                  NaN            NaN
# 9                     NaN                  NaN            NaN
#
#   taxi_or_rental_car availability last_timing_belt_change  \
# 0                NaN          NaN                     NaN
# 1                NaN          NaN                     NaN
# 2                NaN          NaN                     NaN
# 3                NaN          NaN                     NaN
# 4                NaN          NaN                     NaN
# 5                NaN          NaN                     NaN
# 6                NaN          NaN                     NaN
# 7                NaN          NaN                     NaN
# 8                NaN          NaN                     NaN
# 9                NaN          NaN                     NaN
#
#   electric_range_(wltp) power_consumption_(wltp) battery_ownership  \
# 0                   NaN                      NaN               NaN
# 1                   NaN                      NaN               NaN
# 2                   NaN                      NaN               NaN
# 3                   NaN                      NaN               NaN
# 4                   NaN                      NaN               NaN
# 5                   NaN                      NaN               NaN
# 6                   NaN                      NaN               NaN
# 7                   NaN                      NaN               NaN
# 8                   NaN                      NaN               NaN
# 9                   NaN                      NaN               NaN
#
#   entertainment_media2
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                 1.00
# 4                 2.00
# 5                 1.00
# 6                  NaN
# 7                 1.00
# 8                  NaN
# 9                  NaN

# %%
df['entertainment_media2'].value_counts(dropna=False)
# Out:
# 1.0     8274
# 2.0     7523
# NaN     5836
# 0.0     3997
# high    3850
# Name: entertainment_media2, dtype: int64

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'make', 'model', 'location', 'price',
#        'body_type', 'type', 'doors', 'country_version', 'offer_number',
#        'warranty', 'mileage', 'first_registration', 'gearbox', 'fuel_type',
#        'colour', 'paint', 'desc', 'seller', 'seats', 'power', 'engine_size',
#        'gears', 'co₂_emissions', 'manufacturer_colour', 'drivetrain',
#        'cylinders', 'fuel_consumption', 'comfort_convenience',
#        'entertainment_media', 'safety_security', 'extras', 'empty_weight',
#        'model_code', 'general_inspection', 'last_service',
#        'full_service_history', 'non_smoker_vehicle', 'emission_class',
#        'emissions_sticker', 'upholstery_colour', 'upholstery',
#        'production_date', 'previous_owner', 'other_fuel_types',
#        'power_consumption', 'energy_efficiency_class', 'co₂_efficiency',
#        'fuel_consumption_(wltp)', 'co₂_emissions_(wltp)', 'available_from',
#        'taxi_or_rental_car', 'availability', 'last_timing_belt_change',
#        'electric_range_(wltp)', 'power_consumption_(wltp)',
#        'battery_ownership', 'entertainment_media2', 'entertainment_media1',
#        'entertainment_point1', 'entertainment_media3'],
#       dtype='object')

# %%
df.drop(['entertainment_media2', 'entertainment_media1',
       'entertainment_point1', 'entertainment_media3']

# %%
#???
df['safety_security'].value_counts()
# Out:
# [Isofix]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       380
# [ABS, Central door lock, Driver-side airbag, Electronic stability control, Immobilizer, Isofix, Passenger-side airbag, Power steering, Side airbag]                                                                                                                                                                                                                                                                                                                                                                            328
# [ABS, Central door lock, Driver-side airbag, Immobilizer, Isofix, Passenger-side airbag, Power steering, Side airbag, Traction control]                                                                                                                                                                                                                                                                                                                                                                                        125
# [ABS, Central door lock, Driver-side airbag, Electronic stability control, Fog lights, Isofix, Power steering, Side airbag]                                                                                                                                                                                                                                                                                                                                                                                                    121
# [ABS, Fog lights, Side airbag]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 100
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# [Daytime running lights, Emergency brake assistant, Fog lights, Isofix, LED Daytime Running Lights, Lane departure warning system, Power steering, Tire pressure monitoring system]                                                                                                                                                                                                                                                                                                                                              1
# [ABS, Adaptive Cruise Control, Central door lock, Daytime running lights, Driver drowsiness detection, Driver-side airbag, Electronic stability control, Emergency brake assistant, Emergency system, Fog lights, Full-LED headlights, Glare-free high beam headlights, Immobilizer, Isofix, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control]                                                                               1
# [ABS, Driver-side airbag, Electronic stability control, Emergency brake assistant, Immobilizer, LED Daytime Running Lights, Passenger-side airbag, Side airbag, Tire pressure monitoring system, Traction control]                                                                                                                                                                                                                                                                                                               1
# [ABS, Blind spot monitor, Central door lock, Daytime running lights, Distance warning system, Driver drowsiness detection, Driver-side airbag, Electronic stability control, Emergency system, Fog lights, Full-LED headlights, Head airbag, High beam assist, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Side airbag, Speed limit control system, Tire pressure monitoring system, Traction control, Traffic sign recognition]      1
# [ABS, Alarm system, Central door lock, Central door lock with remote control, Driver-side airbag, Electronic stability control, Fog lights, Head airbag, Immobilizer, Power steering, Side airbag, Traction control]                                                                                                                                                                                                                                                                                                             1
# Name: Safety&Security, Length: 12549, dtype: int64

# %%
#???
df['extras'].value_counts()
# Out:
# [Alloy wheels]                                                                                                                                                                        3408
# [Alloy wheels, Roof rack]                                                                                                                                                              380
# [Alloy wheels, Sport seats]                                                                                                                                                            372
# [Alloy wheels, Touch screen]                                                                                                                                                           231
# [Alloy wheels, Catalytic Converter, Touch screen]                                                                                                                                      178
#                                                                                                                                                                                       ...
# [Alloy wheels (18"), Automatically dimming interior mirror, Catalytic Converter, E10-enabled, Headlight washer system, Sport package, Sport seats, Sport suspension, Summer tyres]       1
# [Alloy wheels (18"), Spoiler, Summer tyres, Trailer hitch]                                                                                                                               1
# [All season tyres, Alloy wheels, Automatically dimming interior mirror, Catalytic Converter, Headlight washer system, Ski bag, Sport seats, Trailer hitch, Winter tyres]                 1
# [Alloy wheels, Automatically dimming interior mirror, Headlight washer system, Sport package, Sport seats, Summer tyres]                                                                 1
# [Alloy wheels, Automatically dimming interior mirror, Ski bag, Trailer hitch]                                                                                                            1
# Name: Extras, Length: 9360, dtype: int64

# %%
df['empty_weight'].value_counts()
# Out:
# [\n1,395 kg\n]    233
# [\n1,055 kg\n]    224
# [\n1,423 kg\n]    216
# [\n1,165 kg\n]    200
# [\n1,320 kg\n]    192
#                  ...
# [\n2,655 kg\n]      1
# [\n1,058 kg\n]      1
# [\n2,091 kg\n]      1
# [\n2,497 kg\n]      1
# [\n1,391 kg\n]      1
# Name: Empty weight, Length: 1218, dtype: int64

# %%
df['empty_weight']=df['empty_weight'].apply(lambda t: t[0].replace(',','') if pd.notnull(t) else t)
df['empty_weight'] = df['empty_weight'].apply(lambda t: int(re.findall(r'\d+', str(t))[0]) if pd.notnull(t) else t)
df['empty_weight'].value_counts()
# Out:
# 1395.00    233
# 1055.00    224
# 1423.00    216
# 1165.00    200
# 1320.00    192
#           ...
# 2655.00      1
# 1058.00      1
# 2091.00      1
# 2497.00      1
# 1391.00      1
# Name: Empty weight, Length: 1218, dtype: int64

# %%
# The 'Model code' column can be dropped later, because 71.62% of the values is null.
percentage_null.loc['model_code']
# Out:
# percentage_null   71.62
# Name: Model code, dtype: float64

# %%
#???
df['general_inspection'].value_counts()
# Out:
# New        5883
# 05/2023     286
# 08/2023     280
# 03/2023     268
# 06/2023     266
# 04/2023     262
# 09/2023     255
# 07/2023     254
# 06/2024     216
# 05/2024     212
# 01/2023     210
# 02/2023     209
# 03/2024     207
# 07/2024     203
# 08/2024     187
# 09/2024     182
# 11/2023     176
# 01/2024     164
# 02/2024     163
# 04/2024     162
# 12/2023     160
# 12/2022     159
# 10/2023     155
# 06/2025     147
# 11/2022     131
# 08/2025     122
# 07/2025     110
# 09/2022      96
# 03/2025      95
# 05/2025      93
# 10/2022      90
# 04/2025      89
# 01/2025      75
# 02/2025      66
# 09/2025      65
# 10/2024      64
# 08/2022      64
# 12/2024      61
# 11/2024      50
# 06/2022      42
# 07/2022      41
# 04/2022      34
# 03/2022      25
# 05/2022      22
# 10/2021      17
# 11/2021      11
# 01/2022      10
# 07/2021      10
# 09/2021       8
# 08/2021       7
# 12/2021       7
# 02/2022       6
# 05/2026       5
# 07/2020       5
# 10/2025       4
# 05/2021       4
# 06/2026       4
# 12/2019       4
# 06/2021       3
# 01/2021       3
# 11/2020       3
# 04/2026       3
# 02/2021       2
# 02/2026       2
# 12/2025       2
# 09/2026       2
# 01/2026       2
# 12/2020       2
# 07/2026       2
# 08/2026       2
# 02/2027       2
# 06/2020       2
# 12/2017       1
# 10/2020       1
# 01/2020       1
# 04/2020       1
# 10/2019       1
# 05/2018       1
# 09/2020       1
# 07/2019       1
# 05/2020       1
# 08/2019       1
# 03/2026       1
# 11/2019       1
# 01/2018       1
# 07/2017       1
# 09/2017       1
# 08/2013       1
# 08/2020       1
# 08/2018       1
# 03/2021       1
# Name: General inspection, dtype: int64

# %%
# The 'Last service' column can be dropped later, because 93.21% of the values is null.
percentage_null.loc['last_service']
# Out:
# percentage_null   93.21
# Name: Last service, dtype: float64

# %%
df['full_service_history'].value_counts()
# Out:
# Yes    12565
# Name: Full service history, dtype: int64

# %%
df['non_smoker_vehicle'].value_counts()
# Out:
# Yes    11594
# Name: Non-smoker vehicle, dtype: int64

# %%
df['emission_class'].value_counts()
# Out:
# Euro 6          6418
# Euro 6d-TEMP    3399
# Euro 6d         2858
# Euro 5          2389
# Euro 4          1743
# Euro 3           523
# Euro 2           217
# Euro 1           172
# Euro 6c          140
# Name: Emission class, dtype: int64

# %%
df.head(3).T
# Out:
#                                                                           0  \
# make_model                                              Mercedes-Benz A 160
# short_description                                                       CDi
# make                                                      \nMercedes-Benz\n
# model                                                       [\n, A 160 ,\n]
# location                  P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...
# price                                                            € 16,950.-
# Body type                                                 [\n, Compact, \n]
# Type                                                         [\n, Used, \n]
# Doors                                                           [\n, 5, \n]
# Country version                                             [\n, Spain, \n]
# Offer number                                              [\n, 7468157, \n]
# Warranty                                                [\n, 24 months, \n]
# Mileage                                                          120,200 km
# First registration                                                  06/2016
# Gearbox                                                        [\nManual\n]
# Fuel type                                                            Diesel
# Colour                                                                Black
# Paint                                                              Metallic
# desc                      [ , Precio al contado: 16950 euros,  ,  , Vehí...
# seller                                                               Dealer
# Seats                                                                   NaN
# Power                                                                   NaN
# Engine size                                                             NaN
# Gears                                                                   NaN
# CO₂-emissions                                                           NaN
# Manufacturer colour                                                     NaN
# Drivetrain                                                              NaN
# Cylinders                                                               NaN
# Fuel consumption                                                        NaN
# Comfort&Convenience                                                     NaN
# Entertainment&Media                                                     NaN
# Safety&Security                                                         NaN
# Extras                                                                  NaN
# Empty weight                                                            NaN
# Model code                                                              NaN
# General inspection                                                      NaN
# Last service                                                            NaN
# Full service history                                                    NaN
# Non-smoker vehicle                                                      NaN
# Emission class                                                          NaN
# Emissions sticker                                                       NaN
# Upholstery colour                                                       NaN
# Upholstery                                                              NaN
# Production date                                                         NaN
# Previous owner                                                          NaN
# Other fuel types                                                        NaN
# Power consumption                                                       NaN
# Energy efficiency class                                                 NaN
# CO₂-efficiency                                                          NaN
# Fuel consumption (WLTP)                                                 NaN
# CO₂-emissions (WLTP)                                                    NaN
# Available from                                                          NaN
# Taxi or rental car                                                      NaN
# Availability                                                            NaN
# Last timing belt change                                                 NaN
# Electric Range (WLTP)                                                   NaN
# Power consumption (WLTP)                                                NaN
# Battery Ownership                                                       NaN
#
#                                                                           1  \
# make_model                                            Mercedes-Benz EQE 350
# short_description                                                      350+
# make                                                      \nMercedes-Benz\n
# model                                                     [\n, EQE 350 ,\n]
# location                       APARTADO DE CORREOS 1032,  26140 LOGROÑO, ES
# price                                                            € 80,900.-
# Body type                                                 [\n, Compact, \n]
# Type                                               [\n, Pre-registered, \n]
# Doors                                                           [\n, 4, \n]
# Country version                                             [\n, Spain, \n]
# Offer number                                              [\n, 7054863, \n]
# Warranty                                                [\n, 24 months, \n]
# Mileage                                                            5,000 km
# First registration                                                  06/2022
# Gearbox                                                     [\nAutomatic\n]
# Fuel type                                                          Electric
# Colour                                                                  NaN
# Paint                                                                   NaN
# desc                      [ , Precio al contado: 88900 euros,  , AUTO OJ...
# seller                                                               Dealer
# Seats                                                                  5.00
# Power                                                                215.00
# Engine size                                                            1.00
# Gears                                                                  9.00
# CO₂-emissions                                                          0.00
# Manufacturer colour                                         Negro Obsidiana
# Drivetrain                                                              NaN
# Cylinders                                                               NaN
# Fuel consumption                                                        NaN
# Comfort&Convenience                                                     NaN
# Entertainment&Media                                                     NaN
# Safety&Security                                                         NaN
# Extras                                                                  NaN
# Empty weight                                                            NaN
# Model code                                                              NaN
# General inspection                                                      NaN
# Last service                                                            NaN
# Full service history                                                    NaN
# Non-smoker vehicle                                                      NaN
# Emission class                                                          NaN
# Emissions sticker                                                       NaN
# Upholstery colour                                                       NaN
# Upholstery                                                              NaN
# Production date                                                         NaN
# Previous owner                                                          NaN
# Other fuel types                                                        NaN
# Power consumption                                                       NaN
# Energy efficiency class                                                 NaN
# CO₂-efficiency                                                          NaN
# Fuel consumption (WLTP)                                                 NaN
# CO₂-emissions (WLTP)                                                    NaN
# Available from                                                          NaN
# Taxi or rental car                                                      NaN
# Availability                                                            NaN
# Last timing belt change                                                 NaN
# Electric Range (WLTP)                                                   NaN
# Power consumption (WLTP)                                                NaN
# Battery Ownership                                                       NaN
#
#                                                                           2
# make_model                                           Mercedes-Benz A 45 AMG
# short_description                                          S 4Matic+ 8G-DCT
# make                                                      \nMercedes-Benz\n
# model                                                    [\n, A 45 AMG ,\n]
# location                  PORT. TARRACO, MOLL DE LLEVANT, Nº 5, LOC. 6-8...
# price                                                            € 69,900.-
# Body type                                                 [\n, Compact, \n]
# Type                                                         [\n, Used, \n]
# Doors                                                           [\n, 5, \n]
# Country version                                             [\n, Spain, \n]
# Offer number                                              [\n, 7410454, \n]
# Warranty                                                [\n, 12 months, \n]
# Mileage                                                           18,900 km
# First registration                                                  07/2020
# Gearbox                                                     [\nAutomatic\n]
# Fuel type                                                          Gasoline
# Colour                                                                 Grey
# Paint                                                                   NaN
# desc                      [Gris MANUFAKTUR mountaingrau magno,  , Linea/...
# seller                                                               Dealer
# Seats                                                                  5.00
# Power                                                                310.00
# Engine size                                                         1991.00
# Gears                                                                  8.00
# CO₂-emissions                                                           NaN
# Manufacturer colour                                      Mountaingrau magno
# Drivetrain                                                              4WD
# Cylinders                                                              4.00
# Fuel consumption                                                       8.40
# Comfort&Convenience                                                     NaN
# Entertainment&Media                                                     NaN
# Safety&Security                                                         NaN
# Extras                                                                  NaN
# Empty weight                                                            NaN
# Model code                                                              NaN
# General inspection                                                      NaN
# Last service                                                            NaN
# Full service history                                                    NaN
# Non-smoker vehicle                                                      NaN
# Emission class                                                          NaN
# Emissions sticker                                                       NaN
# Upholstery colour                                                       NaN
# Upholstery                                                              NaN
# Production date                                                         NaN
# Previous owner                                                          NaN
# Other fuel types                                                        NaN
# Power consumption                                                       NaN
# Energy efficiency class                                                 NaN
# CO₂-efficiency                                                          NaN
# Fuel consumption (WLTP)                                                 NaN
# CO₂-emissions (WLTP)                                                    NaN
# Available from                                                          NaN
# Taxi or rental car                                                      NaN
# Availability                                                            NaN
# Last timing belt change                                                 NaN
# Electric Range (WLTP)                                                   NaN
# Power consumption (WLTP)                                                NaN
# Battery Ownership                                                       NaN

# %% [markdown]
# # PART- 2 `( Handling With Missing Values )`

# %% [markdown]
# # PART- 3 `( Handling With Outliers )`

# %% [markdown]
# # Final Step (Checking final situation of data via graphs)

# %% [markdown]
# ## Export dataframe to csv file (without dummy)

# %%
df.to_csv("final_scout_not_dummy.csv", index=False)

# %% [markdown]
# # Dummy Operation

# %% [markdown]
# ## Export dataframe to csv file (dummy)

# %%
df_dummied.to_csv("final_scout_dummy.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25908\4104035542.py in <module>
# ----> 1 df_dummied.to_csv("final_scout_dummy.csv", index=False)
#
# NameError: name 'df_dummied' is not defined
