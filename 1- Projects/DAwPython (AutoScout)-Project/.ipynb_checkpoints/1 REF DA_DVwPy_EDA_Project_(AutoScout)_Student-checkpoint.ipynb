# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">DA & DVwPY</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Exploratory Data Analysis (EDA) Project</p>
#
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">AutoScout Car Price Prediction EDA</p>

# %% [markdown]
# ## Introduction
# Welcome to "***AutoScout Exploratory Data Analysis (EDA) Project***". This is the project of completing ***Data Analysis & Data Visualization*** Courses and a successful hand-over is mandatory for getting certification for both courses. **Auto Scout** data used in this project scraped from the Website of an online car trading company in 2022, and contains many features of 13 different car makes including 594 models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using a variety of Python libraries, such as Numpy, Pandas, Matplotlib, Seaborn, Scipy, and then you will get a clean dataset for your analysis and pretictive modelling in Machine Learning Path. So you will have the chance to use all the skills you have already learned in the Data Analysis and Visualization courses.
#
# **``In this context, the project consists of 3 parts in general:``**
# * **The first part** is related to ``'Data Cleaning'``. It deals with Incorrect Headers, Incorrect Format, Anomalies, and Dropping useless columns.
# * **The second part** is related to ``'Filling Data'``, in other words 'Imputation'. It deals with Missing Values. Categorical to numeric transformation, Encoding, is done as well.
# * **The third part** is related to ``'Handling Outliers of Data'`` via Visualization libraries. So, some insights will be extracted.
#
# **``SPECIAL NOTE:``**  However, you are ``free to create your own style``. You do ``NOT`` have to stick to the steps above. Nevertheless, we, the DA & DV instructors, recommend you study each part separately to create a source notebook for your further studies.
#
# In order to build your Portfolio in terms of the GitHub account, you need to push your solution file up to your own repository.
#
# Please after solving the task, commit your notebook to GitHub and submit its link to LMS page where the project is settled down.
#
# **BE NOTED:** Please ``DO NOT FORGET`` to click the submit button.
#
# ### Some Reminders on Exploratory data analysis (EDA)
#
# Exploratory data analysis (EDA) is an especially important activity in the routine of a data analyst or scientist. It enables an in depth understanding of the dataset, define or discard hypotheses and create predictive models on a solid basis. It uses data manipulation techniques and several statistical tools to describe and understand the relationship between variables and how these can impact business. By means of EDA, we can obtain meaningful insights that can impact analysis under the following questions (If a checklist is good enough for pilots to use every flight, it’s good enough for data scientists to use with every dataset).
# 1. What question are you trying to solve (or prove wrong)?
# 2. What kind of data do you have?
# 3. What’s missing from the data?
# 4. Where are the outliers?
# 5. How can you add, change or remove features to get more out of your data?
#
# **``Exploratory data analysis (EDA)``** is often an **iterative brainstorming process** where you pose a question, review the data, and develop further questions to investigate before beginning model development work. The image below shows how the brainstorming phase is connected with that of understanding the variables and how this in turn is connected again with the brainstorming phase.<br>
#
# <img src=https://i.ibb.co/k0MC950/EDA-Process.png width="300" height="100">
#
# [Image Credit: Andrew D.](https://towardsdatascience.com/exploratory-data-analysis-in-python-a-step-by-step-process-d0dfa6bf94ee)

# %% [markdown]
# # PART- 1 `( Data Cleaning )`

# %%
pip install skimpy --user

# %%
import numpy as np
import pandas as pd
import re
import seaborn as sns 
import matplotlib.pyplot as plt
#from skimpy import clean_columns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %matplotlib inline
# %matplotlib notebook

plt.rcParams["figure.figsize"] = (10,6)
# plt.rcParams['figure.dpi'] = 100

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.2f' % x)

pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %%
df0 = pd.read_json("as24_cars.json")

# %%
df = df0.copy()

# %%
df.head(10).T
# Out:
#                                                                            0  \
# make_model                                               Mercedes-Benz A 160
# short_description                                                        CDi
# make                                                       \nMercedes-Benz\n
# model                                                        [\n, A 160 ,\n]
# location                   P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...
# price                                                             € 16,950.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7468157, \n]
# Warranty                                                 [\n, 24 months, \n]
# Mileage                                                           120,200 km
# First registration                                                   06/2016
# Gearbox                                                         [\nManual\n]
# Fuel type                                                             Diesel
# Colour                                                                 Black
# Paint                                                               Metallic
# desc                       [ , Precio al contado: 16950 euros,  ,  , Vehí...
# seller                                                                Dealer
# Seats                                                                    NaN
# Power                                                                    NaN
# Engine size                                                              NaN
# Gears                                                                    NaN
# CO₂-emissions                                                            NaN
# Manufacturer colour                                                      NaN
# Drivetrain                                                               NaN
# Cylinders                                                                NaN
# Fuel consumption                                                         NaN
# \nComfort & Convenience\n                                                NaN
# \nEntertainment & Media\n                                                NaN
# \nSafety & Security\n                                                    NaN
# \nExtras\n                                                               NaN
# Empty weight                                                             NaN
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                            1  \
# make_model                                             Mercedes-Benz EQE 350
# short_description                                                       350+
# make                                                       \nMercedes-Benz\n
# model                                                      [\n, EQE 350 ,\n]
# location                        APARTADO DE CORREOS 1032,  26140 LOGROÑO, ES
# price                                                             € 80,900.-
# Body type                                                  [\n, Compact, \n]
# Type                                                [\n, Pre-registered, \n]
# Doors                                                            [\n, 4, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7054863, \n]
# Warranty                                                 [\n, 24 months, \n]
# Mileage                                                             5,000 km
# First registration                                                   06/2022
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                           Electric
# Colour                                                                   NaN
# Paint                                                                    NaN
# desc                       [ , Precio al contado: 88900 euros,  , AUTO OJ...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n215 kW (292 hp)\n]
# Engine size                                                       [\n1 cc\n]
# Gears                                                                [\n9\n]
# CO₂-emissions                                                 0 g/km (comb.)
# Manufacturer colour                                          Negro Obsidiana
# Drivetrain                                                               NaN
# Cylinders                                                                NaN
# Fuel consumption                                                         NaN
# \nComfort & Convenience\n                                                NaN
# \nEntertainment & Media\n                                                NaN
# \nSafety & Security\n                                                    NaN
# \nExtras\n                                                               NaN
# Empty weight                                                             NaN
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                            2  \
# make_model                                            Mercedes-Benz A 45 AMG
# short_description                                           S 4Matic+ 8G-DCT
# make                                                       \nMercedes-Benz\n
# model                                                     [\n, A 45 AMG ,\n]
# location                   PORT. TARRACO, MOLL DE LLEVANT, Nº 5, LOC. 6-8...
# price                                                             € 69,900.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7410454, \n]
# Warranty                                                 [\n, 12 months, \n]
# Mileage                                                            18,900 km
# First registration                                                   07/2020
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                           Gasoline
# Colour                                                                  Grey
# Paint                                                                    NaN
# desc                       [Gris MANUFAKTUR mountaingrau magno,  , Linea/...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n310 kW (421 hp)\n]
# Engine size                                                   [\n1,991 cc\n]
# Gears                                                                [\n8\n]
# CO₂-emissions                                                            NaN
# Manufacturer colour                                       Mountaingrau magno
# Drivetrain                                                     [\n, 4WD, \n]
# Cylinders                                                            [\n4\n]
# Fuel consumption           [[8.4 l/100 km (comb.)], [10.9 l/100 km (city)...
# \nComfort & Convenience\n                                                NaN
# \nEntertainment & Media\n                                                NaN
# \nSafety & Security\n                                                    NaN
# \nExtras\n                                                               NaN
# Empty weight                                                             NaN
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                            3  \
# make_model                                            Mercedes-Benz A 35 AMG
# short_description                                             4Matic+ 7G-DCT
# make                                                       \nMercedes-Benz\n
# model                                                     [\n, A 35 AMG ,\n]
# location                   Carrer de Provença, 31 Local,  8029 BARCELONA, ES
# price                                                             € 46,990.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7464503, \n]
# Warranty                                                 [\n, 12 months, \n]
# Mileage                                                            18,995 km
# First registration                                                   01/2020
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                           Gasoline
# Colour                                                                Yellow
# Paint                                                                    NaN
# desc                       [ , Precio al contado: 48990 euros,  ,  , BONI...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n225 kW (306 hp)\n]
# Engine size                                                   [\n1,991 cc\n]
# Gears                                                                [\n7\n]
# CO₂-emissions                                                            NaN
# Manufacturer colour                                             Amarillo Sol
# Drivetrain                                                     [\n, 4WD, \n]
# Cylinders                                                            [\n4\n]
# Fuel consumption           [[7.3 l/100 km (comb.)], [9.3 l/100 km (city)]...
# \nComfort & Convenience\n  [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n                                              [USB]
# \nSafety & Security\n      [ABS, Central door lock, Driver-side airbag, E...
# \nExtras\n                                                     [Sport seats]
# Empty weight                                                             NaN
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                            4  \
# make_model                                            Mercedes-Benz A 45 AMG
# short_description                                   200CDI BE Line 4M 7G-DCT
# make                                                       \nMercedes-Benz\n
# model                                                     [\n, A 45 AMG ,\n]
# location                              CARRIL ARAGONES 4,  30007 CASILLAS, ES
# price                                                             € 16,800.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7127931, \n]
# Warranty                                                 [\n, 12 months, \n]
# Mileage                                                           197,000 km
# First registration                                                   09/2015
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                             Diesel
# Colour                                                                 White
# Paint                                                               Metallic
# desc                       [ , Precio al contado: 17400 euros,  , Vehícul...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n100 kW (136 hp)\n]
# Engine size                                                   [\n2,143 cc\n]
# Gears                                                                [\n7\n]
# CO₂-emissions                                                            NaN
# Manufacturer colour                                                      NaN
# Drivetrain                                                     [\n, 4WD, \n]
# Cylinders                                                            [\n4\n]
# Fuel consumption           [[4.9 l/100 km (comb.)], [5.7 l/100 km (city)]...
# \nComfort & Convenience\n  [Air conditioning, Electrical side mirrors, Mu...
# \nEntertainment & Media\n                   [Bluetooth, CD player, MP3, USB]
# \nSafety & Security\n      [ABS, Central door lock, Driver-side airbag, E...
# \nExtras\n                                                               NaN
# Empty weight                                                  [\n1,545 kg\n]
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                            5  \
# make_model                                               Mercedes-Benz C 160
# short_description            Sp. Ed. C-Klasse Sportcoupe!TÜV N.!24 Mon. Gew.
# make                                                       \nMercedes-Benz\n
# model                                                        [\n, C 160 ,\n]
# location                               Beethovenstr. 89,  42655 Solingen, DE
# price                                                              € 4,690.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 3, \n]
# Country version                                            [\n, Germany, \n]
# Offer number                                                             NaN
# Warranty                                                                 NaN
# Mileage                                                           165,000 km
# First registration                                                   08/2005
# Gearbox                                                         [\nManual\n]
# Fuel type                                                           Gasoline
# Colour                                                                 Black
# Paint                                                               Metallic
# desc                       [Sonderausstattung:, Panorama-Schiebedach elek...
# seller                                                                Dealer
# Seats                                                            [\n, 4, \n]
# Power                                                   [\n90 kW (122 hp)\n]
# Engine size                                                   [\n1,799 cc\n]
# Gears                                                                [\n6\n]
# CO₂-emissions                                               196 g/km (comb.)
# Manufacturer colour                                Diamant schwarz  metallic
# Drivetrain                                                    [\n, Rear, \n]
# Cylinders                                                            [\n4\n]
# Fuel consumption           [[8.2 l/100 km (comb.)], [11.6 l/100 km (city)...
# \nComfort & Convenience\n  [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n              [CD player, On-board computer, Radio]
# \nSafety & Security\n      [ABS, Bi-Xenon headlights, Central door lock, ...
# \nExtras\n                 [Alloy wheels (17"), Catalytic Converter, Emer...
# Empty weight                                                  [\n1,465 kg\n]
# Model code                                                [\n, 0999/338, \n]
# General inspection                                                       New
# Last service                                                         07/2022
# Full service history                                                     Yes
# Non-smoker vehicle                                                       Yes
# Emission class                                                        Euro 4
# Emissions sticker                                                  4 (Green)
# Upholstery colour                                                      Black
# Upholstery                                                             Cloth
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                            6  \
# make_model                                             Mercedes-Benz CLA 180
# short_description                                                       180D
# make                                                       \nMercedes-Benz\n
# model                                                      [\n, CLA 180 ,\n]
# location                     CR PATERNA-LA CAÑADA, KM. 2,  46980 PATERNA, ES
# price                                                             € 22,550.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7201260, \n]
# Warranty                                                 [\n, 12 months, \n]
# Mileage                                                            83,339 km
# First registration                                                   07/2018
# Gearbox                                                         [\nManual\n]
# Fuel type                                                             Diesel
# Colour                                                                Silver
# Paint                                                                    NaN
# desc                       [ , Precio al contado: 24900 euros,  , LIQUIDA...
# seller                                                                Dealer
# Seats                                                                    NaN
# Power                                                                    NaN
# Engine size                                                              NaN
# Gears                                                                    NaN
# CO₂-emissions                                                            NaN
# Manufacturer colour                                                      NaN
# Drivetrain                                                               NaN
# Cylinders                                                                NaN
# Fuel consumption                                                         NaN
# \nComfort & Convenience\n                                                NaN
# \nEntertainment & Media\n                                                NaN
# \nSafety & Security\n                                                    NaN
# \nExtras\n                                                               NaN
# Empty weight                                                             NaN
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                            7  \
# make_model                                               Mercedes-Benz A 220
# short_description                                                     7G-DCT
# make                                                       \nMercedes-Benz\n
# model                                                        [\n, A 220 ,\n]
# location                        CTRA DE MADRID KM 315,7,  50012 ZARAGOZA, ES
# price                                                             € 26,900.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7329555, \n]
# Warranty                                                 [\n, 24 months, \n]
# Mileage                                                            48,900 km
# First registration                                                   10/2019
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                           Gasoline
# Colour                                                                  Grey
# Paint                                                               Metallic
# desc                       [ , Precio al contado: 28900 euros,  , OPORTUN...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n140 kW (190 hp)\n]
# Engine size                                                   [\n1,991 cc\n]
# Gears                                                                [\n7\n]
# CO₂-emissions                                                            NaN
# Manufacturer colour                                             Gris Montaña
# Drivetrain                                                   [\n, Front, \n]
# Cylinders                                                            [\n4\n]
# Fuel consumption           [[6.1 l/100 km (comb.)], [8.1 l/100 km (city)]...
# \nComfort & Convenience\n  [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n                                              [USB]
# \nSafety & Security\n      [ABS, Central door lock, Driver-side airbag, E...
# \nExtras\n                                                               NaN
# Empty weight                                                  [\n1,450 kg\n]
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                            8  \
# make_model                                            Mercedes-Benz A 35 AMG
# short_description                                                     4MATIC
# make                                                       \nMercedes-Benz\n
# model                                                     [\n, A 35 AMG ,\n]
# location                                 Voogdijstraat 25,  3500 Hasselt, BE
# price                                                             € 44,999.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                                          NaN
# Offer number                                               [\n, j107114, \n]
# Warranty                                                                 NaN
# Mileage                                                            56,876 km
# First registration                                                   06/2019
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                 Regular/Benzine 91
# Colour                                                                  Grey
# Paint                                                                    NaN
# desc                       [440 - Snelheidsregelaar TEMPOMAT met variabel...
# seller                                                                Dealer
# Seats                                                                    NaN
# Power                                                  [\n225 kW (306 hp)\n]
# Engine size                                                   [\n1,991 cc\n]
# Gears                                                                    NaN
# CO₂-emissions                                               168 g/km (comb.)
# Manufacturer colour                                                      NaN
# Drivetrain                                                               NaN
# Cylinders                                                                NaN
# Fuel consumption                                      [[0 l/100 km (comb.)]]
# \nComfort & Convenience\n  [Multi-function steering wheel, Navigation sys...
# \nEntertainment & Media\n                                                NaN
# \nSafety & Security\n                            [Emergency brake assistant]
# \nExtras\n                                                   [Sport package]
# Empty weight                                                             NaN
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                        Euro 6
# Emissions sticker                                                        NaN
# Upholstery colour                                                      Black
# Upholstery                                                      Full leather
# Production date                                                      2019.00
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                            9
# make_model                                               Mercedes-Benz A 200
# short_description                                          200CDI Autotronic
# make                                                       \nMercedes-Benz\n
# model                                                        [\n, A 200 ,\n]
# location                             AUTOVÍA AS-2, Nº 1529,  33392 GIJON, ES
# price                                                             € 23,900.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7454322, \n]
# Warranty                                                 [\n, 12 months, \n]
# Mileage                                                            21,854 km
# First registration                                                   08/2018
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                             Diesel
# Colour                                                                 White
# Paint                                                                    NaN
# desc                       [ , Precio al contado: 25900 euros,  ,  , Extr...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n102 kW (139 hp)\n]
# Engine size                                                   [\n1,991 cc\n]
# Gears                                                                [\n1\n]
# CO₂-emissions                                                            NaN
# Manufacturer colour                                    Blanco Cirro (sólido)
# Drivetrain                                                   [\n, Front, \n]
# Cylinders                                                            [\n4\n]
# Fuel consumption           [[5.4 l/100 km (comb.)], [6.9 l/100 km (city)]...
# \nComfort & Convenience\n  [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n                                                NaN
# \nSafety & Security\n      [ABS, Central door lock, Driver-side airbag, E...
# \nExtras\n                                                    [Alloy wheels]
# Empty weight                                                  [\n1,365 kg\n]
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN

# %%
df.sample().T
# Out:
#                                                                        26359
# make_model                                           Volvo V40 Cross Country
# short_description          T4 Aut. Nordic+ Luxury, Leder, Panoramadak, St...
# make                                                               \nVolvo\n
# model                                            [\n, V40 Cross Country ,\n]
# location                               Het Wendelgoor 3,  7604 PJ ALMELO, NL
# price                                                             € 22,900.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                                          NaN
# Offer number                                                 [\n, 21545, \n]
# Warranty                                                                 NaN
# Mileage                                                            85,023 km
# First registration                                                   10/2016
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                           Gasoline
# Colour                                                                 Black
# Paint                                                               Metallic
# desc                       [Wil jij deze auto graag bezichtigen of een pr...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n140 kW (190 hp)\n]
# Engine size                                                   [\n1,969 cc\n]
# Gears                                                                [\n6\n]
# CO₂-emissions                                               129 g/km (comb.)
# Manufacturer colour                           Onyx Black Metallic (zwart met
# Drivetrain                                                               NaN
# Cylinders                                                            [\n4\n]
# Fuel consumption           [[5.6 l/100 km (comb.)], [7.2 l/100 km (city)]...
# \nComfort & Convenience\n  [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n              [Bluetooth, On-board computer, Radio]
# \nSafety & Security\n      [ABS, Adaptive headlights, Alarm system, Centr...
# \nExtras\n                 [Alloy wheels (17"), Automatically dimming int...
# Empty weight                                                  [\n1,353 kg\n]
# Model code                                                               NaN
# General inspection                                                   03/2024
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                        Euro 6
# Emissions sticker                                                        NaN
# Upholstery colour                                                      Black
# Upholstery                                                      Full leather
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29480 entries, 0 to 29479
# Data columns (total 58 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   make_model                28630 non-null  object
#  1   short_description         28630 non-null  object
#  2   make                      28630 non-null  object
#  3   model                     28630 non-null  object
#  4   location                  28630 non-null  object
#  5   price                     28630 non-null  object
#  6   Body type                 28630 non-null  object
#  7   Type                      28630 non-null  object
#  8   Doors                     28271 non-null  object
#  9   Country version           16889 non-null  object
#  10  Offer number              23100 non-null  object
#  11  Warranty                  15784 non-null  object
#  12  Mileage                   28629 non-null  object
#  13  First registration        28628 non-null  object
#  14  Gearbox                   28382 non-null  object
#  15  Fuel type                 26843 non-null  object
#  16  Colour                    26906 non-null  object
#  17  Paint                     14495 non-null  object
#  18  desc                      28047 non-null  object
#  19  seller                    28630 non-null  object
#  20  Seats                     25505 non-null  object
#  21  Power                     28058 non-null  object
#  22  Engine size               27227 non-null  object
#  23  Gears                     18954 non-null  object
#  24  CO₂-emissions             18594 non-null  object
#  25  Manufacturer colour       21787 non-null  object
#  26  Drivetrain                16893 non-null  object
#  27  Cylinders                 18852 non-null  object
#  28  Fuel consumption          23385 non-null  object
#  29
# Comfort & Convenience
#    25433 non-null  object
#  30
# Entertainment & Media
#    23644 non-null  object
#  31
# Safety & Security
#        25415 non-null  object
#  32
# Extras
#                   23480 non-null  object
#  33  Empty weight              17758 non-null  object
#  34  Model code                8367 non-null   object
#  35  General inspection        12254 non-null  object
#  36  Last service              2003 non-null   object
#  37  Full service history      12565 non-null  object
#  38  Non-smoker vehicle        11594 non-null  object
#  39  Emission class            17859 non-null  object
#  40  Emissions sticker         9414 non-null   object
#  41  Upholstery colour         14569 non-null  object
#  42  Upholstery                18610 non-null  object
#  43  Production date           5908 non-null   float64
#  44  Previous owner            14015 non-null  object
#  45  Other fuel types          2313 non-null   object
#  46  Power consumption         515 non-null    object
#  47  Energy efficiency class   7804 non-null   object
#  48  CO₂-efficiency            7804 non-null   object
#  49  Fuel consumption (WLTP)   100 non-null    object
#  50  CO₂-emissions (WLTP)      116 non-null    object
#  51  Available from            393 non-null    object
#  52  Taxi or rental car        422 non-null    object
#  53  Availability              301 non-null    object
#  54  Last timing belt change   572 non-null    object
#  55  Electric Range (WLTP)     16 non-null     object
#  56  Power consumption (WLTP)  16 non-null     object
#  57  Battery Ownership         7 non-null      object
# dtypes: float64(1), object(57)
# memory usage: 13.0+ MB

# %%
df.head(5).T
# Out:
#                                                                            0  \
# make_model                                               Mercedes-Benz A 160
# short_description                                                        CDi
# make                                                       \nMercedes-Benz\n
# model                                                        [\n, A 160 ,\n]
# location                   P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...
# price                                                             € 16,950.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7468157, \n]
# Warranty                                                 [\n, 24 months, \n]
# Mileage                                                           120,200 km
# First registration                                                   06/2016
# Gearbox                                                         [\nManual\n]
# Fuel type                                                             Diesel
# Colour                                                                 Black
# Paint                                                               Metallic
# desc                       [ , Precio al contado: 16950 euros,  ,  , Vehí...
# seller                                                                Dealer
# Seats                                                                    NaN
# Power                                                                    NaN
# Engine size                                                              NaN
# Gears                                                                    NaN
# CO₂-emissions                                                            NaN
# Manufacturer colour                                                      NaN
# Drivetrain                                                               NaN
# Cylinders                                                                NaN
# Fuel consumption                                                         NaN
# \nComfort & Convenience\n                                                NaN
# \nEntertainment & Media\n                                                NaN
# \nSafety & Security\n                                                    NaN
# \nExtras\n                                                               NaN
# Empty weight                                                             NaN
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                            1  \
# make_model                                             Mercedes-Benz EQE 350
# short_description                                                       350+
# make                                                       \nMercedes-Benz\n
# model                                                      [\n, EQE 350 ,\n]
# location                        APARTADO DE CORREOS 1032,  26140 LOGROÑO, ES
# price                                                             € 80,900.-
# Body type                                                  [\n, Compact, \n]
# Type                                                [\n, Pre-registered, \n]
# Doors                                                            [\n, 4, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7054863, \n]
# Warranty                                                 [\n, 24 months, \n]
# Mileage                                                             5,000 km
# First registration                                                   06/2022
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                           Electric
# Colour                                                                   NaN
# Paint                                                                    NaN
# desc                       [ , Precio al contado: 88900 euros,  , AUTO OJ...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n215 kW (292 hp)\n]
# Engine size                                                       [\n1 cc\n]
# Gears                                                                [\n9\n]
# CO₂-emissions                                                 0 g/km (comb.)
# Manufacturer colour                                          Negro Obsidiana
# Drivetrain                                                               NaN
# Cylinders                                                                NaN
# Fuel consumption                                                         NaN
# \nComfort & Convenience\n                                                NaN
# \nEntertainment & Media\n                                                NaN
# \nSafety & Security\n                                                    NaN
# \nExtras\n                                                               NaN
# Empty weight                                                             NaN
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                            2  \
# make_model                                            Mercedes-Benz A 45 AMG
# short_description                                           S 4Matic+ 8G-DCT
# make                                                       \nMercedes-Benz\n
# model                                                     [\n, A 45 AMG ,\n]
# location                   PORT. TARRACO, MOLL DE LLEVANT, Nº 5, LOC. 6-8...
# price                                                             € 69,900.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7410454, \n]
# Warranty                                                 [\n, 12 months, \n]
# Mileage                                                            18,900 km
# First registration                                                   07/2020
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                           Gasoline
# Colour                                                                  Grey
# Paint                                                                    NaN
# desc                       [Gris MANUFAKTUR mountaingrau magno,  , Linea/...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n310 kW (421 hp)\n]
# Engine size                                                   [\n1,991 cc\n]
# Gears                                                                [\n8\n]
# CO₂-emissions                                                            NaN
# Manufacturer colour                                       Mountaingrau magno
# Drivetrain                                                     [\n, 4WD, \n]
# Cylinders                                                            [\n4\n]
# Fuel consumption           [[8.4 l/100 km (comb.)], [10.9 l/100 km (city)...
# \nComfort & Convenience\n                                                NaN
# \nEntertainment & Media\n                                                NaN
# \nSafety & Security\n                                                    NaN
# \nExtras\n                                                               NaN
# Empty weight                                                             NaN
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                            3  \
# make_model                                            Mercedes-Benz A 35 AMG
# short_description                                             4Matic+ 7G-DCT
# make                                                       \nMercedes-Benz\n
# model                                                     [\n, A 35 AMG ,\n]
# location                   Carrer de Provença, 31 Local,  8029 BARCELONA, ES
# price                                                             € 46,990.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7464503, \n]
# Warranty                                                 [\n, 12 months, \n]
# Mileage                                                            18,995 km
# First registration                                                   01/2020
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                           Gasoline
# Colour                                                                Yellow
# Paint                                                                    NaN
# desc                       [ , Precio al contado: 48990 euros,  ,  , BONI...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n225 kW (306 hp)\n]
# Engine size                                                   [\n1,991 cc\n]
# Gears                                                                [\n7\n]
# CO₂-emissions                                                            NaN
# Manufacturer colour                                             Amarillo Sol
# Drivetrain                                                     [\n, 4WD, \n]
# Cylinders                                                            [\n4\n]
# Fuel consumption           [[7.3 l/100 km (comb.)], [9.3 l/100 km (city)]...
# \nComfort & Convenience\n  [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n                                              [USB]
# \nSafety & Security\n      [ABS, Central door lock, Driver-side airbag, E...
# \nExtras\n                                                     [Sport seats]
# Empty weight                                                             NaN
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                            4
# make_model                                            Mercedes-Benz A 45 AMG
# short_description                                   200CDI BE Line 4M 7G-DCT
# make                                                       \nMercedes-Benz\n
# model                                                     [\n, A 45 AMG ,\n]
# location                              CARRIL ARAGONES 4,  30007 CASILLAS, ES
# price                                                             € 16,800.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7127931, \n]
# Warranty                                                 [\n, 12 months, \n]
# Mileage                                                           197,000 km
# First registration                                                   09/2015
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                             Diesel
# Colour                                                                 White
# Paint                                                               Metallic
# desc                       [ , Precio al contado: 17400 euros,  , Vehícul...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n100 kW (136 hp)\n]
# Engine size                                                   [\n2,143 cc\n]
# Gears                                                                [\n7\n]
# CO₂-emissions                                                            NaN
# Manufacturer colour                                                      NaN
# Drivetrain                                                     [\n, 4WD, \n]
# Cylinders                                                            [\n4\n]
# Fuel consumption           [[4.9 l/100 km (comb.)], [5.7 l/100 km (city)]...
# \nComfort & Convenience\n  [Air conditioning, Electrical side mirrors, Mu...
# \nEntertainment & Media\n                   [Bluetooth, CD player, MP3, USB]
# \nSafety & Security\n      [ABS, Central door lock, Driver-side airbag, E...
# \nExtras\n                                                               NaN
# Empty weight                                                  [\n1,545 kg\n]
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN

# %%
df.describe()
# Out:
#        Production date
# count          5908.00
# mean           2018.00
# std               6.49
# min            1954.00
# 25%            2018.00
# 50%            2019.00
# 75%            2021.00
# max            2022.00

# %%
#df.describe(include=[object])

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'make', 'model', 'location', 'price',
#        'Body type', 'Type', 'Doors', 'Country version', 'Offer number',
#        'Warranty', 'Mileage', 'First registration', 'Gearbox', 'Fuel type',
#        'Colour', 'Paint', 'desc', 'seller', 'Seats', 'Power', 'Engine size',
#        'Gears', 'CO₂-emissions', 'Manufacturer colour', 'Drivetrain',
#        'Cylinders', 'Fuel consumption', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nSafety & Security\n', '\nExtras\n',
#        'Empty weight', 'Model code', 'General inspection', 'Last service',
#        'Full service history', 'Non-smoker vehicle', 'Emission class',
#        'Emissions sticker', 'Upholstery colour', 'Upholstery',
#        'Production date', 'Previous owner', 'Other fuel types',
#        'Power consumption', 'Energy efficiency class', 'CO₂-efficiency',
#        'Fuel consumption (WLTP)', 'CO₂-emissions (WLTP)', 'Available from',
#        'Taxi or rental car', 'Availability', 'Last timing belt change',
#        'Electric Range (WLTP)', 'Power consumption (WLTP)',
#        'Battery Ownership'],
#       dtype='object')

# %% [markdown]
# ##df["Comfort&Convenience"] = df["\nComfort & Convenience\n"]
# df["Entertainment&Media"] = df["\nEntertainment & Media\n"]
# df["Extras"] = df["\nExtras\n"]
# df["Safety_&ecurity"] = df["\nSafety & Security\n"]
#
# drop_columns = ["\nComfort & Convenience\n", "\nEntertainment & Media\n", "\nExtras\n", "\nSafety & Security\n"]
#
# df.drop(drop_columns, axis=1, inplace=True)
#
# df.head(3).T

# %%
df.rename(columns={'\nComfort & Convenience\n': 'Comfort&Convenience', 
                   '\nEntertainment & Media\n': 'Entertainment&Media', 
                   '\nExtras\n': '\nExtras\n', 
                   '\nSafety & Security\n': 'Safety&Security'}, inplace=True)
df.head(3).T
# Out:
#                                                                           0  \
# make_model                                              Mercedes-Benz A 160
# short_description                                                       CDi
# make                                                      \nMercedes-Benz\n
# model                                                       [\n, A 160 ,\n]
# location                  P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...
# price                                                            € 16,950.-
# Body type                                                 [\n, Compact, \n]
# Type                                                         [\n, Used, \n]
# Doors                                                           [\n, 5, \n]
# Country version                                             [\n, Spain, \n]
# Offer number                                              [\n, 7468157, \n]
# Warranty                                                [\n, 24 months, \n]
# Mileage                                                          120,200 km
# First registration                                                  06/2016
# Gearbox                                                        [\nManual\n]
# Fuel type                                                            Diesel
# Colour                                                                Black
# Paint                                                              Metallic
# desc                      [ , Precio al contado: 16950 euros,  ,  , Vehí...
# seller                                                               Dealer
# Seats                                                                   NaN
# Power                                                                   NaN
# Engine size                                                             NaN
# Gears                                                                   NaN
# CO₂-emissions                                                           NaN
# Manufacturer colour                                                     NaN
# Drivetrain                                                              NaN
# Cylinders                                                               NaN
# Fuel consumption                                                        NaN
# Comfort&Convenience                                                     NaN
# Entertainment&Media                                                     NaN
# Safety&Security                                                         NaN
# \nExtras\n                                                              NaN
# Empty weight                                                            NaN
# Model code                                                              NaN
# General inspection                                                      NaN
# Last service                                                            NaN
# Full service history                                                    NaN
# Non-smoker vehicle                                                      NaN
# Emission class                                                          NaN
# Emissions sticker                                                       NaN
# Upholstery colour                                                       NaN
# Upholstery                                                              NaN
# Production date                                                         NaN
# Previous owner                                                          NaN
# Other fuel types                                                        NaN
# Power consumption                                                       NaN
# Energy efficiency class                                                 NaN
# CO₂-efficiency                                                          NaN
# Fuel consumption (WLTP)                                                 NaN
# CO₂-emissions (WLTP)                                                    NaN
# Available from                                                          NaN
# Taxi or rental car                                                      NaN
# Availability                                                            NaN
# Last timing belt change                                                 NaN
# Electric Range (WLTP)                                                   NaN
# Power consumption (WLTP)                                                NaN
# Battery Ownership                                                       NaN
#
#                                                                           1  \
# make_model                                            Mercedes-Benz EQE 350
# short_description                                                      350+
# make                                                      \nMercedes-Benz\n
# model                                                     [\n, EQE 350 ,\n]
# location                       APARTADO DE CORREOS 1032,  26140 LOGROÑO, ES
# price                                                            € 80,900.-
# Body type                                                 [\n, Compact, \n]
# Type                                               [\n, Pre-registered, \n]
# Doors                                                           [\n, 4, \n]
# Country version                                             [\n, Spain, \n]
# Offer number                                              [\n, 7054863, \n]
# Warranty                                                [\n, 24 months, \n]
# Mileage                                                            5,000 km
# First registration                                                  06/2022
# Gearbox                                                     [\nAutomatic\n]
# Fuel type                                                          Electric
# Colour                                                                  NaN
# Paint                                                                   NaN
# desc                      [ , Precio al contado: 88900 euros,  , AUTO OJ...
# seller                                                               Dealer
# Seats                                                           [\n, 5, \n]
# Power                                                 [\n215 kW (292 hp)\n]
# Engine size                                                      [\n1 cc\n]
# Gears                                                               [\n9\n]
# CO₂-emissions                                                0 g/km (comb.)
# Manufacturer colour                                         Negro Obsidiana
# Drivetrain                                                              NaN
# Cylinders                                                               NaN
# Fuel consumption                                                        NaN
# Comfort&Convenience                                                     NaN
# Entertainment&Media                                                     NaN
# Safety&Security                                                         NaN
# \nExtras\n                                                              NaN
# Empty weight                                                            NaN
# Model code                                                              NaN
# General inspection                                                      NaN
# Last service                                                            NaN
# Full service history                                                    NaN
# Non-smoker vehicle                                                      NaN
# Emission class                                                          NaN
# Emissions sticker                                                       NaN
# Upholstery colour                                                       NaN
# Upholstery                                                              NaN
# Production date                                                         NaN
# Previous owner                                                          NaN
# Other fuel types                                                        NaN
# Power consumption                                                       NaN
# Energy efficiency class                                                 NaN
# CO₂-efficiency                                                          NaN
# Fuel consumption (WLTP)                                                 NaN
# CO₂-emissions (WLTP)                                                    NaN
# Available from                                                          NaN
# Taxi or rental car                                                      NaN
# Availability                                                            NaN
# Last timing belt change                                                 NaN
# Electric Range (WLTP)                                                   NaN
# Power consumption (WLTP)                                                NaN
# Battery Ownership                                                       NaN
#
#                                                                           2
# make_model                                           Mercedes-Benz A 45 AMG
# short_description                                          S 4Matic+ 8G-DCT
# make                                                      \nMercedes-Benz\n
# model                                                    [\n, A 45 AMG ,\n]
# location                  PORT. TARRACO, MOLL DE LLEVANT, Nº 5, LOC. 6-8...
# price                                                            € 69,900.-
# Body type                                                 [\n, Compact, \n]
# Type                                                         [\n, Used, \n]
# Doors                                                           [\n, 5, \n]
# Country version                                             [\n, Spain, \n]
# Offer number                                              [\n, 7410454, \n]
# Warranty                                                [\n, 12 months, \n]
# Mileage                                                           18,900 km
# First registration                                                  07/2020
# Gearbox                                                     [\nAutomatic\n]
# Fuel type                                                          Gasoline
# Colour                                                                 Grey
# Paint                                                                   NaN
# desc                      [Gris MANUFAKTUR mountaingrau magno,  , Linea/...
# seller                                                               Dealer
# Seats                                                           [\n, 5, \n]
# Power                                                 [\n310 kW (421 hp)\n]
# Engine size                                                  [\n1,991 cc\n]
# Gears                                                               [\n8\n]
# CO₂-emissions                                                           NaN
# Manufacturer colour                                      Mountaingrau magno
# Drivetrain                                                    [\n, 4WD, \n]
# Cylinders                                                           [\n4\n]
# Fuel consumption          [[8.4 l/100 km (comb.)], [10.9 l/100 km (city)...
# Comfort&Convenience                                                     NaN
# Entertainment&Media                                                     NaN
# Safety&Security                                                         NaN
# \nExtras\n                                                              NaN
# Empty weight                                                            NaN
# Model code                                                              NaN
# General inspection                                                      NaN
# Last service                                                            NaN
# Full service history                                                    NaN
# Non-smoker vehicle                                                      NaN
# Emission class                                                          NaN
# Emissions sticker                                                       NaN
# Upholstery colour                                                       NaN
# Upholstery                                                              NaN
# Production date                                                         NaN
# Previous owner                                                          NaN
# Other fuel types                                                        NaN
# Power consumption                                                       NaN
# Energy efficiency class                                                 NaN
# CO₂-efficiency                                                          NaN
# Fuel consumption (WLTP)                                                 NaN
# CO₂-emissions (WLTP)                                                    NaN
# Available from                                                          NaN
# Taxi or rental car                                                      NaN
# Availability                                                            NaN
# Last timing belt change                                                 NaN
# Electric Range (WLTP)                                                   NaN
# Power consumption (WLTP)                                                NaN
# Battery Ownership                                                       NaN

# %%
df.isnull().sum()
# Out:
# make_model                    850
# short_description             850
# make                          850
# model                         850
# location                      850
# price                         850
# Body type                     850
# Type                          850
# Doors                        1209
# Country version             12591
# Offer number                 6380
# Warranty                    13696
# Mileage                       851
# First registration            852
# Gearbox                      1098
# Fuel type                    2637
# Colour                       2574
# Paint                       14985
# desc                         1433
# seller                        850
# Seats                        3975
# Power                        1422
# Engine size                  2253
# Gears                       10526
# CO₂-emissions               10886
# Manufacturer colour          7693
# Drivetrain                  12587
# Cylinders                   10628
# Fuel consumption             6095
# Empty weight                11722
# Model code                  21113
# General inspection          17226
# Last service                27477
# Full service history        16915
# Non-smoker vehicle          17886
# Emission class              11621
# Emissions sticker           20066
# Upholstery colour           14911
# Upholstery                  10870
# Production date             23572
# Previous owner              15465
# Other fuel types            27167
# Power consumption           28965
# Energy efficiency class     21676
# CO₂-efficiency              21676
# Fuel consumption (WLTP)     29380
# CO₂-emissions (WLTP)        29364
# Available from              29087
# Taxi or rental car          29058
# Availability                29179
# Last timing belt change     28908
# Electric Range (WLTP)       29464
# Power consumption (WLTP)    29464
# Battery Ownership           29473
# Comfort&Convenience          4047
# Entertainment&Media          5836
# Extras                       6000
# Safety_&ecurity              4065
# dtype: int64

# %%
is_null = pd.DataFrame(df.isnull().sum(), columns = ['isnull'])
is_null
# Out:
#                           isnull
# make_model                   850
# short_description            850
# make                         850
# model                        850
# location                     850
# price                        850
# Body type                    850
# Type                         850
# Doors                       1209
# Country version            12591
# Offer number                6380
# Warranty                   13696
# Mileage                      851
# First registration           852
# Gearbox                     1098
# Fuel type                   2637
# Colour                      2574
# Paint                      14985
# desc                        1433
# seller                       850
# Seats                       3975
# Power                       1422
# Engine size                 2253
# Gears                      10526
# CO₂-emissions              10886
# Manufacturer colour         7693
# Drivetrain                 12587
# Cylinders                  10628
# Fuel consumption            6095
# Comfort&Convenience         4047
# Entertainment&Media         5836
# Safety&Security             4065
# Extras                      6000
# Empty weight               11722
# Model code                 21113
# General inspection         17226
# Last service               27477
# Full service history       16915
# Non-smoker vehicle         17886
# Emission class             11621
# Emissions sticker          20066
# Upholstery colour          14911
# Upholstery                 10870
# Production date            23572
# Previous owner             15465
# Other fuel types           27167
# Power consumption          28965
# Energy efficiency class    21676
# CO₂-efficiency             21676
# Fuel consumption (WLTP)    29380
# CO₂-emissions (WLTP)       29364
# Available from             29087
# Taxi or rental car         29058
# Availability               29179
# Last timing belt change    28908
# Electric Range (WLTP)      29464
# Power consumption (WLTP)   29464
# Battery Ownership          29473

# %%
percentage_null = pd.DataFrame(df.isnull().sum()/df.shape[0]*100, columns = ['percentage_null'])
percentage_null
# Out:
#                           percentage_null
# make_model                           2.88
# short_description                    2.88
# make                                 2.88
# model                                2.88
# location                             2.88
# price                                2.88
# Body type                            2.88
# Type                                 2.88
# Doors                                4.10
# Country version                     42.71
# Offer number                        21.64
# Warranty                            46.46
# Mileage                              2.89
# First registration                   2.89
# Gearbox                              3.72
# Fuel type                            8.95
# Colour                               8.73
# Paint                               50.83
# desc                                 4.86
# seller                               2.88
# Seats                               13.48
# Power                                4.82
# Engine size                          7.64
# Gears                               35.71
# CO₂-emissions                       36.93
# Manufacturer colour                 26.10
# Drivetrain                          42.70
# Cylinders                           36.05
# Fuel consumption                    20.68
# Empty weight                        39.76
# Model code                          71.62
# General inspection                  58.43
# Last service                        93.21
# Full service history                57.38
# Non-smoker vehicle                  60.67
# Emission class                      39.42
# Emissions sticker                   68.07
# Upholstery colour                   50.58
# Upholstery                          36.87
# Production date                     79.96
# Previous owner                      52.46
# Other fuel types                    92.15
# Power consumption                   98.25
# Energy efficiency class             73.53
# CO₂-efficiency                      73.53
# Fuel consumption (WLTP)             99.66
# CO₂-emissions (WLTP)                99.61
# Available from                      98.67
# Taxi or rental car                  98.57
# Availability                        98.98
# Last timing belt change             98.06
# Electric Range (WLTP)               99.95
# Power consumption (WLTP)            99.95
# Battery Ownership                   99.98
# Comfort&Convenience                 13.73
# Entertainment&Media                 19.80
# Extras                              20.35
# Safety_&ecurity                     13.79

# %%
summary_null = pd.concat([is_null, percentage_null], axis = 1).reset_index().rename({'index':'Columns'},axis = 1)
summary_null
# Out:
#                      Columns   isnull  percentage_null
# 0                 make_model   850.00             2.88
# 1          short_description   850.00             2.88
# 2                       make   850.00             2.88
# 3                      model   850.00             2.88
# 4                   location   850.00             2.88
# 5                      price   850.00             2.88
# 6                  Body type   850.00             2.88
# 7                       Type   850.00             2.88
# 8                      Doors  1209.00             4.10
# 9            Country version 12591.00            42.71
# 10              Offer number  6380.00            21.64
# 11                  Warranty 13696.00            46.46
# 12                   Mileage   851.00             2.89
# 13        First registration   852.00             2.89
# 14                   Gearbox  1098.00             3.72
# 15                 Fuel type  2637.00             8.95
# 16                    Colour  2574.00             8.73
# 17                     Paint 14985.00            50.83
# 18                      desc  1433.00             4.86
# 19                    seller   850.00             2.88
# 20                     Seats  3975.00            13.48
# 21                     Power  1422.00             4.82
# 22               Engine size  2253.00             7.64
# 23                     Gears 10526.00            35.71
# 24             CO₂-emissions 10886.00            36.93
# 25       Manufacturer colour  7693.00            26.10
# 26                Drivetrain 12587.00            42.70
# 27                 Cylinders 10628.00            36.05
# 28          Fuel consumption  6095.00            20.68
# 29       Comfort&Convenience  4047.00            13.73
# 30       Entertainment&Media  5836.00            19.80
# 31           Safety&Security  4065.00              NaN
# 32                    Extras  6000.00            20.35
# 33              Empty weight 11722.00            39.76
# 34                Model code 21113.00            71.62
# 35        General inspection 17226.00            58.43
# 36              Last service 27477.00            93.21
# 37      Full service history 16915.00            57.38
# 38        Non-smoker vehicle 17886.00            60.67
# 39            Emission class 11621.00            39.42
# 40         Emissions sticker 20066.00            68.07
# 41         Upholstery colour 14911.00            50.58
# 42                Upholstery 10870.00            36.87
# 43           Production date 23572.00            79.96
# 44            Previous owner 15465.00            52.46
# 45          Other fuel types 27167.00            92.15
# 46         Power consumption 28965.00            98.25
# 47   Energy efficiency class 21676.00            73.53
# 48            CO₂-efficiency 21676.00            73.53
# 49   Fuel consumption (WLTP) 29380.00            99.66
# 50      CO₂-emissions (WLTP) 29364.00            99.61
# 51            Available from 29087.00            98.67
# 52        Taxi or rental car 29058.00            98.57
# 53              Availability 29179.00            98.98
# 54   Last timing belt change 28908.00            98.06
# 55     Electric Range (WLTP) 29464.00            99.95
# 56  Power consumption (WLTP) 29464.00            99.95
# 57         Battery Ownership 29473.00            99.98
# 58           Safety_&ecurity      NaN            13.79

# %%
missing = df.isnull().sum()*100 / df.shape[0]

# %%
missing.loc[lambda x : x >= 70] #%70
# Out:
# Model code                 71.62
# Last service               93.21
# Production date            79.96
# Other fuel types           92.15
# Power consumption          98.25
# Energy efficiency class    73.53
# CO₂-efficiency             73.53
# Fuel consumption (WLTP)    99.66
# CO₂-emissions (WLTP)       99.61
# Available from             98.67
# Taxi or rental car         98.57
# Availability               98.98
# Last timing belt change    98.06
# Electric Range (WLTP)      99.95
# Power consumption (WLTP)   99.95
# Battery Ownership          99.98
# dtype: float64

# %% [markdown]
# # BUNDAN SONRASI HUSEYIN K.

# %%
df.columns[20:40]
# Out:
# Index(['Seats', 'Power', 'Engine size', 'Gears', 'CO₂-emissions',
#        'Manufacturer colour', 'Drivetrain', 'Cylinders', 'Fuel consumption',
#        'Comfort&Convenience', 'Entertainment&Media', 'Safety&Security',
#        'Extras', 'Empty weight', 'Model code', 'General inspection',
#        'Last service', 'Full service history', 'Non-smoker vehicle',
#        'Emission class'],
#       dtype='object')

# %%
df['Seats'].value_counts()
# Out:
# [\n, 5, \n]     18308
# [\n, 4, \n]      5390
# [\n, 2, \n]      1186
# [\n, 7, \n]       488
# [\n, 8, \n]        43
# [\n, 9, \n]        35
# [\n, 3, \n]        25
# [\n, 6, \n]        12
# [\n, 0, \n]         9
# [\n, 1, \n]         7
# [\n, 17, \n]        2
# Name: Seats, dtype: int64

# %%
df['Seats'] = df['Seats'].apply(lambda t: int(str(t).split(',')[1].strip()) if pd.notnull(t) else t)
df['Seats'].value_counts()
# Out:
# 5.00     18308
# 4.00      5390
# 2.00      1186
# 7.00       488
# 8.00        43
# 9.00        35
# 3.00        25
# 6.00        12
# 0.00         9
# 1.00         7
# 17.00        2
# Name: Seats, dtype: int64

# %%
df['Power'].value_counts()
# Out:
# [\n110 kW (150 hp)\n]      1992
# [\n96 kW (131 hp)\n]       1356
# [\n88 kW (120 hp)\n]       1182
# [\n81 kW (110 hp)\n]       1166
# [\n66 kW (90 hp)\n]        1110
#                            ...
# [\n746 kW (1,014 hp)\n]       1
# [\n570 kW (775 hp)\n]         1
# [\n471 kW (640 hp)\n]         1
# [\n179 kW (243 hp)\n]         1
# [\n26 kW (35 hp)\n]           1
# Name: Power, Length: 351, dtype: int64

# %%
df['Power'] = df['Power'].apply(lambda t: int(re.findall(r'\d+', str(t))[0]) if pd.notnull(t) else t)
df['Power'].value_counts()
# Out:
# 110.00    1992
# 96.00     1356
# 88.00     1182
# 81.00     1166
# 66.00     1110
#           ...
# 746.00       1
# 570.00       1
# 471.00       1
# 179.00       1
# 26.00        1
# Name: Power, Length: 351, dtype: int64

# %%
df['Engine size'].value_counts()
# Out:
# [\n1,598 cc\n]    2099
# [\n999 cc\n]      2068
# [\n1,969 cc\n]    1929
# [\n1,461 cc\n]    1110
# [\n1,998 cc\n]    1000
#                   ...
# [\n2,753 cc\n]       1
# [\n2,495 cc\n]       1
# [\n200 cc\n]         1
# [\n3,224 cc\n]       1
# [\n2,473 cc\n]       1
# Name: Engine size, Length: 467, dtype: int64

# %%
df['Engine size']=df['Engine size'].apply(lambda t: t[0].replace(',','') if pd.notnull(t) else t)
df['Engine size'] = df['Engine size'].apply(lambda t: int(re.findall(r'\d+', str(t))[0]) if pd.notnull(t) else t)
df['Engine size'].value_counts()
# Out:
# 1598.00    2099
# 999.00     2068
# 1969.00    1929
# 1461.00    1110
# 1998.00    1000
#            ...
# 2753.00       1
# 2495.00       1
# 200.00        1
# 3224.00       1
# 2473.00       1
# Name: Engine size, Length: 467, dtype: int64

# %%
df['Gears'].value_counts()
# Out:
# [\n6\n]     8412
# [\n5\n]     5335
# [\n7\n]     1738
# [\n8\n]     1690
# [\n1\n]      712
# [\n9\n]      642
# [\n4\n]      256
# [\n10\n]     112
# [\n0\n]       31
# [\n3\n]       24
# [\n2\n]        2
# Name: Gears, dtype: int64

# %%
df['Gears'] = df['Gears'].apply(lambda t: int(re.findall(r'\d+', str(t))[0]) if pd.notnull(t) else t)
df['Gears'].value_counts()
# Out:
# 6.00     8412
# 5.00     5335
# 7.00     1738
# 8.00     1690
# 1.00      712
# 9.00      642
# 4.00      256
# 10.00     112
# 0.00       31
# 3.00       24
# 2.00        2
# Name: Gears, dtype: int64

# %%
df['CO₂-emissions'].value_counts()
# Out:
# 0 g/km (comb.)       1038
# 119 g/km (comb.)      393
# 124 g/km (comb.)      340
# 129 g/km (comb.)      319
# 114 g/km (comb.)      313
#                      ...
# 7 g/km (comb.)          1
# 80 g/km (comb.)         1
# 196  g/km (comb.)       1
# 100  g/km (comb.)       1
# 53 g/km (comb.)         1
# Name: CO₂-emissions, Length: 347, dtype: int64

# %%
df['CO₂-emissions'] = df['CO₂-emissions'].apply(lambda t: int(re.findall(r'\d+', str(t))[0]) if pd.notnull(t) else t)
df['CO₂-emissions'].value_counts()
# Out:
# 0.00      1040
# 119.00     393
# 124.00     340
# 129.00     319
# 114.00     313
#           ...
# 272.00       1
# 344.00       1
# 342.00       1
# 398.00       1
# 53.00        1
# Name: CO₂-emissions, Length: 326, dtype: int64

# %%
# The 'CO₂-emissions' column can be dropped later, because there are several other columns showing the similar feature, such as 'Emission class and 'Emisssions sticker'. .

# %%
df['Manufacturer colour'].value_counts()
# Out:
# Blanco                            1235
# Gris                               671
# Azul                               552
# Negro                              546
# Rojo                               381
#                                   ...
# Colore esterno (snowflake whit       1
# Pompeigraumetallic                   1
# Cararragrau                          1
# ICE WHITE (wit metallic)             1
# Denim Blue metallic (blauw met       1
# Name: Manufacturer colour, Length: 4963, dtype: int64

# %%
# The 'Manufacrurer colour' column can be dropped later, because it has 4963 distinct values with description of colours by manufacturers in different languages. The 'Colour' column can be used instead. It has 14 distinct values already including almost all auto colours.

# %%
df['Drivetrain'].value_counts()
# Out:
# [\n, Front, \n]    12066
# [\n, 4WD, \n]       3252
# [\n, Rear, \n]      1575
# Name: Drivetrain, dtype: int64

# %%
df['Drivetrain']=df['Drivetrain'].apply(lambda t: str(t).split(',')[1].strip() if pd.notnull(t) else t)
df['Drivetrain'].value_counts()
# Out:
# Front    12066
# 4WD       3252
# Rear      1575
# Name: Drivetrain, dtype: int64

# %%
df['Cylinders'].value_counts()
# Out:
# [\n4\n]     13068
# [\n3\n]      3258
# [\n6\n]      1013
# [\n5\n]       799
# [\n8\n]       539
# [\n2\n]       103
# [\n0\n]        35
# [\n1\n]        21
# [\n12\n]        8
# [\n7\n]         6
# [\n26\n]        1
# [\n16\n]        1
# Name: Cylinders, dtype: int64

# %%
df['Cylinders'] = df['Cylinders'].apply(lambda t: int(re.findall(r'\d+', str(t))[0]) if pd.notnull(t) else t)
df['Cylinders'].value_counts()
# Out:
# 4.00     13068
# 3.00      3258
# 6.00      1013
# 5.00       799
# 8.00       539
# 2.00       103
# 0.00        35
# 1.00        21
# 12.00        8
# 7.00         6
# 26.00        1
# 16.00        1
# Name: Cylinders, dtype: int64

# %%
df['Fuel consumption'].value_counts()
# Out:
# [[0 l/100 km (comb.)]]                                                         330
# [[0 l/100 km (comb.)], [0 l/100 km (city)], [0 l/100 km (country)]]            306
# [[3.4 l/100 km (comb.)], [3.7 l/100 km (city)], [3.2 l/100 km (country)]]      170
# [[4 l/100 km (comb.)]]                                                         149
# [[3.9 l/100 km (comb.)]]                                                       133
#                                                                               ...
# [[5.2 l/100 km (comb.)], [5.6 l/100 km (city)], [5 l/100 km (country)]]          1
# [[5 l/100 km (comb.)], [4.4 l/100 km (city)], [3.6 l/100 km (country)]]          1
# [[5.5 l/100 km (comb.)], [4.8 l/100 km (city)], [3.9 l/100 km (country)]]        1
# [[4.8 l/100 km (comb.)], [5.5 l/100 km (city)], [4.3 l/100 km (country)]]        1
# [[10.4 l/100 km (comb.)], [15.3 l/100 km (city)], [7.6 l/100 km (country)]]      1
# Name: Fuel consumption, Length: 3452, dtype: int64

# %%
df[df['Fuel consumption'].notnull()]['Fuel consumption'].apply(lambda x: x[0])
# Out:
# 2         [8.4 l/100 km (comb.)]
# 3         [7.3 l/100 km (comb.)]
# 4         [4.9 l/100 km (comb.)]
# 5         [8.2 l/100 km (comb.)]
# 7         [6.1 l/100 km (comb.)]
#                   ...
# 29474       [2 l/100 km (comb.)]
# 29475     [9.1 l/100 km (comb.)]
# 29476     [3.8 l/100 km (comb.)]
# 29477     [6.5 l/100 km (comb.)]
# 29478    [10.4 l/100 km (comb.)]
# Name: Fuel consumption, Length: 23385, dtype: object

# %%
df['Fuel consumption2'] = df['Fuel consumption'].apply(lambda t: int(re.findall(r'\d+', str(t[0]))[0]) if pd.notnull(t) else t)
df['Fuel consumption2'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25908\4077242193.py in <module>
# ----> 1 df['Fuel consumption2'] = df['Fuel consumption'].apply(lambda t: int(re.findall(r'\d+', str(t[0]))[0]) if pd.notnull(t) else t)
#       2 df['Fuel consumption2'].value_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1141                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142                 # "Callable[[Any], Any]"
# -> 1143                 mapped = lib.map_infer(
#    1144                     values,
#    1145                     f,  # type: ignore[arg-type]
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp\ipykernel_25908\4077242193.py in <lambda>(t)
# ----> 1 df['Fuel consumption2'] = df['Fuel consumption'].apply(lambda t: int(re.findall(r'\d+', str(t[0]))[0]) if pd.notnull(t) else t)
#       2 df['Fuel consumption2'].value_counts()
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
df['Comfort&Convenience'].value_counts()
# Out:
# [Air conditioning, Automatic climate control, Electrical side mirrors, Multi-function steering wheel, Power windows]                                                                                                                                          244
# [Air conditioning, Automatic climate control, Cruise control]                                                                                                                                                                                                 171
# [Air conditioning, Automatic climate control, Cruise control, Electrical side mirrors, Multi-function steering wheel, Power windows]                                                                                                                          168
# [Air conditioning]                                                                                                                                                                                                                                            157
# [Power windows]                                                                                                                                                                                                                                               150
#                                                                                                                                                                                                                                                              ...
# [Air conditioning, Automatic climate control, Multi-function steering wheel, Parking assist system sensors front, Parking assist system sensors rear, Split rear seats]                                                                                         1
# [Air conditioning, Electrical side mirrors, Leather steering wheel, Power windows, Seat heating, Tinted windows, Wind deflector]                                                                                                                                1
# [Air conditioning, Electrical side mirrors, Hill Holder, Power windows, Tinted windows]                                                                                                                                                                         1
# [Air conditioning, Automatic climate control, Electrical side mirrors, Leather steering wheel, Light sensor, Multi-function steering wheel, Parking assist system camera, Power windows, Rain sensor, Split rear seats, Start-stop system, Tinted windows]      1
# [Air conditioning, Armrest, Cruise control, Electrical side mirrors, Leather steering wheel, Lumbar support, Multi-function steering wheel, Navigation system, Power windows, Seat heating, Tinted windows]                                                     1
# Name: Comfort&Convenience, Length: 14438, dtype: int64

# %%
df['Entertainment&Media'].value_counts()
# Out:
# [Bluetooth, USB]                                                                                                                                                             753
# [Bluetooth]                                                                                                                                                                  665
# [On-board computer]                                                                                                                                                          662
# [CD player, On-board computer, Radio]                                                                                                                                        644
# [Radio]                                                                                                                                                                      425
#                                                                                                                                                                             ...
# [Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, Sound system, WLAN / WiFi hotspot]      1
# [Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Sound system, USB, WLAN / WiFi hotspot]            1
# [Digital cockpit, Digital radio, On-board computer, Radio]                                                                                                                     1
# [Android Auto, Apple CarPlay, Digital radio, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot]                                                                 1
# [Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB]                                                                                              1
# Name: Entertainment&Media, Length: 1944, dtype: int64

# %%
df['Safety&Security'].value_counts()
# Out:
# [Isofix]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       380
# [ABS, Central door lock, Driver-side airbag, Electronic stability control, Immobilizer, Isofix, Passenger-side airbag, Power steering, Side airbag]                                                                                                                                                                                                                                                                                                                                                                            328
# [ABS, Central door lock, Driver-side airbag, Immobilizer, Isofix, Passenger-side airbag, Power steering, Side airbag, Traction control]                                                                                                                                                                                                                                                                                                                                                                                        125
# [ABS, Central door lock, Driver-side airbag, Electronic stability control, Fog lights, Isofix, Power steering, Side airbag]                                                                                                                                                                                                                                                                                                                                                                                                    121
# [ABS, Fog lights, Side airbag]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 100
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# [Daytime running lights, Emergency brake assistant, Fog lights, Isofix, LED Daytime Running Lights, Lane departure warning system, Power steering, Tire pressure monitoring system]                                                                                                                                                                                                                                                                                                                                              1
# [ABS, Adaptive Cruise Control, Central door lock, Daytime running lights, Driver drowsiness detection, Driver-side airbag, Electronic stability control, Emergency brake assistant, Emergency system, Fog lights, Full-LED headlights, Glare-free high beam headlights, Immobilizer, Isofix, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control]                                                                               1
# [ABS, Driver-side airbag, Electronic stability control, Emergency brake assistant, Immobilizer, LED Daytime Running Lights, Passenger-side airbag, Side airbag, Tire pressure monitoring system, Traction control]                                                                                                                                                                                                                                                                                                               1
# [ABS, Blind spot monitor, Central door lock, Daytime running lights, Distance warning system, Driver drowsiness detection, Driver-side airbag, Electronic stability control, Emergency system, Fog lights, Full-LED headlights, Head airbag, High beam assist, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Side airbag, Speed limit control system, Tire pressure monitoring system, Traction control, Traffic sign recognition]      1
# [ABS, Alarm system, Central door lock, Central door lock with remote control, Driver-side airbag, Electronic stability control, Fog lights, Head airbag, Immobilizer, Power steering, Side airbag, Traction control]                                                                                                                                                                                                                                                                                                             1
# Name: Safety&Security, Length: 12549, dtype: int64

# %%
df['Extras'].value_counts()

# %%
# The 'Model code' column can be dropped later, because 71.62% of the values is null.
percentage_null.loc['Model code']
# Out:
# percentage_null   71.62
# Name: Model code, dtype: float64

# %%
# The 'Last service' column can be dropped later, because 93.21% of the values is null.
percentage_null.loc['Last service']
# Out:
# percentage_null   93.21
# Name: Last service, dtype: float64

# %%
df.drop('Cylinders2', axis=1, inplace=True)

# %%
df.head(3).T
# Out:
#                                                                           0  \
# make_model                                              Mercedes-Benz A 160
# short_description                                                       CDi
# make                                                      \nMercedes-Benz\n
# model                                                       [\n, A 160 ,\n]
# location                  P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...
# price                                                            € 16,950.-
# Body type                                                 [\n, Compact, \n]
# Type                                                         [\n, Used, \n]
# Doors                                                           [\n, 5, \n]
# Country version                                             [\n, Spain, \n]
# Offer number                                              [\n, 7468157, \n]
# Warranty                                                [\n, 24 months, \n]
# Mileage                                                          120,200 km
# First registration                                                  06/2016
# Gearbox                                                        [\nManual\n]
# Fuel type                                                            Diesel
# Colour                                                                Black
# Paint                                                              Metallic
# desc                      [ , Precio al contado: 16950 euros,  ,  , Vehí...
# seller                                                               Dealer
# Seats                                                                   NaN
# Power                                                                   NaN
# Engine size                                                             NaN
# Gears                                                                   NaN
# CO₂-emissions                                                           NaN
# Manufacturer colour                                                     NaN
# Drivetrain                                                              NaN
# Cylinders                                                               NaN
# Fuel consumption                                                        NaN
# Comfort&Convenience                                                     NaN
# Entertainment&Media                                                     NaN
# Safety&Security                                                         NaN
# Extras                                                                  NaN
# Empty weight                                                            NaN
# Model code                                                              NaN
# General inspection                                                      NaN
# Last service                                                            NaN
# Full service history                                                    NaN
# Non-smoker vehicle                                                      NaN
# Emission class                                                          NaN
# Emissions sticker                                                       NaN
# Upholstery colour                                                       NaN
# Upholstery                                                              NaN
# Production date                                                         NaN
# Previous owner                                                          NaN
# Other fuel types                                                        NaN
# Power consumption                                                       NaN
# Energy efficiency class                                                 NaN
# CO₂-efficiency                                                          NaN
# Fuel consumption (WLTP)                                                 NaN
# CO₂-emissions (WLTP)                                                    NaN
# Available from                                                          NaN
# Taxi or rental car                                                      NaN
# Availability                                                            NaN
# Last timing belt change                                                 NaN
# Electric Range (WLTP)                                                   NaN
# Power consumption (WLTP)                                                NaN
# Battery Ownership                                                       NaN
#
#                                                                           1  \
# make_model                                            Mercedes-Benz EQE 350
# short_description                                                      350+
# make                                                      \nMercedes-Benz\n
# model                                                     [\n, EQE 350 ,\n]
# location                       APARTADO DE CORREOS 1032,  26140 LOGROÑO, ES
# price                                                            € 80,900.-
# Body type                                                 [\n, Compact, \n]
# Type                                               [\n, Pre-registered, \n]
# Doors                                                           [\n, 4, \n]
# Country version                                             [\n, Spain, \n]
# Offer number                                              [\n, 7054863, \n]
# Warranty                                                [\n, 24 months, \n]
# Mileage                                                            5,000 km
# First registration                                                  06/2022
# Gearbox                                                     [\nAutomatic\n]
# Fuel type                                                          Electric
# Colour                                                                  NaN
# Paint                                                                   NaN
# desc                      [ , Precio al contado: 88900 euros,  , AUTO OJ...
# seller                                                               Dealer
# Seats                                                                  5.00
# Power                                                                215.00
# Engine size                                                            1.00
# Gears                                                                  9.00
# CO₂-emissions                                                          0.00
# Manufacturer colour                                         Negro Obsidiana
# Drivetrain                                                              NaN
# Cylinders                                                               NaN
# Fuel consumption                                                        NaN
# Comfort&Convenience                                                     NaN
# Entertainment&Media                                                     NaN
# Safety&Security                                                         NaN
# Extras                                                                  NaN
# Empty weight                                                            NaN
# Model code                                                              NaN
# General inspection                                                      NaN
# Last service                                                            NaN
# Full service history                                                    NaN
# Non-smoker vehicle                                                      NaN
# Emission class                                                          NaN
# Emissions sticker                                                       NaN
# Upholstery colour                                                       NaN
# Upholstery                                                              NaN
# Production date                                                         NaN
# Previous owner                                                          NaN
# Other fuel types                                                        NaN
# Power consumption                                                       NaN
# Energy efficiency class                                                 NaN
# CO₂-efficiency                                                          NaN
# Fuel consumption (WLTP)                                                 NaN
# CO₂-emissions (WLTP)                                                    NaN
# Available from                                                          NaN
# Taxi or rental car                                                      NaN
# Availability                                                            NaN
# Last timing belt change                                                 NaN
# Electric Range (WLTP)                                                   NaN
# Power consumption (WLTP)                                                NaN
# Battery Ownership                                                       NaN
#
#                                                                           2
# make_model                                           Mercedes-Benz A 45 AMG
# short_description                                          S 4Matic+ 8G-DCT
# make                                                      \nMercedes-Benz\n
# model                                                    [\n, A 45 AMG ,\n]
# location                  PORT. TARRACO, MOLL DE LLEVANT, Nº 5, LOC. 6-8...
# price                                                            € 69,900.-
# Body type                                                 [\n, Compact, \n]
# Type                                                         [\n, Used, \n]
# Doors                                                           [\n, 5, \n]
# Country version                                             [\n, Spain, \n]
# Offer number                                              [\n, 7410454, \n]
# Warranty                                                [\n, 12 months, \n]
# Mileage                                                           18,900 km
# First registration                                                  07/2020
# Gearbox                                                     [\nAutomatic\n]
# Fuel type                                                          Gasoline
# Colour                                                                 Grey
# Paint                                                                   NaN
# desc                      [Gris MANUFAKTUR mountaingrau magno,  , Linea/...
# seller                                                               Dealer
# Seats                                                                  5.00
# Power                                                                310.00
# Engine size                                                         1991.00
# Gears                                                                  8.00
# CO₂-emissions                                                           NaN
# Manufacturer colour                                      Mountaingrau magno
# Drivetrain                                                              4WD
# Cylinders                                                              4.00
# Fuel consumption          [[8.4 l/100 km (comb.)], [10.9 l/100 km (city)...
# Comfort&Convenience                                                     NaN
# Entertainment&Media                                                     NaN
# Safety&Security                                                         NaN
# Extras                                                                  NaN
# Empty weight                                                            NaN
# Model code                                                              NaN
# General inspection                                                      NaN
# Last service                                                            NaN
# Full service history                                                    NaN
# Non-smoker vehicle                                                      NaN
# Emission class                                                          NaN
# Emissions sticker                                                       NaN
# Upholstery colour                                                       NaN
# Upholstery                                                              NaN
# Production date                                                         NaN
# Previous owner                                                          NaN
# Other fuel types                                                        NaN
# Power consumption                                                       NaN
# Energy efficiency class                                                 NaN
# CO₂-efficiency                                                          NaN
# Fuel consumption (WLTP)                                                 NaN
# CO₂-emissions (WLTP)                                                    NaN
# Available from                                                          NaN
# Taxi or rental car                                                      NaN
# Availability                                                            NaN
# Last timing belt change                                                 NaN
# Electric Range (WLTP)                                                   NaN
# Power consumption (WLTP)                                                NaN
# Battery Ownership                                                       NaN

# %% [markdown]
# # PART- 2 `( Handling With Missing Values )`

# %% [markdown]
# # PART- 3 `( Handling With Outliers )`

# %% [markdown]
# # Final Step (Checking final situation of data via graphs)

# %% [markdown]
# ## Export dataframe to csv file (without dummy)

# %%
df.to_csv("final_scout_not_dummy.csv", index=False)

# %% [markdown]
# # Dummy Operation

# %% [markdown]
# ## Export dataframe to csv file (dummy)

# %%
df_dummied.to_csv("final_scout_dummy.csv", index=False)
