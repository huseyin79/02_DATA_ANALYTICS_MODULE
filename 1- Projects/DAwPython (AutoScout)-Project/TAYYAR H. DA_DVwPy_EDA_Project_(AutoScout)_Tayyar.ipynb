# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">DA & DVwPY</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Exploratory Data Analysis (EDA) Project</p>
#
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">AutoScout Car Price Prediction EDA</p>

# %% [markdown]
# ## Introduction
# Welcome to "***AutoScout Exploratory Data Analysis (EDA) Project***". This is the project of completing ***Data Analysis & Data Visualization*** Courses and a successful hand-over is mandatory for getting certification for both courses. **Auto Scout** data used in this project scraped from the Website of an online car trading company in 2022, and contains many features of 13 different car makes including 594 models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using a variety of Python libraries, such as Numpy, Pandas, Matplotlib, Seaborn, Scipy, and then you will get a clean dataset for your analysis and pretictive modelling in Machine Learning Path. So you will have the chance to use all the skills you have already learned in the Data Analysis and Visualization courses.
#
# **``In this context, the project consists of 3 parts in general:``**
# * **The first part** is related to ``'Data Cleaning'``. It deals with Incorrect Headers, Incorrect Format, Anomalies, and Dropping useless columns.
# * **The second part** is related to ``'Filling Data'``, in other words 'Imputation'. It deals with Missing Values. Categorical to numeric transformation, Encoding, is done as well.
# * **The third part** is related to ``'Handling Outliers of Data'`` via Visualization libraries. So, some insights will be extracted.
#
# **``SPECIAL NOTE:``**  However, you are ``free to create your own style``. You do ``NOT`` have to stick to the steps above. Nevertheless, we, the DA & DV instructors, recommend you study each part separately to create a source notebook for your further studies.
#
# In order to build your Portfolio in terms of the GitHub account, you need to push your solution file up to your own repository.
#
# Please after solving the task, commit your notebook to GitHub and submit its link to LMS page where the project is settled down.
#
# **BE NOTED:** Please ``DO NOT FORGET`` to click the submit button.
#
# ### Some Reminders on Exploratory data analysis (EDA)
#
# Exploratory data analysis (EDA) is an especially important activity in the routine of a data analyst or scientist. It enables an in depth understanding of the dataset, define or discard hypotheses and create predictive models on a solid basis. It uses data manipulation techniques and several statistical tools to describe and understand the relationship between variables and how these can impact business. By means of EDA, we can obtain meaningful insights that can impact analysis under the following questions (If a checklist is good enough for pilots to use every flight, it’s good enough for data scientists to use with every dataset).
# 1. What question are you trying to solve (or prove wrong)?
# 2. What kind of data do you have?
# 3. What’s missing from the data?
# 4. Where are the outliers?
# 5. How can you add, change or remove features to get more out of your data?
#
# **``Exploratory data analysis (EDA)``** is often an **iterative brainstorming process** where you pose a question, review the data, and develop further questions to investigate before beginning model development work. The image below shows how the brainstorming phase is connected with that of understanding the variables and how this in turn is connected again with the brainstorming phase.<br>
#
# <img src=https://i.ibb.co/k0MC950/EDA-Process.png width="300" height="100">
#
# [Image Credit: Andrew D.](https://towardsdatascience.com/exploratory-data-analysis-in-python-a-step-by-step-process-d0dfa6bf94ee)

# %% [markdown]
# # PART- 1 `( Data Cleaning )`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# import warnings
# warnings.filterwarnings("ignore")
# warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# pd.options.display.max_rows = 100
# pd.options.display.max_columns = 100

# %%
df0 = pd.read_json('as24_cars.json')
df = df0.copy()

# %%
df.head()
# Out:
#                make_model         short_description               make  \
# 0     Mercedes-Benz A 160                       CDi  \nMercedes-Benz\n
# 1   Mercedes-Benz EQE 350                      350+  \nMercedes-Benz\n
# 2  Mercedes-Benz A 45 AMG          S 4Matic+ 8G-DCT  \nMercedes-Benz\n
# 3  Mercedes-Benz A 35 AMG            4Matic+ 7G-DCT  \nMercedes-Benz\n
# 4  Mercedes-Benz A 45 AMG  200CDI BE Line 4M 7G-DCT  \nMercedes-Benz\n
#
#                 model                                           location  \
# 0     [\n, A 160 ,\n]  P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...
# 1   [\n, EQE 350 ,\n]       APARTADO DE CORREOS 1032,  26140 LOGROÑO, ES
# 2  [\n, A 45 AMG ,\n]  PORT. TARRACO, MOLL DE LLEVANT, Nº 5, LOC. 6-8...
# 3  [\n, A 35 AMG ,\n]  Carrer de Provença, 31 Local,  8029 BARCELONA, ES
# 4  [\n, A 45 AMG ,\n]             CARRIL ARAGONES 4,  30007 CASILLAS, ES
#
#         price          Body type                      Type        Doors  \
# 0  € 16,950.-  [\n, Compact, \n]            [\n, Used, \n]  [\n, 5, \n]
# 1  € 80,900.-  [\n, Compact, \n]  [\n, Pre-registered, \n]  [\n, 4, \n]
# 2  € 69,900.-  [\n, Compact, \n]            [\n, Used, \n]  [\n, 5, \n]
# 3  € 46,990.-  [\n, Compact, \n]            [\n, Used, \n]  [\n, 5, \n]
# 4  € 16,800.-  [\n, Compact, \n]            [\n, Used, \n]  [\n, 5, \n]
#
#    Country version  ... CO₂-efficiency Fuel consumption (WLTP)  \
# 0  [\n, Spain, \n]  ...            NaN                     NaN
# 1  [\n, Spain, \n]  ...            NaN                     NaN
# 2  [\n, Spain, \n]  ...            NaN                     NaN
# 3  [\n, Spain, \n]  ...            NaN                     NaN
# 4  [\n, Spain, \n]  ...            NaN                     NaN
#
#   CO₂-emissions (WLTP) Available from Taxi or rental car Availability  \
# 0                  NaN            NaN                NaN          NaN
# 1                  NaN            NaN                NaN          NaN
# 2                  NaN            NaN                NaN          NaN
# 3                  NaN            NaN                NaN          NaN
# 4                  NaN            NaN                NaN          NaN
#
#   Last timing belt change Electric Range (WLTP) Power consumption (WLTP)  \
# 0                     NaN                   NaN                      NaN
# 1                     NaN                   NaN                      NaN
# 2                     NaN                   NaN                      NaN
# 3                     NaN                   NaN                      NaN
# 4                     NaN                   NaN                      NaN
#
#   Battery Ownership
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 58 columns]

# %%
df.shape
# Out:
# (29480, 58)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29480 entries, 0 to 29479
# Data columns (total 58 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   make_model                28630 non-null  object
#  1   short_description         28630 non-null  object
#  2   make                      28630 non-null  object
#  3   model                     28630 non-null  object
#  4   location                  28630 non-null  object
#  5   price                     28630 non-null  object
#  6   Body type                 28630 non-null  object
#  7   Type                      28630 non-null  object
#  8   Doors                     28271 non-null  object
#  9   Country version           16889 non-null  object
#  10  Offer number              23100 non-null  object
#  11  Warranty                  15784 non-null  object
#  12  Mileage                   28629 non-null  object
#  13  First registration        28628 non-null  object
#  14  Gearbox                   28382 non-null  object
#  15  Fuel type                 26843 non-null  object
#  16  Colour                    26906 non-null  object
#  17  Paint                     14495 non-null  object
#  18  desc                      28047 non-null  object
#  19  seller                    28630 non-null  object
#  20  Seats                     25505 non-null  object
#  21  Power                     28058 non-null  object
#  22  Engine size               27227 non-null  object
#  23  Gears                     18954 non-null  object
#  24  CO₂-emissions             18594 non-null  object
#  25  Manufacturer colour       21787 non-null  object
#  26  Drivetrain                16893 non-null  object
#  27  Cylinders                 18852 non-null  object
#  28  Fuel consumption          23385 non-null  object
#  29
# Comfort & Convenience
#    25433 non-null  object
#  30
# Entertainment & Media
#    23644 non-null  object
#  31
# Safety & Security
#        25415 non-null  object
#  32
# Extras
#                   23480 non-null  object
#  33  Empty weight              17758 non-null  object
#  34  Model code                8367 non-null   object
#  35  General inspection        12254 non-null  object
#  36  Last service              2003 non-null   object
#  37  Full service history      12565 non-null  object
#  38  Non-smoker vehicle        11594 non-null  object
#  39  Emission class            17859 non-null  object
#  40  Emissions sticker         9414 non-null   object
#  41  Upholstery colour         14569 non-null  object
#  42  Upholstery                18610 non-null  object
#  43  Production date           5908 non-null   float64
#  44  Previous owner            14015 non-null  object
#  45  Other fuel types          2313 non-null   object
#  46  Power consumption         515 non-null    object
#  47  Energy efficiency class   7804 non-null   object
#  48  CO₂-efficiency            7804 non-null   object
#  49  Fuel consumption (WLTP)   100 non-null    object
#  50  CO₂-emissions (WLTP)      116 non-null    object
#  51  Available from            393 non-null    object
#  52  Taxi or rental car        422 non-null    object
#  53  Availability              301 non-null    object
#  54  Last timing belt change   572 non-null    object
#  55  Electric Range (WLTP)     16 non-null     object
#  56  Power consumption (WLTP)  16 non-null     object
#  57  Battery Ownership         7 non-null      object
# dtypes: float64(1), object(57)
# memory usage: 13.0+ MB

# %%
df.head().T
# Out:
#                                                                            0  \
# make_model                                               Mercedes-Benz A 160
# short_description                                                        CDi
# make                                                       \nMercedes-Benz\n
# model                                                        [\n, A 160 ,\n]
# location                   P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...
# price                                                             € 16,950.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7468157, \n]
# Warranty                                                 [\n, 24 months, \n]
# Mileage                                                           120,200 km
# First registration                                                   06/2016
# Gearbox                                                         [\nManual\n]
# Fuel type                                                             Diesel
# Colour                                                                 Black
# Paint                                                               Metallic
# desc                       [ , Precio al contado: 16950 euros,  ,  , Vehí...
# seller                                                                Dealer
# Seats                                                                    NaN
# Power                                                                    NaN
# Engine size                                                              NaN
# Gears                                                                    NaN
# CO₂-emissions                                                            NaN
# Manufacturer colour                                                      NaN
# Drivetrain                                                               NaN
# Cylinders                                                                NaN
# Fuel consumption                                                         NaN
# \nComfort & Convenience\n                                                NaN
# \nEntertainment & Media\n                                                NaN
# \nSafety & Security\n                                                    NaN
# \nExtras\n                                                               NaN
# Empty weight                                                             NaN
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                            1  \
# make_model                                             Mercedes-Benz EQE 350
# short_description                                                       350+
# make                                                       \nMercedes-Benz\n
# model                                                      [\n, EQE 350 ,\n]
# location                        APARTADO DE CORREOS 1032,  26140 LOGROÑO, ES
# price                                                             € 80,900.-
# Body type                                                  [\n, Compact, \n]
# Type                                                [\n, Pre-registered, \n]
# Doors                                                            [\n, 4, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7054863, \n]
# Warranty                                                 [\n, 24 months, \n]
# Mileage                                                             5,000 km
# First registration                                                   06/2022
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                           Electric
# Colour                                                                   NaN
# Paint                                                                    NaN
# desc                       [ , Precio al contado: 88900 euros,  , AUTO OJ...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n215 kW (292 hp)\n]
# Engine size                                                       [\n1 cc\n]
# Gears                                                                [\n9\n]
# CO₂-emissions                                                 0 g/km (comb.)
# Manufacturer colour                                          Negro Obsidiana
# Drivetrain                                                               NaN
# Cylinders                                                                NaN
# Fuel consumption                                                         NaN
# \nComfort & Convenience\n                                                NaN
# \nEntertainment & Media\n                                                NaN
# \nSafety & Security\n                                                    NaN
# \nExtras\n                                                               NaN
# Empty weight                                                             NaN
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                            2  \
# make_model                                            Mercedes-Benz A 45 AMG
# short_description                                           S 4Matic+ 8G-DCT
# make                                                       \nMercedes-Benz\n
# model                                                     [\n, A 45 AMG ,\n]
# location                   PORT. TARRACO, MOLL DE LLEVANT, Nº 5, LOC. 6-8...
# price                                                             € 69,900.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7410454, \n]
# Warranty                                                 [\n, 12 months, \n]
# Mileage                                                            18,900 km
# First registration                                                   07/2020
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                           Gasoline
# Colour                                                                  Grey
# Paint                                                                    NaN
# desc                       [Gris MANUFAKTUR mountaingrau magno,  , Linea/...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n310 kW (421 hp)\n]
# Engine size                                                   [\n1,991 cc\n]
# Gears                                                                [\n8\n]
# CO₂-emissions                                                            NaN
# Manufacturer colour                                       Mountaingrau magno
# Drivetrain                                                     [\n, 4WD, \n]
# Cylinders                                                            [\n4\n]
# Fuel consumption           [[8.4 l/100 km (comb.)], [10.9 l/100 km (city)...
# \nComfort & Convenience\n                                                NaN
# \nEntertainment & Media\n                                                NaN
# \nSafety & Security\n                                                    NaN
# \nExtras\n                                                               NaN
# Empty weight                                                             NaN
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                            3  \
# make_model                                            Mercedes-Benz A 35 AMG
# short_description                                             4Matic+ 7G-DCT
# make                                                       \nMercedes-Benz\n
# model                                                     [\n, A 35 AMG ,\n]
# location                   Carrer de Provença, 31 Local,  8029 BARCELONA, ES
# price                                                             € 46,990.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7464503, \n]
# Warranty                                                 [\n, 12 months, \n]
# Mileage                                                            18,995 km
# First registration                                                   01/2020
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                           Gasoline
# Colour                                                                Yellow
# Paint                                                                    NaN
# desc                       [ , Precio al contado: 48990 euros,  ,  , BONI...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n225 kW (306 hp)\n]
# Engine size                                                   [\n1,991 cc\n]
# Gears                                                                [\n7\n]
# CO₂-emissions                                                            NaN
# Manufacturer colour                                             Amarillo Sol
# Drivetrain                                                     [\n, 4WD, \n]
# Cylinders                                                            [\n4\n]
# Fuel consumption           [[7.3 l/100 km (comb.)], [9.3 l/100 km (city)]...
# \nComfort & Convenience\n  [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n                                              [USB]
# \nSafety & Security\n      [ABS, Central door lock, Driver-side airbag, E...
# \nExtras\n                                                     [Sport seats]
# Empty weight                                                             NaN
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                            4
# make_model                                            Mercedes-Benz A 45 AMG
# short_description                                   200CDI BE Line 4M 7G-DCT
# make                                                       \nMercedes-Benz\n
# model                                                     [\n, A 45 AMG ,\n]
# location                              CARRIL ARAGONES 4,  30007 CASILLAS, ES
# price                                                             € 16,800.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7127931, \n]
# Warranty                                                 [\n, 12 months, \n]
# Mileage                                                           197,000 km
# First registration                                                   09/2015
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                             Diesel
# Colour                                                                 White
# Paint                                                               Metallic
# desc                       [ , Precio al contado: 17400 euros,  , Vehícul...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n100 kW (136 hp)\n]
# Engine size                                                   [\n2,143 cc\n]
# Gears                                                                [\n7\n]
# CO₂-emissions                                                            NaN
# Manufacturer colour                                                      NaN
# Drivetrain                                                     [\n, 4WD, \n]
# Cylinders                                                            [\n4\n]
# Fuel consumption           [[4.9 l/100 km (comb.)], [5.7 l/100 km (city)]...
# \nComfort & Convenience\n  [Air conditioning, Electrical side mirrors, Mu...
# \nEntertainment & Media\n                   [Bluetooth, CD player, MP3, USB]
# \nSafety & Security\n      [ABS, Central door lock, Driver-side airbag, E...
# \nExtras\n                                                               NaN
# Empty weight                                                  [\n1,545 kg\n]
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN

# %%
df.sample(100).T
# Out:
#                                                                        27044  \
# make_model                                                         Volvo C70
# short_description          Convertible 2.4 Kinetic Leer, Stoelv, Clima, L...
# make                                                               \nVolvo\n
# model                                                          [\n, C70 ,\n]
# location                                 Neereind 1,  3998 WJ SCHALKWIJK, NL
# price                                                             € 11,950.-
# Body type                                              [\n, Convertible, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 2, \n]
# Country version                                                          NaN
# Offer number                                              [\n, JD-565-F, \n]
# Warranty                                                                 NaN
# Mileage                                                           143,447 km
# First registration                                                   11/2006
# Gearbox                                                         [\nManual\n]
# Fuel type                                                           Gasoline
# Colour                                                                  Blue
# Paint                                                                    NaN
# desc                       [Volvo C70 Convertible 2.4 Kinetic Leer, Stoel...
# seller                                                                Dealer
# Seats                                                            [\n, 4, \n]
# Power                                                  [\n103 kW (140 hp)\n]
# Engine size                                                   [\n2,435 cc\n]
# Gears                                                                    NaN
# CO₂-emissions                                               212 g/km (comb.)
# Manufacturer colour                                                Niebieski
# Drivetrain                                                   [\n, Front, \n]
# Cylinders                                                            [\n5\n]
# Fuel consumption           [[8.9 l/100 km (comb.)], [12.8 l/100 km (city)...
# \nComfort & Convenience\n  [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n              [CD player, On-board computer, Radio]
# \nSafety & Security\n      [ABS, Alarm system, Bi-Xenon headlights, Centr...
# \nExtras\n                 [Alloy wheels (17"), Automatically dimming int...
# Empty weight                                                  [\n1,598 kg\n]
# Model code                                                               NaN
# General inspection                                                   05/2023
# Last service                                                             NaN
# Full service history                                                     Yes
# Non-smoker vehicle                                                       NaN
# Emission class                                                        Euro 4
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                      Full leather
# Production date                                                          NaN
# Previous owner                                    [[143,447 km, 11/2006], 2]
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                        5190   \
# make_model                                                       Renault ZOE
# short_description          R110 Life 50 (AccuHuur) incl. BTW excl. Overhe...
# make                                                             \nRenault\n
# model                                                          [\n, ZOE ,\n]
# location                               Sluiswachter 26,  3861 SN NIJKERK, NL
# price                                                             € 20,950.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                                          NaN
# Offer number                                              [\n, R-734-FG, \n]
# Warranty                                                 [\n, 12 months, \n]
# Mileage                                                             6,275 km
# First registration                                                   12/2020
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                                NaN
# Colour                                                                 White
# Paint                                                                    NaN
# desc                       [Uitleg batterijhuur/koop:, Wanneer u ervoor k...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                   [\n80 kW (109 hp)\n]
# Engine size                                                              NaN
# Gears                                                                    NaN
# CO₂-emissions                                                            NaN
# Manufacturer colour                                                      Wit
# Drivetrain                                                   [\n, Front, \n]
# Cylinders                                                                NaN
# Fuel consumption                                                         NaN
# \nComfort & Convenience\n  [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n  [Android Auto, Apple CarPlay, Bluetooth, Digit...
# \nSafety & Security\n      [ABS, Alarm system, Central door lock, Central...
# \nExtras\n                                                   [Voice Control]
# Empty weight                                                  [\n1,477 kg\n]
# Model code                                                               NaN
# General inspection                                                       New
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                      Black
# Upholstery                                                             Cloth
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                 Electricity
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                        28087  \
# make_model                                                        Volvo XC60
# short_description                                      B4 Plus Dark FWD Aut.
# make                                                               \nVolvo\n
# model                                                         [\n, XC60 ,\n]
# location                   CALLE D 43 POLIGONO INDUSTRIAL TALLUNTXE,  311...
# price                                                             € 56,600.-
# Body type                                         [\n, Off-Road/Pick-up, \n]
# Type                                                [\n, Pre-registered, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7225108, \n]
# Warranty                                                 [\n, 36 months, \n]
# Mileage                                                                 9 km
# First registration                                                   07/2022
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                             Diesel
# Colour                                                                  Grey
# Paint                                                               Metallic
# desc                       [ , Precio al contado: 59900 euros,  , ENTREGA...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n145 kW (197 hp)\n]
# Engine size                                                   [\n1,969 cc\n]
# Gears                                                                [\n8\n]
# CO₂-emissions                                                            NaN
# Manufacturer colour                                              SILVER DAWN
# Drivetrain                                                   [\n, Front, \n]
# Cylinders                                                            [\n4\n]
# Fuel consumption           [[0 l/100 km (comb.)], [0 l/100 km (city)], [0...
# \nComfort & Convenience\n                                                NaN
# \nEntertainment & Media\n                                                NaN
# \nSafety & Security\n                                                    NaN
# \nExtras\n                                                               NaN
# Empty weight                                                  [\n1,843 kg\n]
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                        14314  \
# make_model                                                      Skoda Kodiaq
# short_description          Clever 4x4 2.0 TDI EU6d++LED, Navi, Keyless, ACC,
# make                                                               \nSkoda\n
# model                                                       [\n, Kodiaq ,\n]
# location                           Carl-Zeiss-Str- 1,  64331 Weiterstadt, DE
# price                                                             € 42,900.-
# Body type                                         [\n, Off-Road/Pick-up, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                                          NaN
# Offer number                                               [\n, 8016434, \n]
# Warranty                                                 [\n, 60 months, \n]
# Mileage                                                            15,450 km
# First registration                                                   01/2022
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                           Diesel (Particle filter)
# Colour                                                                  Grey
# Paint                                                               Metallic
# desc                       [Getriebe:,  Automatik, Technik:,  Allrad, Bor...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n147 kW (200 hp)\n]
# Engine size                                                   [\n1,968 cc\n]
# Gears                                                                [\n7\n]
# CO₂-emissions                                               140 g/km (comb.)
# Manufacturer colour                                   Graphite grau metallic
# Drivetrain                                                     [\n, 4WD, \n]
# Cylinders                                                            [\n4\n]
# Fuel consumption           [[5.3 l/100 km (comb.)], [6.4 l/100 km (city)]...
# \nComfort & Convenience\n  [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n  [Android Auto, Apple CarPlay, Bluetooth, CD pl...
# \nSafety & Security\n      [ABS, Adaptive Cruise Control, Adaptive headli...
# \nExtras\n                 [Alloy wheels, Roof rack, Touch screen, Traile...
# Empty weight                                                  [\n1,765 kg\n]
# Model code                                                [\n, 8004/AVV, \n]
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     Yes
# Non-smoker vehicle                                                       Yes
# Emission class                                                       Euro 6d
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                             Cloth
# Production date                                                      2021.00
# Previous owner                                     [[15,450 km, 01/2022], 1]
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                    A
# CO₂-efficiency             Calculated on basis of measured CO₂-emissions ...
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       Yes
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                        21487  \
# make_model                                                       Ford Fiesta
# short_description                                                      Style
# make                                                                \nFord\n
# model                                                       [\n, Fiesta ,\n]
# location                                Rheinlandstr. 23,  42549 Velbert, DE
# price                                                              € 2,990.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 2, \n]
# Country version                                                          NaN
# Offer number                                                             NaN
# Warranty                                                       [\n, Yes, \n]
# Mileage                                                           137,800 km
# First registration                                                   10/2007
# Gearbox                                                         [\nManual\n]
# Fuel type                                                             Diesel
# Colour                                                                Silver
# Paint                                                               Metallic
# desc                       [Sonderausstattung:, Audiosystem 6000 (Radio/C...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                    [\n50 kW (68 hp)\n]
# Engine size                                                   [\n1,399 cc\n]
# Gears                                                                    NaN
# CO₂-emissions                                               119 g/km (comb.)
# Manufacturer colour                                    Polar-Silber Metallic
# Drivetrain                                                               NaN
# Cylinders                                                                NaN
# Fuel consumption           [[4.5 l/100 km (comb.)], [5.8 l/100 km (city)]...
# \nComfort & Convenience\n  [Air conditioning, Electrical side mirrors, Ke...
# \nEntertainment & Media\n                                 [CD player, Radio]
# \nSafety & Security\n      [ABS, Central door lock, Immobilizer, Power st...
# \nExtras\n                                                               NaN
# Empty weight                                                             NaN
# Model code                                                               NaN
# General inspection                                                       New
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                        Euro 4
# Emissions sticker                                                  4 (Green)
# Upholstery colour                                                      Other
# Upholstery                                                             Cloth
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                        15014  \
# make_model                                                      Skoda Superb
# short_description                          Limousine Style iV 1.4 TSI Hybrid
# make                                                               \nSkoda\n
# model                                                       [\n, Superb ,\n]
# location                          Fröbelstr. 15,  50823 Köln (Ehrenfeld), DE
# price                                                             € 35,990.-
# Body type                                                    [\n, Sedan, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                            [\n, Germany, \n]
# Offer number                                                [\n, G38109, \n]
# Warranty                                                                 NaN
# Mileage                                                            67,649 km
# First registration                                                   10/2020
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                           Super 95
# Colour                                                                  Blue
# Paint                                                               Metallic
# desc                       [Getriebe, Automatik, Technik, Bordcomputer, S...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n115 kW (156 hp)\n]
# Engine size                                                   [\n1,395 cc\n]
# Gears                                                                [\n6\n]
# CO₂-emissions                                                37 g/km (comb.)
# Manufacturer colour                                       Race-blau metallic
# Drivetrain                                                   [\n, Front, \n]
# Cylinders                                                            [\n4\n]
# Fuel consumption                                    [[1.4 l/100 km (comb.)]]
# \nComfort & Convenience\n  [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n  [Android Auto, Apple CarPlay, Bluetooth, CD pl...
# \nSafety & Security\n      [ABS, Adaptive Cruise Control, Adaptive headli...
# \nExtras\n                                      [Alloy wheels, Touch screen]
# Empty weight                                                  [\n1,730 kg\n]
# Model code                                                [\n, 8004/AUI, \n]
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     Yes
# Non-smoker vehicle                                                       Yes
# Emission class                                                       Euro 6d
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                             Cloth
# Production date                                                      2020.00
# Previous owner                                     [[67,649 km, 10/2020], 1]
# Other fuel types                                                 Electricity
# Power consumption                                                        NaN
# Energy efficiency class                                                   A+
# CO₂-efficiency             Calculated on basis of measured CO₂-emissions ...
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                        21416  \
# make_model                                                       Ford Fiesta
# short_description                                  1.0 EcoBoost S&S TITANIUM
# make                                                                \nFord\n
# model                                                       [\n, Fiesta ,\n]
# location                                   Opelstraße 1,  78467 Konstanz, DE
# price                                                             € 16,680.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                                          NaN
# Offer number                                            [\n, 7568_52655, \n]
# Warranty                                                                 NaN
# Mileage                                                            17,100 km
# First registration                                                   11/2019
# Gearbox                                                         [\nManual\n]
# Fuel type                                         Super 95 (Particle filter)
# Colour                                                                 Black
# Paint                                                               Metallic
# desc                       [ * ABS elektronisch mit EBD,  * Airbag: Beifa...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                   [\n92 kW (125 hp)\n]
# Engine size                                                     [\n998 cc\n]
# Gears                                                                [\n6\n]
# CO₂-emissions                                               105 g/km (comb.)
# Manufacturer colour                                     Agate Black Metallic
# Drivetrain                                                   [\n, Front, \n]
# Cylinders                                                            [\n3\n]
# Fuel consumption           [[4.6 l/100 km (comb.)], [5.7 l/100 km (city)]...
# \nComfort & Convenience\n  [Air conditioning, Armrest, Electrical side mi...
# \nEntertainment & Media\n  [Android Auto, Apple CarPlay, Bluetooth, Hands...
# \nSafety & Security\n      [ABS, Adaptive headlights, Central door lock, ...
# \nExtras\n                 [Alloy wheels (16"), Automatically dimming int...
# Empty weight                                                  [\n1,164 kg\n]
# Model code                                                [\n, 8566/BOG, \n]
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       Yes
# Emission class                                                        Euro 6
# Emissions sticker                                                  4 (Green)
# Upholstery colour                                                        NaN
# Upholstery                                                             Cloth
# Production date                                                          NaN
# Previous owner                                     [[17,100 km, 11/2019], 2]
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                    A
# CO₂-efficiency             Calculated on basis of measured CO₂-emissions ...
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                        18405  \
# make_model                                                      Toyota Auris
# short_description                            1.8 140H Advance Touring Sports
# make                                                              \nToyota\n
# model                                                        [\n, Auris ,\n]
# location                                  Av. Laboral, 10,  28021 MADRID, ES
# price                                                             € 15,490.-
# Body type                                            [\n, Station wagon, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7416855, \n]
# Warranty                                                 [\n, 12 months, \n]
# Mileage                                                           120,321 km
# First registration                                                   03/2018
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                             Others
# Colour                                                                 White
# Paint                                                                    NaN
# desc                       [ , Precio al contado: 16990 euros,  , Clicars...
# seller                                                                Dealer
# Seats                                                                    NaN
# Power                                                  [\n100 kW (136 hp)\n]
# Engine size                                                   [\n1,798 cc\n]
# Gears                                                                    NaN
# CO₂-emissions                                                            NaN
# Manufacturer colour                                                   Blanco
# Drivetrain                                                               NaN
# Cylinders                                                                NaN
# Fuel consumption                                    [[4.5 l/100 km (comb.)]]
# \nComfort & Convenience\n  [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n                                   [Bluetooth, USB]
# \nSafety & Security\n                                               [Isofix]
# \nExtras\n                                                    [Alloy wheels]
# Empty weight                                                             NaN
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                        14012  \
# make_model                                                       Skoda Scala
# short_description                                      1.6 TDI Ambition 85kW
# make                                                               \nSkoda\n
# model                                                        [\n, Scala ,\n]
# location                   Carrer de la Ciutat d'Asuncion, 55, 61,,  0803...
# price                                                             € 16,800.-
# Body type                                                  [\n, Compact, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 7327453, \n]
# Warranty                                                 [\n, 12 months, \n]
# Mileage                                                            32,176 km
# First registration                                                   06/2020
# Gearbox                                                         [\nManual\n]
# Fuel type                                                             Diesel
# Colour                                                                   Red
# Paint                                                                    NaN
# desc                       [ , Precio al contado: 18300 euros,  ,  , Extr...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                   [\n85 kW (116 hp)\n]
# Engine size                                                   [\n1,598 cc\n]
# Gears                                                                [\n6\n]
# CO₂-emissions                                                            NaN
# Manufacturer colour                                                P2 - ROJO
# Drivetrain                                                   [\n, Front, \n]
# Cylinders                                                            [\n4\n]
# Fuel consumption           [[4.2 l/100 km (comb.)], [5.1 l/100 km (city)]...
# \nComfort & Convenience\n                                    [Power windows]
# \nEntertainment & Media\n                                        [Bluetooth]
# \nSafety & Security\n      [ABS, Central door lock, Driver-side airbag, E...
# \nExtras\n                                                               NaN
# Empty weight                                                  [\n1,324 kg\n]
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                        23010  \
# make_model                                                        Ford Focus
# short_description                          Titanium LED ACC Techologie Paket
# make                                                                \nFord\n
# model                                                        [\n, Focus ,\n]
# location                          Halterner Straße  39-43,  48249 Dülmen, DE
# price                                                             € 24,790.-
# Body type                                            [\n, Station wagon, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                            [\n, Germany, \n]
# Offer number                                            [\n, Focus81772, \n]
# Warranty                                                 [\n, 12 months, \n]
# Mileage                                                            23,890 km
# First registration                                                   04/2020
# Gearbox                                                         [\nManual\n]
# Fuel type                                           Diesel (Particle filter)
# Colour                                                                  Grey
# Paint                                                               Metallic
# desc                       [Getriebe, Schaltgetriebe, Technik, Bordcomput...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n110 kW (150 hp)\n]
# Engine size                                                   [\n1,997 cc\n]
# Gears                                                                [\n6\n]
# CO₂-emissions                                               105 g/km (comb.)
# Manufacturer colour                                 Magnetic-grau (metallic)
# Drivetrain                                                   [\n, Front, \n]
# Cylinders                                                            [\n4\n]
# Fuel consumption           [[4 l/100 km (comb.)], [4.7 l/100 km (city)], ...
# \nComfort & Convenience\n  [Armrest, Cruise control, Electric tailgate, E...
# \nEntertainment & Media\n  [Android Auto, Apple CarPlay, Bluetooth, Digit...
# \nSafety & Security\n      [ABS, Adaptive Cruise Control, Bi-Xenon headli...
# \nExtras\n                 [Alloy wheels, Roof rack, Sport seats, Touch s...
# Empty weight                                                  [\n1,460 kg\n]
# Model code                                                [\n, 8566/BQQ, \n]
# General inspection                                                   04/2023
# Last service                                                             NaN
# Full service history                                                     Yes
# Non-smoker vehicle                                                       Yes
# Emission class                                                  Euro 6d-TEMP
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                             Cloth
# Production date                                                      2019.00
# Previous owner                                     [[23,890 km, 04/2020], 1]
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                    A
# CO₂-efficiency             Calculated on basis of measured CO₂-emissions ...
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                            ...  \
# make_model                 ...
# short_description          ...
# make                       ...
# model                      ...
# location                   ...
# price                      ...
# Body type                  ...
# Type                       ...
# Doors                      ...
# Country version            ...
# Offer number               ...
# Warranty                   ...
# Mileage                    ...
# First registration         ...
# Gearbox                    ...
# Fuel type                  ...
# Colour                     ...
# Paint                      ...
# desc                       ...
# seller                     ...
# Seats                      ...
# Power                      ...
# ...
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                        Euro 5
# Emissions sticker                                                        NaN
# Upholstery colour                                                      Black
# Upholstery                                                         alcantara
# Production date                                                          NaN
# Previous owner                                     [[69,000 km, 05/2017], 2]
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                        13884  \
# make_model                                                       Skoda Scala
# short_description                                    1.5 TSI Style DSG 110kW
# make                                                               \nSkoda\n
# model                                                        [\n, Scala ,\n]
# location                          Ctra. N-152 Km. 25,5,  8403 Granollers, ES
# price                                                             € 26,150.-
# Body type                                                  [\n, Compact, \n]
# Type                                                [\n, Pre-registered, \n]
# Doors                                                            [\n, 5, \n]
# Country version                                              [\n, Spain, \n]
# Offer number                                               [\n, 6842854, \n]
# Warranty                                                 [\n, 12 months, \n]
# Mileage                                                                10 km
# First registration                                                   04/2022
# Gearbox                                                      [\nAutomatic\n]
# Fuel type                                                           Gasoline
# Colour                                                                  Grey
# Paint                                                                    NaN
# desc                       [Precio sujeto a financiación. Llámanos., Auto...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                  [\n110 kW (150 hp)\n]
# Engine size                                                   [\n1,498 cc\n]
# Gears                                                                [\n7\n]
# CO₂-emissions                                                            NaN
# Manufacturer colour                                                      NaN
# Drivetrain                                                   [\n, Front, \n]
# Cylinders                                                            [\n3\n]
# Fuel consumption           [[5 l/100 km (comb.)], [6.4 l/100 km (city)], ...
# \nComfort & Convenience\n                                    [Power windows]
# \nEntertainment & Media\n                                        [Bluetooth]
# \nSafety & Security\n      [ABS, Driver-side airbag, Electronic stability...
# \nExtras\n                                                    [Alloy wheels]
# Empty weight                                                  [\n1,265 kg\n]
# Model code                                                               NaN
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                               NaN
# Production date                                                          NaN
# Previous owner                                                           NaN
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                        4721   \
# make_model                                                        Opel Corsa
# short_description                       E Selection 1.2 *Klima*ESP*CD/Radio*
# make                                                                \nOpel\n
# model                                                        [\n, Corsa ,\n]
# location                              Max-Planck-Straße 14,  50354 Hürth, DE
# price                                                              € 9,990.-
# Body type                                                    [\n, Sedan, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 3, \n]
# Country version                                            [\n, Germany, \n]
# Offer number                                                  [\n, 3867, \n]
# Warranty                                                                 NaN
# Mileage                                                            28,021 km
# First registration                                                   12/2015
# Gearbox                                                         [\nManual\n]
# Fuel type                                                           Super 95
# Colour                                                                 Black
# Paint                                                               Metallic
# desc                       [Getriebe, Schaltgetriebe, Assistenten, Bergan...
# seller                                                                Dealer
# Seats                                                            [\n, 5, \n]
# Power                                                    [\n51 kW (69 hp)\n]
# Engine size                                                   [\n1,229 cc\n]
# Gears                                                                [\n5\n]
# CO₂-emissions                                               128 g/km (comb.)
# Manufacturer colour                                          Graphit schwarz
# Drivetrain                                                   [\n, Front, \n]
# Cylinders                                                            [\n4\n]
# Fuel consumption           [[5.4 l/100 km (comb.)], [6.7 l/100 km (city)]...
# \nComfort & Convenience\n  [Air conditioning, Electrical side mirrors, Hi...
# \nEntertainment & Media\n                 [Bluetooth, CD player, Radio, USB]
# \nSafety & Security\n      [ABS, Central door lock, Daytime running light...
# \nExtras\n                                             [Catalytic Converter]
# Empty weight                                                  [\n1,120 kg\n]
# Model code                                                [\n, 0035/BCJ, \n]
# General inspection                                                       NaN
# Last service                                                             NaN
# Full service history                                                     NaN
# Non-smoker vehicle                                                       NaN
# Emission class                                                        Euro 6
# Emissions sticker                                                        NaN
# Upholstery colour                                                        NaN
# Upholstery                                                             Cloth
# Production date                                                      2015.00
# Previous owner                                     [[28,021 km, 12/2015], 1]
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                    D
# CO₂-efficiency             Calculated on basis of measured CO₂-emissions ...
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
#                                                                        27079
# make_model                                                         Volvo C70
# short_description                                     Cabriolet 2.4 Momentum
# make                                                               \nVolvo\n
# model                                                          [\n, C70 ,\n]
# location                   Frankfurter Straße 1,  61203 Reichelsheim-Beie...
# price                                                              € 9,300.-
# Body type                                              [\n, Convertible, \n]
# Type                                                          [\n, Used, \n]
# Doors                                                            [\n, 2, \n]
# Country version                                            [\n, Germany, \n]
# Offer number                                                             NaN
# Warranty                                                                 NaN
# Mileage                                                           144,000 km
# First registration                                                   03/2007
# Gearbox                                                         [\nManual\n]
# Fuel type                                                 Regular/Benzine 91
# Colour                                                                 Black
# Paint                                                               Metallic
# desc                       [Verkauf erfolgt im Kundenauftrag.,  Sonderaus...
# seller                                                                Dealer
# Seats                                                            [\n, 4, \n]
# Power                                                  [\n103 kW (140 hp)\n]
# Engine size                                                   [\n2,435 cc\n]
# Gears                                                                    NaN
# CO₂-emissions                                               211 g/km (comb.)
# Manufacturer colour                           BLACK SAPPHIRE METALLIC / Meta
# Drivetrain                                                               NaN
# Cylinders                                                                NaN
# Fuel consumption           [[8.9 l/100 km (comb.)], [12.8 l/100 km (city)...
# \nComfort & Convenience\n  [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n  [CD player, On-board computer, Radio, Sound sy...
# \nSafety & Security\n      [ABS, Central door lock, Driver-side airbag, E...
# \nExtras\n                 [All season tyres, Alloy wheels, Headlight was...
# Empty weight                                                             NaN
# Model code                                                               NaN
# General inspection                                                   06/2024
# Last service                                                             NaN
# Full service history                                                     Yes
# Non-smoker vehicle                                                       NaN
# Emission class                                                           NaN
# Emissions sticker                                                        NaN
# Upholstery colour                                                      Black
# Upholstery                                                      Full leather
# Production date                                                          NaN
# Previous owner                                    [[144,000 km, 03/2007], 2]
# Other fuel types                                                         NaN
# Power consumption                                                        NaN
# Energy efficiency class                                                  NaN
# CO₂-efficiency                                                           NaN
# Fuel consumption (WLTP)                                                  NaN
# CO₂-emissions (WLTP)                                                     NaN
# Available from                                                           NaN
# Taxi or rental car                                                       NaN
# Availability                                                             NaN
# Last timing belt change                                                  NaN
# Electric Range (WLTP)                                                    NaN
# Power consumption (WLTP)                                                 NaN
# Battery Ownership                                                        NaN
#
# [58 rows x 100 columns]

# %%
df.describe()
# Out:
#        Production date
# count          5908.00
# mean           2018.00
# std               6.49
# min            1954.00
# 25%            2018.00
# 50%            2019.00
# 75%            2021.00
# max            2022.00

# %% [markdown]
# ### Öncelikle column isimlerini standardize edelim.

# %%
# column isimlerini ara bosluklari (_), ve sag-soldaki terimlerim trim yapalim.

df.columns
# Out:
# Index(['make_model', 'short_description', 'make', 'model', 'location', 'price',
#        'Body type', 'Type', 'Doors', 'Country version', 'Offer number',
#        'Warranty', 'Mileage', 'First registration', 'Gearbox', 'Fuel type',
#        'Colour', 'Paint', 'desc', 'seller', 'Seats', 'Power', 'Engine size',
#        'Gears', 'CO₂-emissions', 'Manufacturer colour', 'Drivetrain',
#        'Cylinders', 'Fuel consumption', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nSafety & Security\n', '\nExtras\n',
#        'Empty weight', 'Model code', 'General inspection', 'Last service',
#        'Full service history', 'Non-smoker vehicle', 'Emission class',
#        'Emissions sticker', 'Upholstery colour', 'Upholstery',
#        'Production date', 'Previous owner', 'Other fuel types',
#        'Power consumption', 'Energy efficiency class', 'CO₂-efficiency',
#        'Fuel consumption (WLTP)', 'CO₂-emissions (WLTP)', 'Available from',
#        'Taxi or rental car', 'Availability', 'Last timing belt change',
#        'Electric Range (WLTP)', 'Power consumption (WLTP)',
#        'Battery Ownership'],
#       dtype='object')

# %%
for i in df.columns:
    df.rename(columns={i:i.lower().replace(' & ','_').replace(' ','_').replace('\n','').replace('-','_')},inplace = True)

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'make', 'model', 'location', 'price',
#        'body_type', 'type', 'doors', 'country_version', 'offer_number',
#        'warranty', 'mileage', 'first_registration', 'gearbox', 'fuel_type',
#        'colour', 'paint', 'desc', 'seller', 'seats', 'power', 'engine_size',
#        'gears', 'co₂_emissions', 'manufacturer_colour', 'drivetrain',
#        'cylinders', 'fuel_consumption', 'comfort_convenience',
#        'entertainment_media', 'safety_security', 'extras', 'empty_weight',
#        'model_code', 'general_inspection', 'last_service',
#        'full_service_history', 'non_smoker_vehicle', 'emission_class',
#        'emissions_sticker', 'upholstery_colour', 'upholstery',
#        'production_date', 'previous_owner', 'other_fuel_types',
#        'power_consumption', 'energy_efficiency_class', 'co₂_efficiency',
#        'fuel_consumption_(wltp)', 'co₂_emissions_(wltp)', 'available_from',
#        'taxi_or_rental_car', 'availability', 'last_timing_belt_change',
#        'electric_range_(wltp)', 'power_consumption_(wltp)',
#        'battery_ownership'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# make_model                    850
# short_description             850
# make                          850
# model                         850
# location                      850
# price                         850
# body_type                     850
# type                          850
# doors                        1209
# country_version             12591
# offer_number                 6380
# warranty                    13696
# mileage                       851
# first_registration            852
# gearbox                      1098
# fuel_type                    2637
# colour                       2574
# paint                       14985
# desc                         1433
# seller                        850
# seats                        3975
# power                        1422
# engine_size                  2253
# gears                       10526
# co₂_emissions               10886
# manufacturer_colour          7693
# drivetrain                  12587
# cylinders                   10628
# fuel_consumption             6095
# comfort_convenience          4047
# entertainment_media          5836
# safety_security              4065
# extras                       6000
# empty_weight                11722
# model_code                  21113
# general_inspection          17226
# last_service                27477
# full_service_history        16915
# non_smoker_vehicle          17886
# emission_class              11621
# emissions_sticker           20066
# upholstery_colour           14911
# upholstery                  10870
# production_date             23572
# previous_owner              15465
# other_fuel_types            27167
# power_consumption           28965
# energy_efficiency_class     21676
# co₂_efficiency              21676
# fuel_consumption_(wltp)     29380
# co₂_emissions_(wltp)        29364
# available_from              29087
# taxi_or_rental_car          29058
# availability                29179
# last_timing_belt_change     28908
# electric_range_(wltp)       29464
# power_consumption_(wltp)    29464
# battery_ownership           29473
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# make_model                  2.88
# short_description           2.88
# make                        2.88
# model                       2.88
# location                    2.88
# price                       2.88
# body_type                   2.88
# type                        2.88
# doors                       4.10
# country_version            42.71
# offer_number               21.64
# warranty                   46.46
# mileage                     2.89
# first_registration          2.89
# gearbox                     3.72
# fuel_type                   8.95
# colour                      8.73
# paint                      50.83
# desc                        4.86
# seller                      2.88
# seats                      13.48
# power                       4.82
# engine_size                 7.64
# gears                      35.71
# co₂_emissions              36.93
# manufacturer_colour        26.10
# drivetrain                 42.70
# cylinders                  36.05
# fuel_consumption           20.68
# comfort_convenience        13.73
# entertainment_media        19.80
# safety_security            13.79
# extras                     20.35
# empty_weight               39.76
# model_code                 71.62
# general_inspection         58.43
# last_service               93.21
# full_service_history       57.38
# non_smoker_vehicle         60.67
# emission_class             39.42
# emissions_sticker          68.07
# upholstery_colour          50.58
# upholstery                 36.87
# production_date            79.96
# previous_owner             52.46
# other_fuel_types           92.15
# power_consumption          98.25
# energy_efficiency_class    73.53
# co₂_efficiency             73.53
# fuel_consumption_(wltp)    99.66
# co₂_emissions_(wltp)       99.61
# available_from             98.67
# taxi_or_rental_car         98.57
# availability               98.98
# last_timing_belt_change    98.06
# electric_range_(wltp)      99.95
# power_consumption_(wltp)   99.95
# battery_ownership          99.98
# dtype: float64

# %%
df['battery_ownership'].unique()
# Out:
# array([nan, 'Included'], dtype=object)

# %%
df['battery_ownership'].value_counts()
# Out:
# Included    7
# Name: battery_ownership, dtype: int64

# %% [markdown]
# ### 'emission_class' column una data cleaning uygulayalim nan degerler disinda numerik veriler haline getirelim. Emission sinifini 'Euro' ve diger ifadelerden kurtaralim.

# %%
df['emission_class'].unique()
# Out:
# array([nan, 'Euro 4', 'Euro 6', 'Euro 6d-TEMP', 'Euro 5', 'Euro 6d',
#        'Euro 6c', 'Euro 3', 'Euro 2', 'Euro 1'], dtype=object)

# %%
df['emission_class'] = df.emission_class.str.strip("dTEMP-c")

# %%
df['emission_class'].unique() #dtype:float missig value lari doldurduktan sonra int yapabiliriz.
# Out:
# array([nan,  4.,  6.,  5.,  3.,  2.,  1.])

# %% [markdown]
# ### emissions_sticker

# %%
df['emissions_sticker'].unique()
# Out:
# array([nan, '4 (Green)', '1 (No sticker)', '3 (Yellow)', '2 (Red)'],
#       dtype=object)

# %%
df['emissions_sticker'] = df['emissions_sticker'].str.strip(" )(1432")
df['emissions_sticker'].unique()
# Out:
# array([nan,  4.,  1.,  3.,  2.])

# %% [markdown]
# ### upholstery_colour
# #### white, black, other

# %%
df['upholstery_colour'].unique()
# Out:
# array([nan, 'Black', 'Grey', 'Other', 'Blue', 'Brown', 'Beige', 'Red',
#        'White', 'Orange', 'Yellow', 'Green'], dtype=object)

# %%
colour = ['Black', 'Grey', 'Other', 'Blue', 'Brown', 'Beige', 'Red', 'White', 'Orange', 'Yellow', 'Green']
for i in colour:
    if i=='White':
        df['upholstery_colour'] = df['upholstery_colour'].str.replace(i,'white')
    elif i=='Black':
        df['upholstery_colour'] = df['upholstery_colour'].str.replace(i,'black')
    else :
        df['upholstery_colour'] = df['upholstery_colour'].str.replace(i,'other')

# %%
df['upholstery_colour'].unique()
# Out:
# array([nan, 'black', 'other', 'white'], dtype=object)

# %% [markdown]
# ### upholstery
# #### leather, other

# %%
df['upholstery'].unique()
# Out:
# array([nan, 'Cloth', 'Full leather', 'Part leather', 'Other', 'alcantara',
#        'Velour'], dtype=object)

# %%
origin = ['Cloth', 'Full leather', 'Part leather', 'Other', 'alcantara',
       'Velour']
for i in origin:
    if i=='Full leather' or i=='Part leather':
        df['upholstery'] = df['upholstery'].str.replace(i,'leather')
    else :
        df['upholstery'] = df['upholstery'].str.replace(i,'other')

# %%
df['upholstery'].unique()
# Out:
# array([nan, 'other', 'leather'], dtype=object)

# %% [markdown]
# ### production_date

# %%
df['production_date'].unique()
# Out:
# array([  nan, 2019., 2021., 2018., 2014., 2011., 2020., 2022., 2017.,
#        2016., 2013., 2008., 2002., 1991., 2010., 2006., 2012., 1999.,
#        2015., 1997., 2004., 1996., 1962., 2005., 2003., 2007., 1993.,
#        1994., 2009., 2001., 1985., 1970., 1990., 1998., 1981., 1995.,
#        1973., 2000., 1978., 1987., 1982., 1988., 1966., 1965., 1967.,
#        1961., 1968., 1954., 1969., 1976.])

# %%
df['production_date'].value_counts()
# Out:
# 2019.00    1179
# 2021.00     980
# 2022.00     894
# 2020.00     763
# 2018.00     762
# 2017.00     391
# 2016.00     239
# 2015.00     118
# 2014.00      90
# 2013.00      76
# 2010.00      53
# 2012.00      43
# 2011.00      43
# 2008.00      34
# 2009.00      26
# 2007.00      20
# 2006.00      17
# 2002.00      15
# 2004.00      13
# 2003.00      13
# 1967.00      12
# 2001.00      12
# 1966.00      11
# 1999.00       9
# 2005.00       9
# 1965.00       9
# 1970.00       9
# 1997.00       8
# 1994.00       8
# 1968.00       7
# 2000.00       7
# 1998.00       5
# 1990.00       3
# 1973.00       3
# 1987.00       3
# 1993.00       3
# 1991.00       3
# 1996.00       3
# 1995.00       2
# 1969.00       2
# 1978.00       2
# 1982.00       2
# 1961.00       1
# 1954.00       1
# 1988.00       1
# 1962.00       1
# 1981.00       1
# 1985.00       1
# 1976.00       1
# Name: production_date, dtype: int64

# %% [markdown]
# ### previous_owner

# %%
df['previous_owner'].sample(100)
# Out:
# 21808                           NaN
# 21426      [[6,609 km, 05/2021], 1]
# 18987                           NaN
# 10379                           NaN
# 23435                           NaN
#                     ...
# 7014                            NaN
# 6577     [[238,853 km, 06/2012], 2]
# 13337      [[2,500 km, 07/2022], 1]
# 28828    [[117,042 km, 11/2013], 2]
# 26055                           NaN
# Name: previous_owner, Length: 100, dtype: object

# %%
df['previous_owner'] = df['previous_owner'].str[-1].astype(float)
df['previous_owner'].unique()
# Out:
# array([nan,  2.,  1.,  3.,  6.,  4.,  8.,  5.,  7.,  9., 10., 14., 13.,
#        12.])

# %%
df['previous_owner'].sample(20)
# Out:
# 26433    NaN
# 18834   1.00
# 403     1.00
# 11533    NaN
# 9043     NaN
# 22196   1.00
# 7286     NaN
# 28982   1.00
# 8704     NaN
# 3839     NaN
# 20762    NaN
# 16671    NaN
# 15296   2.00
# 3824    2.00
# 21519   3.00
# 3491     NaN
# 25194    NaN
# 13891    NaN
# 3251     NaN
# 22911    NaN
# Name: previous_owner, dtype: float64

# %% [markdown]
# ### other_fuel_types
# #### hydogen, other

# %%
df['other_fuel_types'].unique()
# Out:
# array([nan, 'Electricity', 'Hydogen', 'Super E10 95'], dtype=object)

# %%
f_type = ['Electricity', 'Hydogen', 'Super E10 95']
for i in f_type:
    if i=='Hydogen':
        df['other_fuel_types'] = df['other_fuel_types'].str.replace(i,'hydogen')
    else :
        df['other_fuel_types'] = df['other_fuel_types'].str.replace(i,'other')

# %%
df['other_fuel_types'].unique()
# Out:
# array([nan, 'other', 'hydogen'], dtype=object)

# %% [markdown]
# ### energy_efficiency_class
# #### energy_efficiency_class : A, other

# %%
df['energy_efficiency_class'].unique()
# Out:
# array([nan, 'C', 'B', 'E', 'D', 'A', 'G', 'F', 'A+', 'A+++', 'A++'],
#       dtype=object)

# %%
df['energy_efficiency_class'] = df['energy_efficiency_class'].str.strip('+')

e_class = ['C', 'B', 'E', 'D', 'G', 'F']
for i in e_class:
   df['energy_efficiency_class'] = df['energy_efficiency_class'].str.replace(i,'other')

# %%
df['energy_efficiency_class'].unique()
# Out:
# array([nan, 'other', 'A'], dtype=object)

# %% [markdown]
# ### co₂_efficiency

# %%
df['co₂_efficiency'].unique() #drop?
# Out:
# array([nan,
#        'Calculated on basis of measured CO₂-emissions taking into account the mass of the vehicle.'],
#       dtype=object)

# %%
df['co₂_efficiency'].sample(40) #drop edilmesi düsünülebilinir.
# Out:
# 19050    Calculated on basis of measured CO₂-emissions ...
# 25484                                                  NaN
# 25731                                                  NaN
# 12678    Calculated on basis of measured CO₂-emissions ...
# 3548                                                   NaN
# 7749                                                   NaN
# 13272    Calculated on basis of measured CO₂-emissions ...
# 11042                                                  NaN
# 17670                                                  NaN
# 27138                                                  NaN
# 6831                                                   NaN
# 5781     Calculated on basis of measured CO₂-emissions ...
# 20480                                                  NaN
# 21329                                                  NaN
# 28302    Calculated on basis of measured CO₂-emissions ...
# 25378                                                  NaN
# 6092     Calculated on basis of measured CO₂-emissions ...
# 2296                                                   NaN
# 7230                                                   NaN
# 4728     Calculated on basis of measured CO₂-emissions ...
# 26355                                                  NaN
# 22710    Calculated on basis of measured CO₂-emissions ...
# 28866                                                  NaN
# 2632     Calculated on basis of measured CO₂-emissions ...
# 21567                                                  NaN
# 18411    Calculated on basis of measured CO₂-emissions ...
# 16605                                                  NaN
# 9677                                                   NaN
# 1307                                                   NaN
# 2958                                                   NaN
# 12005                                                  NaN
# 29053                                                  NaN
# 27809                                                  NaN
# 949      Calculated on basis of measured CO₂-emissions ...
# 29231                                                  NaN
# 16093                                                  NaN
# 4140     Calculated on basis of measured CO₂-emissions ...
# 18289                                                  NaN
# 8624     Calculated on basis of measured CO₂-emissions ...
# 21403                                                  NaN
# Name: co₂_efficiency, dtype: object

# %%
df.sample(100).T
# Out:
#                                                                       18276  \
# make_model                                               Toyota Yaris Cross
# short_description                                          120H Active Tech
# make                                                             \nToyota\n
# model                                                 [\n, Yaris Cross ,\n]
# location                                  AVDA. PORTUGAL 8,  24009 LEÓN, ES
# price                                                            € 23,280.-
# body_type                                        [\n, Off-Road/Pick-up, \n]
# type                                               [\n, Pre-registered, \n]
# doors                                                           [\n, 5, \n]
# country_version                                             [\n, Spain, \n]
# offer_number                                              [\n, 7296076, \n]
# warranty                                                [\n, 60 months, \n]
# mileage                                                                3 km
# first_registration                                                  08/2022
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                                               NaN
# colour                                                                 Grey
# paint                                                                   NaN
# desc                      [ , Precio al contado: 25945 euros,  , Toyota ...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                  [\n85 kW (116 hp)\n]
# engine_size                                                  [\n1,490 cc\n]
# gears                                                               [\n1\n]
# co₂_emissions                                                           NaN
# manufacturer_colour                                            BRONCE OLIVA
# drivetrain                                                  [\n, Front, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption                                     [[0 l/100 km (comb.)]]
# comfort_convenience                                                     NaN
# entertainment_media                                                     NaN
# safety_security                                                         NaN
# extras                                                                  NaN
# empty_weight                                                 [\n1,485 kg\n]
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                      other
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
#
#                                                                       10554  \
# make_model                                                       Fiat Coupe
# short_description                                 2.0 20V TURBO LEDER AIRCO
# make                                                               \nFiat\n
# model                                                       [\n, Coupe ,\n]
# location                                  Ambachtsweg 1,  4854 MK BAVEL, NL
# price                                                            € 16,945.-
# body_type                                                   [\n, Coupe, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 2, \n]
# country_version                                       [\n, Netherlands, \n]
# offer_number                                             [\n, RZ-LS-75, \n]
# warranty                                                                NaN
# mileage                                                          182,658 km
# first_registration                                                  07/1997
# gearbox                                                        [\nManual\n]
# fuel_type                                                          Gasoline
# colour                                                                 Grey
# paint                                                              Metallic
# desc                      [Zeer mooi en in deze staat nauwelijks nog te ...
# seller                                                               Dealer
# seats                                                                   NaN
# power                                                 [\n161 kW (219 hp)\n]
# engine_size                                                  [\n1,995 cc\n]
# gears                                                               [\n5\n]
# co₂_emissions                                                           NaN
# manufacturer_colour                                          Grijs metallic
# drivetrain                                                              NaN
# cylinders                                                           [\n5\n]
# fuel_consumption          [[10.1 l/100 km (comb.)], [14.4 l/100 km (city...
# comfort_convenience                                      [Air conditioning]
# entertainment_media                                                 [Radio]
# safety_security                         [Central door lock, Power steering]
# extras                                                       [Alloy wheels]
# empty_weight                                                 [\n1,285 kg\n]
# model_code                                                              NaN
# general_inspection                                                      New
# last_service                                                            NaN
# full_service_history                                                    Yes
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                     black
# upholstery                                                          leather
# production_date                                                     1997.00
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
#
#                                                                       5468   \
# make_model                                                   Renault Megane
# short_description                    coupé cabriolet 1.9 dCi Privilège Luxe
# make                                                            \nRenault\n
# model                                                      [\n, Megane ,\n]
# location                                   Parallelweg 7f,  5349 AD OSS, NL
# price                                                             € 1,595.-
# body_type                                             [\n, Convertible, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 2, \n]
# country_version                                                         NaN
# offer_number                                             [\n, 18-RK-KD, \n]
# warranty                                                                NaN
# mileage                                                          313,192 km
# first_registration                                                  05/2005
# gearbox                                                        [\nManual\n]
# fuel_type                                                            Diesel
# colour                                                                Black
# paint                                                                   NaN
# desc                      [Voor een ruim assortiment aan goedkope auto’s...
# seller                                                               Dealer
# seats                                                           [\n, 4, \n]
# power                                                  [\n88 kW (120 hp)\n]
# engine_size                                                  [\n1,870 cc\n]
# gears                                                               [\n5\n]
# co₂_emissions                                              146 g/km (comb.)
# manufacturer_colour                                                   Zwart
# drivetrain                                                  [\n, Front, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption                                                        NaN
# comfort_convenience       [Air conditioning, Armrest, Cruise control, El...
# entertainment_media                   [CD player, On-board computer, Radio]
# safety_security           [ABS, Central door lock, Driver-side airbag, F...
# extras                                                 [Alloy wheels (16")]
# empty_weight                                                 [\n1,400 kg\n]
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                          leather
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
#
#                                                                       28052  \
# make_model                                                       Volvo XC60
# short_description         Inscription Recharge Plug-In Hybrid AWD T6 Twi...
# make                                                              \nVolvo\n
# model                                                        [\n, XC60 ,\n]
# location                                 Neuenhofstr. 77,  52078 Aachen, DE
# price                                                            € 64,790.-
# body_type                                        [\n, Off-Road/Pick-up, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                                         NaN
# offer_number                                              [\n, 2815-22, \n]
# warranty                                                                NaN
# mileage                                                            3,201 km
# first_registration                                                  12/2021
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                                          Super 95
# colour                                                                 Grey
# paint                                                              Metallic
# desc                      [Getriebe:,  Automatik, Technik:,  Allrad, Ass...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                 [\n251 kW (341 hp)\n]
# engine_size                                                  [\n1,969 cc\n]
# gears                                                               [\n8\n]
# co₂_emissions                                               42 g/km (comb.)
# manufacturer_colour                                    Pine grey / metallic
# drivetrain                                                    [\n, 4WD, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption                                   [[1.9 l/100 km (comb.)]]
# comfort_convenience       [Air conditioning, Armrest, Automatic climate ...
# entertainment_media                      [Digital radio, Sound system, USB]
# safety_security           [ABS, Adaptive Cruise Control, Adaptive headli...
# extras                                            [Alloy wheels, Roof rack]
# empty_weight                                                 [\n2,169 kg\n]
# model_code                                               [\n, 9101/BNH, \n]
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                         6.00
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                          leather
# production_date                                                     2021.00
# previous_owner                                                         1.00
# other_fuel_types                                                      other
# power_consumption                                                       NaN
# energy_efficiency_class                                                   A
# co₂_efficiency            Calculated on basis of measured CO₂-emissions ...
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      Yes
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
#
#                                                                       21974  \
# make_model                                                    Ford Streetka
# short_description                                           1.6 8V Elegance
# make                                                               \nFord\n
# model                                                    [\n, Streetka ,\n]
# location                                                75331 Pforzheim, DE
# price                                                             € 1,500.-
# body_type                                             [\n, Convertible, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 2, \n]
# country_version                                                         NaN
# offer_number                                                            NaN
# warranty                                                                NaN
# mileage                                                          211,000 km
# first_registration                                                  09/2004
# gearbox                                                        [\nManual\n]
# fuel_type                                                          Super 95
# colour                                                               Orange
# paint                                                                   NaN
# desc                      [VERKAUF NUR MIT SOFTTOP!, HARDTOP IST NICHT M...
# seller                                                       Private seller
# seats                                                           [\n, 2, \n]
# power                                                   [\n70 kW (95 hp)\n]
# engine_size                                                  [\n1,599 cc\n]
# gears                                                               [\n5\n]
# co₂_emissions                                              189 g/km (comb.)
# manufacturer_colour                                                     NaN
# drivetrain                                                              NaN
# cylinders                                                           [\n4\n]
# fuel_consumption          [[7.9 l/100 km (comb.)], [10.6 l/100 km (city)...
# comfort_convenience       [Air conditioning, Electrical side mirrors, Le...
# entertainment_media                                      [CD player, Radio]
# safety_security           [ABS, Central door lock with remote control, D...
# extras                        [All season tyres, Alloy wheels, Sport seats]
# empty_weight                                                 [\n1,061 kg\n]
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      Yes
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                     black
# upholstery                                                          leather
# production_date                                                         NaN
# previous_owner                                                         2.00
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
#
#                          15945  \
# make_model                 NaN
# short_description          NaN
# make                       NaN
# model                      NaN
# location                   NaN
# price                      NaN
# body_type                  NaN
# type                       NaN
# doors                      NaN
# country_version            NaN
# offer_number               NaN
# warranty                   NaN
# mileage                    NaN
# first_registration         NaN
# gearbox                    NaN
# fuel_type                  NaN
# colour                     NaN
# paint                      NaN
# desc                       NaN
# seller                     NaN
# seats                      NaN
# power                      NaN
# engine_size                NaN
# gears                      NaN
# co₂_emissions              NaN
# manufacturer_colour        NaN
# drivetrain                 NaN
# cylinders                  NaN
# fuel_consumption           NaN
# comfort_convenience        NaN
# entertainment_media        NaN
# safety_security            NaN
# extras                     NaN
# empty_weight               NaN
# model_code                 NaN
# general_inspection         NaN
# last_service               NaN
# full_service_history       NaN
# non_smoker_vehicle         NaN
# emission_class             NaN
# emissions_sticker          NaN
# upholstery_colour          NaN
# upholstery                 NaN
# production_date            NaN
# previous_owner             NaN
# other_fuel_types           NaN
# power_consumption          NaN
# energy_efficiency_class    NaN
# co₂_efficiency             NaN
# fuel_consumption_(wltp)    NaN
# co₂_emissions_(wltp)       NaN
# available_from             NaN
# taxi_or_rental_car         NaN
# availability               NaN
# last_timing_belt_change    NaN
# electric_range_(wltp)      NaN
# power_consumption_(wltp)   NaN
# battery_ownership          NaN
#
#                                                                       25566  \
# make_model                                                    Hyundai IONIQ
# short_description                                              Style Hybrid
# make                                                            \nHyundai\n
# model                                                       [\n, IONIQ ,\n]
# location                  Av. Reial Monestir Santa Maria de Poblet, 42.,...
# price                                                            € 15,290.-
# body_type                                                   [\n, Sedan, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                             [\n, Spain, \n]
# offer_number                                              [\n, 7279632, \n]
# warranty                                                [\n, 12 months, \n]
# mileage                                                          124,872 km
# first_registration                                                  02/2017
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                                               NaN
# colour                                                                 Grey
# paint                                                                   NaN
# desc                      [ , Precio al contado: 16490 euros,  , En HRMO...
# seller                                                               Dealer
# seats                                                                   NaN
# power                                                  [\n77 kW (105 hp)\n]
# engine_size                                                  [\n1,580 cc\n]
# gears                                                                   NaN
# co₂_emissions                                                           NaN
# manufacturer_colour                                                    Gris
# drivetrain                                                              NaN
# cylinders                                                               NaN
# fuel_consumption                                   [[3.4 l/100 km (comb.)]]
# comfort_convenience                                                     NaN
# entertainment_media                                                     NaN
# safety_security                                                         NaN
# extras                                                                  NaN
# empty_weight                                                            NaN
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                      other
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
#
#                                                                       13005  \
# make_model                                                        SEAT Leon
# short_description                    ST Style 1.6 TDI*Navigation*PDC* Style
# make                                                               \nSEAT\n
# model                                                        [\n, Leon ,\n]
# location                  Oldenburger Straße 38,  26180 Rastede/ Wahnbek...
# price                                                            € 12,990.-
# body_type                                           [\n, Station wagon, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                           [\n, Germany, \n]
# offer_number                                             [\n, MN-21235, \n]
# warranty                                                                NaN
# mileage                                                          116,540 km
# first_registration                                                  05/2018
# gearbox                                                        [\nManual\n]
# fuel_type                                                            Diesel
# colour                                                                Black
# paint                                                                   NaN
# desc                      [www.nord-automobile.de, Leon ST Style 1.6 TDI...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                  [\n85 kW (116 hp)\n]
# engine_size                                                  [\n1,598 cc\n]
# gears                                                               [\n5\n]
# co₂_emissions                                              108 g/km (comb.)
# manufacturer_colour                                     Mitternachtsschwarz
# drivetrain                                                  [\n, Front, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption          [[4.1 l/100 km (comb.)], [4.6 l/100 km (city)]...
# comfort_convenience       [Air conditioning, Armrest, Cruise control, El...
# entertainment_media       [Bluetooth, Digital radio, Hands-free equipmen...
# safety_security           [ABS, Central door lock, Daytime running light...
# extras                             [Alloy wheels, Roof rack, Voice Control]
# empty_weight                                                 [\n1,305 kg\n]
# model_code                                               [\n, 7593/ANB, \n]
# general_inspection                                                  05/2023
# last_service                                                            NaN
# full_service_history                                                    Yes
# non_smoker_vehicle                                                      Yes
# emission_class                                                         6.00
# emissions_sticker                                                      4.00
# upholstery_colour                                                       NaN
# upholstery                                                            other
# production_date                                                     2018.00
# previous_owner                                                         1.00
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
#
#                                                                       3015   \
# make_model                                                            Opel
# short_description                                Cabrio 1.4T S&S Excellence
# make                                                               \nOpel\n
# model                                                            [\n,  ,\n]
# location                  Avda. Arquitecto Miguel Angel Beloqui 11,  300...
# price                                                            € 17,009.-
# body_type                                             [\n, Convertible, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 2, \n]
# country_version                                             [\n, Spain, \n]
# offer_number                                              [\n, 7205527, \n]
# warranty                                                [\n, 12 months, \n]
# mileage                                                           51,441 km
# first_registration                                                  03/2017
# gearbox                                                        [\nManual\n]
# fuel_type                                                          Gasoline
# colour                                                               Silver
# paint                                                                   NaN
# desc                      [ , Precio al contado: 18200 euros,  , Ref.  8...
# seller                                                               Dealer
# seats                                                           [\n, 4, \n]
# power                                                 [\n103 kW (140 hp)\n]
# engine_size                                                  [\n1,362 cc\n]
# gears                                                               [\n6\n]
# co₂_emissions                                                           NaN
# manufacturer_colour                                              Gris Plata
# drivetrain                                                  [\n, Front, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption          [[6.3 l/100 km (comb.)], [7.8 l/100 km (city)]...
# comfort_convenience       [Air conditioning, Automatic climate control, ...
# entertainment_media          [Bluetooth, CD player, MP3, On-board computer]
# safety_security           [ABS, Central door lock, Driver-side airbag, E...
# extras                        [Alloy wheels, Sport seats, Sport suspension]
# empty_weight                                                 [\n1,701 kg\n]
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
#
#                                                                       4917   \
# make_model                                                   Renault Twingo
# short_description                 SCe 70 EDC LIMITED AUTOMATIK+EINPARKHILFE
# make                                                            \nRenault\n
# model                                                      [\n, Twingo ,\n]
# location                     Schmidtstraße 43,  60326 Frankfurt am Main, DE
# price                                                            € 12,990.-
# body_type                                                 [\n, Compact, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                                         NaN
# offer_number                                          [\n, GR88/22_622, \n]
# warranty                                                                NaN
# mileage                                                           48,153 km
# first_registration                                                  03/2019
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                                          Super 95
# colour                                                                White
# paint                                                                   NaN
# desc                      [Einparkhilfe hinten, Ganzjahresreifen, Radio:...
# seller                                                               Dealer
# seats                                                           [\n, 4, \n]
# power                                                   [\n51 kW (69 hp)\n]
# engine_size                                                    [\n999 cc\n]
# gears                                                               [\n6\n]
# co₂_emissions                                              117 g/km (comb.)
# manufacturer_colour                                           Pyrénées-Weiß
# drivetrain                                                   [\n, Rear, \n]
# cylinders                                                           [\n3\n]
# fuel_consumption          [[5.2 l/100 km (comb.)], [6.1 l/100 km (city)]...
# comfort_convenience       [Air conditioning, Hill Holder, Leather steeri...
# entertainment_media       [Bluetooth, Hands-free equipment, On-board com...
# safety_security           [ABS, Central door lock, Daytime running light...
# extras                    [E10-enabled, Emergency tyre repair kit, Steel...
# empty_weight                                                 [\n1,038 kg\n]
# model_code                                               [\n, 3333/BCX, \n]
# general_inspection                                                      New
# last_service                                                            NaN
# full_service_history                                                    Yes
# non_smoker_vehicle                                                      NaN
# emission_class                                                         6.00
# emissions_sticker                                                      4.00
# upholstery_colour                                                     black
# upholstery                                                            other
# production_date                                                         NaN
# previous_owner                                                         1.00
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                               other
# co₂_efficiency            Calculated on basis of measured CO₂-emissions ...
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
#
#                           ...  \
# make_model                ...
# short_description         ...
# make                      ...
# model                     ...
# location                  ...
# price                     ...
# body_type                 ...
# type                      ...
# doors                     ...
# country_version           ...
# offer_number              ...
# warranty                  ...
# mileage                   ...
# first_registration        ...
# gearbox                   ...
# fuel_type                 ...
# colour                    ...
# paint                     ...
# desc                      ...
# seller                    ...
# seats                     ...
# power                     ...
# engine_size               ...
# gears                     ...
# co₂_emissions             ...
# manufacturer_colour       ...
# drivetrain                ...
# cylinders                 ...
# fuel_consumption          ...
# comfort_convenience       ...
# entertainment_media       ...
# safety_security           ...
# extras                    ...
# empty_weight              ...
# model_code                ...
# general_inspection        ...
# last_service              ...
# full_service_history      ...
# non_smoker_vehicle        ...
# emission_class            ...
# emissions_sticker         ...
# upholstery_colour         ...
# upholstery                ...
# production_date           ...
# previous_owner            ...
# other_fuel_types          ...
# power_consumption         ...
# energy_efficiency_class   ...
# co₂_efficiency            ...
# fuel_consumption_(wltp)   ...
# co₂_emissions_(wltp)      ...
# available_from            ...
# taxi_or_rental_car        ...
# availability              ...
# last_timing_belt_change   ...
# electric_range_(wltp)     ...
# power_consumption_(wltp)  ...
# battery_ownership         ...
#
#                                                                       7168   \
# make_model                                                 Renault Talisman
# short_description                     2.0 Blue dCi 190ch Initiale Paris EDC
# make                                                            \nRenault\n
# model                                                    [\n, Talisman ,\n]
# location                                                   10000 Troyes, FR
# price                                                            € 36,990.-
# body_type                                                   [\n, Sedan, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 4, \n]
# country_version                                                         NaN
# offer_number                                 [\n, star-GA-477-CC_20629, \n]
# warranty                                                                NaN
# mileage                                                            3,523 km
# first_registration                                                  06/2021
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                          Diesel (Particle filter)
# colour                                                                  NaN
# paint                                                                   NaN
# desc                      [Marque: RENAULTModèle: TalismanVersion: 2.0 B...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                                   NaN
# engine_size                                                  [\n1,997 cc\n]
# gears                                                                   NaN
# co₂_emissions                                                           NaN
# ...
# empty_weight                                                            NaN
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    Yes
# non_smoker_vehicle                                                      Yes
# emission_class                                                         6.00
# emissions_sticker                                                       NaN
# upholstery_colour                                                     black
# upholstery                                                            other
# production_date                                                         NaN
# previous_owner                                                         1.00
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
#
#                                                                       11228  \
# make_model                                                            Fiat
# short_description                                       Qubo 1,4 73 Dynamic
# make                                                               \nFiat\n
# model                                                            [\n,  ,\n]
# location                               Ludersdorf 266,  8200 Ludersdorf, AT
# price                                                             € 5,990.-
# body_type                                           [\n, Station wagon, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 5, \n]
# country_version                                                         NaN
# offer_number                                                  [\n, 159, \n]
# warranty                                                                NaN
# mileage                                                          148,500 km
# first_registration                                                  05/2011
# gearbox                                                        [\nManual\n]
# fuel_type                                                          Gasoline
# colour                                                                White
# paint                                                                   NaN
# desc                      [ACHTUNG 2 Standorte, Standort Gleisdorf , FIN...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                   [\n54 kW (73 hp)\n]
# engine_size                                                  [\n1,360 cc\n]
# gears                                                               [\n5\n]
# co₂_emissions                                              152 g/km (comb.)
# manufacturer_colour                                                    Weiß
# drivetrain                                                  [\n, Front, \n]
# cylinders                                                               NaN
# fuel_consumption          [[6.6 l/100 km (comb.)], [8.2 l/100 km (city)]...
# comfort_convenience       [Air conditioning, Armrest, Electrical side mi...
# entertainment_media       [Bluetooth, CD player, Hands-free equipment, M...
# safety_security           [ABS, Central door lock, Central door lock wit...
# extras                                            [Alloy wheels, Roof rack]
# empty_weight                                                 [\n1,180 kg\n]
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                         5.00
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                     2011.00
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
#
#                                                                       10666  \
# make_model                                                   Fiat Barchetta
# short_description                                 Barchetta LIMITED EDITION
# make                                                               \nFiat\n
# model                                                   [\n, Barchetta ,\n]
# location                                                   10121 Torino, IT
# price                                                            € 12,500.-
# body_type                                                   [\n, Coupe, \n]
# type                                                         [\n, Used, \n]
# doors                                                           [\n, 2, \n]
# country_version                                                         NaN
# offer_number                                                            NaN
# warranty                                                                NaN
# mileage                                                           82,021 km
# first_registration                                                  04/1997
# gearbox                                                        [\nManual\n]
# fuel_type                                                          Gasoline
# colour                                                                 Grey
# paint                                                                   NaN
# desc                         [Fiat Barchetta Limited Edition. Iscritta ASI]
# seller                                                       Private seller
# seats                                                           [\n, 2, \n]
# power                                                  [\n96 kW (131 hp)\n]
# engine_size                                                  [\n1,747 cc\n]
# gears                                                                   NaN
# co₂_emissions                                                           NaN
# manufacturer_colour                                                     NaN
# drivetrain                                                              NaN
# cylinders                                                           [\n4\n]
# fuel_consumption          [[8.4 l/100 km (comb.)], [11.6 l/100 km (city)...
# comfort_convenience                                                     NaN
# entertainment_media                                                     NaN
# safety_security                                                         NaN
# extras                                                                  NaN
# empty_weight                                                 [\n1,060 kg\n]
# model_code                                                              NaN
# general_inspection                                                      NaN
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                          NaN
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                              NaN
# production_date                                                         NaN
# previous_owner                                                          NaN
# other_fuel_types                                                        NaN
# power_consumption                                                       NaN
# energy_efficiency_class                                                 NaN
# co₂_efficiency                                                          NaN
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
#
#                                                                       25363
# make_model                                                    Hyundai IONIQ
# short_description               1.6 6-AT HYBRID KAMERA+BLUETOOTH+PDC HINTEN
# make                                                            \nHyundai\n
# model                                                       [\n, IONIQ ,\n]
# location                               Bruchstraße 58,  45525 Hattingen, DE
# price                                                            € 26,490.-
# body_type                                                   [\n, Sedan, \n]
# type                                               [\n, Pre-registered, \n]
# doors                                                           [\n, 5, \n]
# country_version                                           [\n, Germany, \n]
# offer_number                                             [\n, NU294006, \n]
# warranty                                                [\n, 60 months, \n]
# mileage                                                               12 km
# first_registration                                                  08/2022
# gearbox                                                     [\nAutomatic\n]
# fuel_type                                                          Super 95
# colour                                                                 Grey
# paint                                                              Metallic
# desc                      [Getriebe:,  Automatik, Technik:,  Bordcompute...
# seller                                                               Dealer
# seats                                                           [\n, 5, \n]
# power                                                  [\n77 kW (105 hp)\n]
# engine_size                                                  [\n1,580 cc\n]
# gears                                                               [\n6\n]
# co₂_emissions                                               97 g/km (comb.)
# manufacturer_colour                                        Cyber grey / met
# drivetrain                                                  [\n, Front, \n]
# cylinders                                                           [\n4\n]
# fuel_consumption                                   [[4.2 l/100 km (comb.)]]
# comfort_convenience       [Air conditioning, Armrest, Automatic climate ...
# entertainment_media       [Android Auto, Apple CarPlay, Bluetooth, Digit...
# safety_security           [ABS, Alarm system, Central door lock, Daytime...
# extras                          [Alloy wheels, Shift paddles, Touch screen]
# empty_weight                                                 [\n1,544 kg\n]
# model_code                                               [\n, 8252/AHM, \n]
# general_inspection                                                  08/2025
# last_service                                                            NaN
# full_service_history                                                    NaN
# non_smoker_vehicle                                                      NaN
# emission_class                                                         6.00
# emissions_sticker                                                       NaN
# upholstery_colour                                                       NaN
# upholstery                                                            other
# production_date                                                         NaN
# previous_owner                                                         1.00
# other_fuel_types                                                      other
# power_consumption                                                       NaN
# energy_efficiency_class                                                   A
# co₂_efficiency            Calculated on basis of measured CO₂-emissions ...
# fuel_consumption_(wltp)                                                 NaN
# co₂_emissions_(wltp)                                                    NaN
# available_from                                                          NaN
# taxi_or_rental_car                                                      NaN
# availability                                                            NaN
# last_timing_belt_change                                                 NaN
# electric_range_(wltp)                                                   NaN
# power_consumption_(wltp)                                                NaN
# battery_ownership                                                       NaN
#
# [58 rows x 100 columns]

# %%
df["comfort_convenience"] = [",".join(item) if type(item) == list else item for item in df["comfort_convenience"]]

# %%
df["comfort_convenience"].value_counts(dropna=False)
# Out:
# NaN                                                                                                                                                                                                                                                                                                                                                                                                            4047
# Air conditioning, Automatic climate control, Electrical side mirrors, Multi-function steering wheel, Power windows                                                                                                                                                                                                                                                                                              244
# Air conditioning, Automatic climate control, Cruise control                                                                                                                                                                                                                                                                                                                                                     171
# Air conditioning, Automatic climate control, Cruise control, Electrical side mirrors, Multi-function steering wheel, Power windows                                                                                                                                                                                                                                                                              168
# Air conditioning                                                                                                                                                                                                                                                                                                                                                                                                157
#                                                                                                                                                                                                                                                                                                                                                                                                                ...
# Armrest, Automatic climate control, 2 zones, Cruise control, Fold flat passenger seat, Hill Holder, Leather steering wheel, Light sensor, Lumbar support, Multi-function steering wheel, Navigation system, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Split rear seats, Start-stop system                                                                                     1
# Air conditioning, Armrest, Automatic climate control, Cruise control, Electric tailgate, Electrical side mirrors, Hill Holder, Keyless central door lock, Leather steering wheel, Light sensor, Multi-function steering wheel, Navigation system, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating                                               1
# Armrest, Automatic climate control, 2 zones, Cruise control, Electrical side mirrors, Fold flat passenger seat, Hill Holder, Leather steering wheel, Light sensor, Lumbar support, Multi-function steering wheel, Navigation system, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Split rear seats, Start-stop system, Tinted windows       1
# Armrest, Automatic climate control, 2 zones, Cruise control, Electrical side mirrors, Hill Holder, Keyless central door lock, Leather steering wheel, Light sensor, Multi-function steering wheel, Parking assist system camera, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Split rear seats, Start-stop system, Tinted windows           1
# Air conditioning, Armrest, Cruise control, Electrical side mirrors, Leather steering wheel, Lumbar support, Multi-function steering wheel, Navigation system, Power windows, Seat heating, Tinted windows                                                                                                                                                                                                         1
# Name: comfort_convenience, Length: 14439, dtype: int64

# %%
A= ['Parking assist system sensors rear', 'Rain sensor', 'Seat heating', 'Split rear seats', 'Start-stop system', 'Tinted windows']
C= ['Air conditioning','Electrical side mirrors']

for i in A:
    if df['comfort_convenience'].str.contains(i) and df['comfort_convenience'].str.contains('Seat heating') and df['comfort_convenience'].str.contains('Rain sensor') and df['comfort_convenience'].str.contains('Split rear seats') and df['comfort_convenience'].str.contains('Start-stop system') and df['comfort_convenience'].str.contains('Tinted windows'):
    df['comfort_convenience']='A'
elif df['comfort_convenience'].str.contains('Air conditioning') and df['comfort_convenience'].str.contains('Electrical side mirrors'):
     df['comfort_convenience']='C'  
else:
    df['comfort_convenience']='B'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12860\1063207402.py in <module>
#      10 #     df['comfort_convenience']='B'
#      11
# ---> 12 if df['comfort_convenience'].str.contains("Parking assist system sensors rear"):
#      13     print('a')
#      14
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1525     @final
#    1526     def __nonzero__(self):
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# ### 'make'

# %%
df['make'].unique()
# Out:
# array(['\nMercedes-Benz\n', nan, '\nOpel\n', '\nRenault\n', '\nPeugeot\n',
#        '\nFiat\n', '\nSEAT\n', '\nSkoda\n', '\nDacia\n', '\nToyota\n',
#        '\nNissan\n', '\nFord\n', '\nHyundai\n', '\nVolvo\n'], dtype=object)

# %%
df['make'] = df['make'].str.strip('\n')

# %%
df['make'].unique()
# Out:
# array(['Mercedes-Benz', nan, 'Opel', 'Renault', 'Peugeot', 'Fiat', 'SEAT',
#        'Skoda', 'Dacia', 'Toyota', 'Nissan', 'Ford', 'Hyundai', 'Volvo'],
#       dtype=object)

# %% [markdown]
# ### 'model'

# %%
df['model'] = df['model'].str.join(",").str.strip('\n,')

# %%
df['model'].unique() #nasil yapilacagi tartisilabilinir..
# Out:
# array([' A 160 ', ' EQE 350 ', ' A 45 AMG ', ' A 35 AMG ', ' C 160 ',
#        ' CLA 180 ', ' A 220 ', ' A 200 ', ' A 250 ', ' A 180 ',
#        ' GLC 220 ', ' E 220 ', ' B 200 ', ' A 150 ', ' V 220 ',
#        ' AMG GT ', ' E 300 ', ' EQS ', ' A 140 ', '  ', ' CL ', ' B 180 ',
#        ' GLB 200 ', ' E 350 ', ' CLA 200 ', ' 280 ', ' GLA 180 ',
#        ' Viano ', ' E 53 AMG ', ' SLK 200 ', ' GLE 350 ', ' 220 ',
#        ' SL 500 ', ' E 400 ', ' SLC 43 AMG ', ' SL 350 ', ' SLC 250 ',
#        ' SLK 350 ', ' SLS ', ' CLK 200 ', ' C 400 ', ' SL 65 AMG ',
#        ' C 43 AMG ', ' C 63 AMG ', ' SLK 250 ', ' 500 ', ' SLK 300 ',
#        ' SLC 200 ', ' SLK 55 AMG ', ' S 63 AMG ', ' 230 ', ' E 500 ',
#        ' SLK ', ' SL 55 AMG ', ' CLK 55 AMG ', ' C 300 ', ' SLK 280 ',
#        ' E 450 ', ' SLC 180 ', ' C 200 ', ' E 200 ', ' SL 63 AMG ',
#        ' SL 300 ', ' S 560 ', ' C 180 ', ' C 250 ', ' C 220 ', ' E 250 ',
#        ' SL 560 ', ' SLK 230 ', ' SL 280 ', ' SL 380 ', ' SL 600 ',
#        ' G 500 ', ' 190 ', ' 250 ', ' CLK 350 ', ' SLC 300 ', ' G 320 ',
#        ' S 500 ', ' SL 320 ', ' SLR ', ' SL 400 ', ' CLK 280 ',
#        ' SL 450 ', ' CLK 240 ', ' CLK 230 ', ' 200 ', ' CL 500 ',
#        ' CLA 220 ', ' CLA 45 AMG ', ' CLS 500 ', ' S 400 ', ' CL 63 AMG ',
#        ' CLS 350 ', ' GLC 43 AMG ', ' CLS 400 ', ' CLK 63 AMG ',
#        ' CLS 250 ', ' 450 ', ' CLK 500 ', ' CLA 35 AMG ', ' GLC 63 AMG ',
#        ' CLS 320 ', ' CLK 320 ', ' CLS 450 ', ' 320 ', ' CLS 53 AMG ',
#        ' CL 600 ', ' GLE 43 AMG ', ' CLA 250 ', ' GLC 200 ',
#        ' GLE 63 AMG ', ' GLC 400 ', ' CLS ', ' GLE 400 ', ' CLK ',
#        ' 350 ', ' GLC 250 ', ' S 65 AMG ', ' GLC 350 ', ' CLS 300 ',
#        ' GLE 300 ', ' E 50 AMG ', ' S 450 ', ' GLC 300 ', ' GLE 450 ',
#        ' ML 320 ', ' ML 63 AMG ', ' ML 500 ', ' GL 500 ', ' GLE 580 ',
#        ' GLE 53 AMG ', ' G 63 AMG ', ' EQA ', ' G 400 ', ' GL 63 AMG ',
#        ' ML 450 ', ' ML 300 ', ' GLS 400 ', ' ML 350 ', ' EQC 400 ',
#        ' R 300 ', ' GLA 45 AMG ', ' GLK 350 ', ' GLK 220 ', ' GL 350 ',
#        ' GLB 220 ', ' GLA 220 ', ' GLK 250 ', ' G 350 ', ' GLA 250 ',
#        ' GLE 250 ', ' ML 400 ', ' EQB 350 ', ' ML 250 ', ' GLA 200 ',
#        ' GLA 35 AMG ', ' GLK 200 ', ' G ', ' G 55 AMG ', ' GLS 350 ',
#        ' GL 420 ', ' GLE 500 ', ' EQB 300 ', ' GLB 250 ', ' GLB 180 ',
#        ' EQA 250 ', ' G 230 ', ' GLB 35 AMG ', ' X 250 ', ' GL 320 ',
#        ' GLS 63 AMG ', ' 170 ', ' ML 280 ', ' G 65 AMG ', ' Sprinter ',
#        ' C 350 ', ' E 43 AMG ', ' E 280 ', ' CLS 63 AMG ', ' C 32 AMG ',
#        ' E 63 AMG ', ' V 300 ', ' EQE 43 ', nan, ' V 250 ', ' Vito ',
#        ' EQV 300 ', ' B 220 ', ' B 250 ', ' S 300 ', ' C 36 AMG ',
#        ' S 580 ', ' S 600 ', ' C 280 ', ' S 350 ', ' CLS 280 ',
#        ' S 55 AMG ', ' E 240 ', ' C 320 ', ' E 320 ', ' E 230 ',
#        ' EQE 500 ', ' S 420 ', ' 260 ', ' Corsa ', ' Astra ', ' Adam ',
#        ' Corsa-e ', ' Meriva ', ' Karl ', ' Agila ', ' Insignia ',
#        ' Vectra ', ' Antara ', ' Ampera ', ' GT ', ' Cascada ', ' Tigra ',
#        ' Speedster ', ' Kadett ', ' Calibra ', ' Manta ', ' Commodore ',
#        ' Rekord ', ' Monza ', ' Ascona ', ' Crossland X ', ' Grandland ',
#        ' Grandland X ', ' Monterey ', ' Mokka ', ' Mokka X ',
#        ' Crossland ', ' Frontera ', ' Mokka-E ', ' Vivaro ',
#        ' Zafira Tourer ', ' Zafira Life ', ' Combo Life ', ' Combo ',
#        ' Zafira ', ' Movano ', ' Senator ', ' Megane ', ' Clio ',
#        ' Laguna ', ' Twingo ', ' ZOE ', ' Captur ', ' Twizy ',
#        ' Fluence ', ' Grand Scenic ', ' R 19 ', ' Avantime ',
#        ' Megane E-Tech ', ' Espace ', ' Kangoo Z.E. ', ' Alpine A110 ',
#        ' Wind ', ' Spider ', ' R 4 ', ' Coupe ', ' Talisman ', ' R 9 ',
#        ' Alpine A310 ', ' Kangoo ', ' Alpine V6 ', ' Super 5 ',
#        ' Arkana ', ' R 5 ', ' Fuego ', ' Alpine A610 ', ' Kadjar ',
#        ' Alaskan ', ' Koleos ', ' Scenic ', ' Trafic ', ' Master ',
#        ' Express ', ' Grand Espace ', ' P 1400 ', ' Latitude ',
#        ' Safrane ', ' R 18 ', ' R 21 ', ' Grand Modus ', ' R 11 ',
#        ' 308 ', ' 205 ', ' 206 ', ' 208 ', ' 207 ', ' 1007 ', ' 307 ',
#        ' 108 ', ' Rifter ', ' e-208 ', ' 3008 ', ' 508 ', ' Partner ',
#        ' 107 ', ' 106 ', ' 306 ', ' iOn ', ' 504 ', ' 404 ', ' Expert ',
#        ' 407 ', ' RCZ ', ' 406 ', ' 309 ', ' 304 ', ' 2008 ', ' 4007 ',
#        ' 4008 ', ' 5008 ', ' e-2008 ', ' Traveller ', ' Bipper ',
#        ' Ranch ', ' 607 ', ' 505 ', ' 305 ', ' 301 ', ' Boxer ',
#        ' 500 Abarth ', ' 595 Abarth ', ' Tipo ', ' Stilo ', ' 500X ',
#        ' 500e ', ' Punto ', ' Panda ', ' Fiorino ', ' Seicento ',
#        ' 500C ', ' Brava ', ' New Panda ', ' Grande Punto ', ' 850 ',
#        ' Punto Evo ', ' 600 ', ' Bravo ', ' 126 ', ' Uno ', ' 500L ',
#        ' Barchetta ', ' 124 Spider ', ' Spider Europa ', ' Dino ',
#        ' 130 ', ' 131 ', ' X 1/9 ', ' 124 Coupè ', ' 128 ', ' 127 ',
#        ' Ritmo ', ' Cinquecento ', ' Fullback ', ' Freemont ', ' Strada ',
#        ' Sedici ', ' Talento ', ' Croma ', ' Qubo ', ' Doblo ',
#        ' Multipla ', ' Leon ', ' Ibiza ', ' Toledo ', ' Cordoba ',
#        ' Arona ', ' Mii ', ' Altea XL ', ' Arosa ', ' Tarraco ',
#        ' Marbella ', ' Ateca ', ' Altea ', ' Alhambra ', ' Exeo ',
#        ' Leon e-Hybrid ', ' Octavia ', ' Scala ', ' Rapid/Spaceback ',
#        ' Fabia ', ' Kamiq ', ' Citigo ', ' Superb ', ' Kodiaq ',
#        ' Felicia ', ' 105 ', ' Karoq ', ' Enyaq ', ' Yeti ', ' Spring ',
#        ' Sandero ', ' Logan ', ' Lodgy ', ' Dokker ', ' Duster ',
#        ' Jogger ', ' Break ', ' Prius ', ' Aygo X ', ' Yaris ', ' Aygo ',
#        ' Corolla ', ' Auris ', ' Urban Cruiser ', ' iQ ', ' Verso ',
#        ' Avensis ', ' Yaris Cross ', ' Starlet ', ' Verso-S ', ' MR 2 ',
#        ' Supra ', ' FJ40 ', ' Celica ', ' Land Cruiser ', ' RAV 4 ',
#        ' Paseo ', ' C-HR ', ' GT86 ', ' Coaster ', ' GR86 ', ' Tacoma ',
#        ' FJ Cruiser ', ' Hilux ', ' Highlander ', ' Proace ', ' Tundra ',
#        ' 4-Runner ', ' Corolla Verso ', ' Sienna ', ' Crown ', ' Mirai ',
#        ' Camry ', ' Aristo ', ' Prius+ ', ' Leaf ', ' Micra ',
#        ' Qashqai ', ' Juke ', ' Pulsar ', ' Note ', ' Almera ', ' Tiida ',
#        ' Primera ', ' Titan ', ' 370Z ', ' 280 ZX ', ' Datsun ', ' 350Z ',
#        ' 100 NX ', ' Patrol ', ' Figaro ', ' 300 ZX ', ' GT-R ',
#        ' Skyline ', ' Silvia ', ' 200 SX ', ' Navara ', ' Sunny ',
#        ' Ariya ', ' X-Trail ', ' Murano ', ' Terrano ', ' Pathfinder ',
#        ' Qashqai+2 ', ' King Cab ', ' Townstar ', ' NV300 ',
#        ' Primastar ', ' NV200 ', ' Stagea ', ' NV250 ', ' Almera Tino ',
#        ' Evalia ', ' Rogue ', ' Cube ', ' NV400 ', ' E-NV200 ', ' Pixo ',
#        ' Gloria ', ' Fiesta ', ' Focus ', ' Mondeo ', ' F 250 ', ' Kuga ',
#        ' Ka/Ka+ ', ' B-Max ', ' EcoSport ', ' Mustang ', ' Bronco ',
#        ' Puma ', ' Escort ', ' M ', ' Thunderbird ', ' Focus CC ',
#        ' Streetka ', ' Fairlane ', ' Galaxy ', ' Probe ',
#        ' Mustang Mach-E ', ' Cougar ', ' Mercury ', ' Gran Torino ',
#        ' Sierra ', ' Capri ', ' Explorer ', ' Edge ', ' Ranger ',
#        ' Maverick ', ' F 150 ', ' Ranger Raptor ', ' Tourneo Custom ',
#        ' Transit Custom ', ' S-Max ', ' Transit Connect ',
#        ' Tourneo Connect ', ' Transit ', ' Tourneo Courier ',
#        ' Grand Tourneo ', ' Grand C-Max ', ' C-Max ', ' Transit Courier ',
#        ' i30 ', ' i10 ', ' i20 ', ' ELANTRA ', ' BAYON ', ' IONIQ ',
#        ' iX20 ', ' Getz ', ' Terracan ', ' KONA ', ' ACCENT ', ' Excel ',
#        ' Atos ', ' VELOSTER ', ' TUCSON ', ' Genesis ', ' Genesis Coupe ',
#        ' Tiburon ', ' S-Coupe ', ' SANTA FE ', ' iX35 ', ' H-1 ',
#        ' IONIQ 5 ', ' NEXO ', ' Grand Santa Fe ', ' i40 ', ' STARIA ',
#        ' Trajet ', ' SONATA ', ' Lantra ', ' H 350 ', ' KONA Elektro ',
#        ' Matrix ', ' V40 ', ' S80 ', ' S60 ', ' S40 ', ' XC60 ', ' C30 ',
#        ' V40 Cross Country ', ' C70 ', ' XC90 ', ' P1800 ', ' Amazon ',
#        ' 480 ', ' 240 ', ' 262 ', ' 780 ', ' PV544 ', ' S90 ', ' C40 ',
#        ' V90 Cross Country ', ' XC40 ', ' V60 Cross Country ', ' XC70 ',
#        ' V90 ', ' V50 ', ' V60 ', ' V70 ', ' 740 ', ' 945 ', ' 440 ',
#        ' S70 ', ' 960 ', ' 244 '], dtype=object)

# %% [markdown]
# ### 'location'

# %%
df['location'].unique()
# Out:
# array(['P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SANTA MARIA, ES',
#        'APARTADO DE CORREOS 1032,  26140 LOGROÑO, ES',
#        'PORT. TARRACO, MOLL DE LLEVANT, Nº 5, LOC. 6-8,  43004 TARRAGONA, ES',
#        ..., '2521AA DEN HAAG, NL', '1000 Brussel, BE',
#        'Sur rendez-vous,  5060 Sambreville, BE'], dtype=object)

# %%
df['location'] = df['location'].str[-2:]

# %%
df['location'].unique()
# Out:
# array(['ES', 'DE', 'BE', 'AT', 'NL', 'FR', 'IT', nan, 'LU', 'DK', 'EE',
#        'BG'], dtype=object)

# %% [markdown]
# ### 'price'

# %%
df['price'].unique()
# Out:
# array(['€ 16,950.-', '€ 80,900.-', '€ 69,900.-', ..., '€ 43,420.-',
#        '€ 36,795.-', '€ 4,440.-'], dtype=object)

# %%
df['price'] = df['price'].str.strip('€.- ').str.replace(",", "").astype(float)

# %%
df['price'].unique()
# Out:
# array([16950., 80900., 69900., ..., 43420., 36795.,  4440.])

# %% [markdown]
# ### 'body_type'

# %%
df['body_type'] = df['body_type'].str.join(",").str.strip(',\n ')

# %%
df['body_type'].unique() #daha calisilabilinir mi
# Out:
# array(['Compact', 'Convertible', 'Coupe', 'Off-Road/Pick-up',
#        'Station wagon', nan, 'Sedan'], dtype=object)

# %% [markdown]
# ### 'type'

# %%
df['type'].sample(5)
# Out:
# 3747     [\n, Pre-registered, \n]
# 11091              [\n, Used, \n]
# 20375              [\n, Used, \n]
# 13079              [\n, Used, \n]
# 2290               [\n, Used, \n]
# Name: type, dtype: object

# %%
df['type'] = df['type'].str.join(",").str.strip(',\n ')

# %%
df['type'].unique() #daha calisilabilinir mi
# Out:
# array(['Used', 'Pre-registered', 'Demonstration', "Employee's car", nan],
#       dtype=object)

# %% [markdown]
# ### 'doors'

# %%
df['doors'].sample(5)
# Out:
# 21723    [\n, 5, \n]
# 28175    [\n, 5, \n]
# 25301    [\n, 5, \n]
# 4830     [\n, 5, \n]
# 20297    [\n, 5, \n]
# Name: doors, dtype: object

# %%
df['doors'] = df['doors'].str.join(",").str.strip(',\n ').astype(float)

# %%
df['doors'].unique()
# Out:
# array([ 5.,  4.,  3.,  2., nan,  1.,  6.])

# %% [markdown]
# # PART- 2 `( Handling With Missing Vales )`

# %% [markdown]
# # PART- 3 `( Handling With Outliers )`

# %% [markdown]
# # Final Step (Checking final situation of data via graphs)

# %% [markdown]
# ## Export dataframe to csv file (without dummy)

# %%
df.to_csv("final_scout_not_dummy.csv", index=False)

# %% [markdown]
# # Dummy Operation

# %% [markdown]
# ## Export dataframe to csv file (dummy)

# %%
df_dummied.to_csv("final_scout_dummy.csv", index=False)
